# %%
import meep as mp
import numpy as np
import matplotlib.pyplot as plt
from typing import Tuple
from scipy.optimize import minimize

#Au material script from complex refractive index data

wvl_data = np.array([250.000000, 260.000000, 270.000000, 280.000000, 290.000000, 300.000000,
                              310.000000, 320.000000, 330.000000, 340.000000, 350.000000, 360.000000,
                              370.000000, 380.000000, 390.000000, 400.000000, 410.000000, 420.000000,
                              430.000000, 440.000000, 450.000000, 460.000000, 470.000000, 480.000000,
                              490.000000, 500.000000, 510.000000, 520.000000, 530.000000, 540.000000,
                              550.000000, 560.000000, 570.000000, 580.000000, 590.000000, 600.000000,
                              610.000000, 620.000000, 630.000000, 640.000000, 650.000000, 660.000000,
                              670.000000, 680.000000, 690.000000, 700.000000, 710.000000, 720.000000,
                              730.000000, 740.000000, 750.000000, 760.000000, 770.000000, 780.000000,
                              790.000000, 800.000000, 810.000000, 820.000000, 830.000000, 840.000000,
                              850.000000, 860.000000, 870.000000, 880.000000, 890.000000, 900.000000,
                              910.000000, 920.000000, 930.000000, 940.000000, 950.000000, 960.000000,
                              970.000000, 980.000000, 990.000000, 1000.000000])

#Refractive index data
n_data = np.array([1.486293, 1.517101, 1.602219, 1.678100, 1.750429, 1.800042, 1.830000, 1.836011,
                   1.813111, 1.781199, 1.751161, 1.726732, 1.706249, 1.687926, 1.670782, 1.658000,
                   1.641467, 1.626593, 1.607286, 1.572004, 1.503407, 1.417996, 1.315496, 1.189871,
                   1.018554, 0.849238, 0.698231, 0.571152, 0.475555, 0.397920, 0.355713, 0.318417,
                   0.295010, 0.278152, 0.261664, 0.245531, 0.229740, 0.214278, 0.199131, 0.184288,
                   0.169737, 0.164060, 0.162125, 0.160792, 0.160087, 0.160906, 0.161863, 0.162930,
                   0.164154, 0.166357, 0.168557, 0.170750, 0.172934, 0.175425, 0.178189, 0.180917,
                   0.183609, 0.186265, 0.189334, 0.193206, 0.197006, 0.200737, 0.204403, 0.208008,
                   0.211773, 0.215750, 0.219658, 0.223500, 0.227279, 0.230997, 0.234659, 0.239028,
                   0.243770, 0.248435, 0.253026, 0.257546])

#Absorption coefficient data (imaginary coefficient of complex refractive index)
k_data = np.array([1.660980, 1.759202, 1.824512, 1.873471, 1.904443, 1.919298, 1.916000, 1.897531,
                   1.870450, 1.852625, 1.847116, 1.855697, 1.883198, 1.916907, 1.939990, 1.956000,
                   1.957488, 1.949527, 1.934151, 1.910625, 1.878436, 1.843614, 1.814717, 1.799925,
                   1.820950, 1.892178, 2.027084, 2.185897, 2.374957, 2.553141, 2.695668, 2.832206,
                   2.899935, 2.930925, 2.961718, 2.992315, 3.022714, 3.052916, 3.082919, 3.112725,
                   3.142334, 3.293285, 3.477580, 3.652616, 3.817434, 3.959739, 4.097111, 4.230027,
                   4.358280, 4.474892, 4.588542, 4.699445, 4.807792, 4.914824, 5.020584, 5.124162,
                   5.225688, 5.325278, 5.419440, 5.505117, 5.589481, 5.672590, 5.754499, 5.835259,
                   5.919898, 6.009588, 6.097960, 6.185070, 6.270970, 6.355709, 6.439333, 6.519685,
                   6.597783, 6.674968, 6.751271, 6.826722])


#Fit the data to Lorentz Function and generate Au material

def lorentzfunc(p: np.ndarray, x: np.ndarray) -> np.ndarray:
    """
    Returns the complex ε profile given a set of Lorentzian parameters p
    (σ_0, ω_0, γ_0, σ_1, ω_1, γ_1, ...) for a set of frequencies x.
    """
    N = len(p) // 3
    y = np.zeros(len(x))
    for n in range(N):
        A_n, x_n, g_n = p[3 * n : 3 * n + 3]
        y = y + A_n / (np.square(x_n) - np.square(x) - 1j * x * g_n)
    return y


def lorentzerr(p: np.ndarray, x: np.ndarray, y: np.ndarray) -> float:
    """
    Returns the error (or residual or loss) as the L2 norm
    of the difference of ε(p,x) and y over a set of frequencies x.
    """
    yp = lorentzfunc(p, x)
    val = np.sum(np.square(abs(y - yp)))
    return val


def lorentzfit(
    p0: np.ndarray,
    x: np.ndarray,
    y: np.ndarray,
    tol: float = 1e-25,
    maxeval: float = 10000,
) -> Tuple[np.ndarray, float]:
    """
    Returns the optimal Lorentzian polarizability parameters and error
    which minimize the error in ε(p0,x) relative to y for an initial
    set of Lorentzian polarizability parameters p0 over a set of
    frequencies x using the scipy.optimize algorithm for a relative
    tolerance tol and a maximum number of iterations maxeval.
    """
    result = minimize(
        lambda p: lorentzerr(p, x, y),
        p0,
        method="L-BFGS-B",
        options={"ftol": tol, "maxiter": maxeval},
    )
    popt = result.x
    minf = result.fun
    return popt, minf


if __name__ == "__main__":
    
    n = n_data[:] + 1j * k_data[:]
    eps_inf = 1.1

    eps = np.square(n) - eps_inf

    wl = wvl_data[:]
    wl_min = 250  # minimum wavelength (units of nm)
    wl_max = 1000  # maximum wavelength (units of nm)
    start_idx = np.where(wl > wl_min)
    idx_start = start_idx[0][0]
    end_idx = np.where(wl < wl_max)
    idx_end = end_idx[0][-1] + 1

    # The fitting function is ε(f) where f is the frequency, rather than ε(λ).
    freqs = 1000 / wl  # units of 1/μm
    freqs_reduced = freqs[idx_start:idx_end]
    wl_reduced = wl[idx_start:idx_end]
    eps_reduced = eps[idx_start:idx_end]

    # Fitting parameter: number of Lorentzian terms to use in the fit
    num_lorentzians = 2

    # Number of times to repeat local optimization with random initial values.
    num_repeat = 30

    ps = np.zeros((num_repeat, 3 * num_lorentzians))
    mins = np.zeros(num_repeat)
    for m in range(num_repeat):
        # Initial values for the Lorentzian polarizability terms. Each term
        # consists of three parameters (σ, ω, γ) and is chosen randomly.
        # Note: for the case of no absorption, γ should be set to zero.
        p_rand = [10 ** (np.random.random()) for _ in range(3 * num_lorentzians)]
        ps[m, :], mins[m] = lorentzfit(p_rand, freqs_reduced, eps_reduced, 1e-25, 50000)
        ps_str = "( " + ", ".join(f"{prm:.4f}" for prm in ps[m, :]) + " )"
        print(f"iteration:, {m:3d}, ps_str, {mins[m]:.6f}")

    # Find the best performing set of parameters.
    idx_opt = np.argmin(mins)
    popt_str = "( " + ", ".join(f"{prm:.4f}" for prm in ps[idx_opt]) + " )"
    print(f"optimal:, {popt_str}, {mins[idx_opt]:.6f}")

    # Define a `Medium` class object using the optimal fitting parameters.
    E_susceptibilities = []

    for n in range(num_lorentzians):
        mymaterial_freq, mymaterial_gamma = ps[idx_opt][3 * n + 1:3 * n + 3]

        if mymaterial_freq == 0:
            mymaterial_sigma = ps[idx_opt][3 * n + 0]
            E_susceptibilities.append(
                mp.DrudeSusceptibility(
                    frequency=1.0, gamma=mymaterial_gamma, sigma=mymaterial_sigma
                )
            )
        else:
            mymaterial_sigma = ps[idx_opt][3 * n + 0] / mymaterial_freq**2
            E_susceptibilities.append(
                mp.LorentzianSusceptibility(
                    frequency=mymaterial_freq,
                    gamma=mymaterial_gamma,
                    sigma=mymaterial_sigma,
                )
            )

    Au = mp.Medium(epsilon=eps_inf, E_susceptibilities=E_susceptibilities)
# Out:
# iteration:,   0, ps_str, 148.081582
# iteration:,   1, ps_str, 787.690920
# iteration:,   2, ps_str, 13043.499609
# iteration:,   3, ps_str, 13044.553836
# iteration:,   4, ps_str, 13047.165209
# iteration:,   5, ps_str, 301.160229
# iteration:,   6, ps_str, 13046.432877
# iteration:,   7, ps_str, 148.081582
# iteration:,   8, ps_str, 13044.815111
# iteration:,   9, ps_str, 1282.154918
# iteration:,  10, ps_str, 148.081582
# iteration:,  11, ps_str, 13051.469910
# iteration:,  12, ps_str, 148.081582
# iteration:,  13, ps_str, 148.081582
# iteration:,  14, ps_str, 515.197800
# iteration:,  15, ps_str, 514.117069
# iteration:,  16, ps_str, 13043.436354
# iteration:,  17, ps_str, 148.081582
# iteration:,  18, ps_str, 13045.781363
# iteration:,  19, ps_str, 148.081582
# iteration:,  20, ps_str, 13045.218465
# iteration:,  21, ps_str, 148.081582
# iteration:,  22, ps_str, 13043.988006
# iteration:,  23, ps_str, 148.081582
# iteration:,  24, ps_str, 1282.155879
# iteration:,  25, ps_str, 148.081582
# iteration:,  26, ps_str, 514.056244
# iteration:,  27, ps_str, 1282.177462
# iteration:,  28, ps_str, 512.614118
# iteration:,  29, ps_str, 13046.454186
# optimal:, ( 71.5169, 3.6554, 2.7409, 40.4727, -0.5242, 0.0183 ), 148.081582

# %%
#Nanorod scattering spectrum
#AR Constant

import meep as mp
import numpy as np
import matplotlib.pyplot as plt



def get_spectrum_nanorod(fraction, wvl_min, wvl_max):

    r = 7.25E-3  # radius of cylinder
    l = 25.40E-3 # length of rod
    
    frac = fraction
    l_c = frac*l # length of cylinder
    
    l_e = 0.5*(l-l_c) # length of half ellipsoid
    
    #default medium is water
    default_material = mp.Medium(index=1.3325)
    
    frq_min = 1 / wvl_max
    frq_max = 1 / wvl_min
    frq_cen = 0.5 * (frq_min + frq_max)
    dfrq = frq_max - frq_min
    nfrq = 100
    
    resolution = 10/r
    
    dpml = 2*r
    pml_layers = [mp.PML(thickness=dpml)]
    
    symmetries = [mp.Mirror(mp.Y), mp.Mirror(mp.Z, phase=-1)]
    
    s = 3*l + dpml
    cell_size = mp.Vector3(s, s, s)
    
    # is_integrated=True necessary for any planewave source extending into PML
    sources = [
        mp.Source(
            mp.GaussianSource(frq_cen, fwidth=dfrq, is_integrated=True),
            center=mp.Vector3(-0.5*s + dpml),
            size=mp.Vector3(0, s, s),
            component=mp.Ez,
        )
    ]
    
    
    sim = mp.Simulation(
        resolution=resolution,
        cell_size=cell_size,
        boundary_layers=pml_layers,
        default_material = default_material,
        sources=sources,
        k_point=mp.Vector3(),
        symmetries=symmetries
    )
    
    
    
    box_x1 = sim.add_flux(
        frq_cen,
        dfrq,
        nfrq,
        mp.FluxRegion(center=mp.Vector3(x=-0.5*l), size=mp.Vector3(0, l, l)),
    )
    
    box_x2 = sim.add_flux(
        frq_cen,
        dfrq,
        nfrq,
        mp.FluxRegion(center=mp.Vector3(x=+0.5*l), size=mp.Vector3(0, l, l)),
    )
    
    box_y1 = sim.add_flux(
        frq_cen,
        dfrq,
        nfrq,
        mp.FluxRegion(center=mp.Vector3(y= -0.5*l), size=mp.Vector3(l, 0, l)),
    )
    
    box_y2 = sim.add_flux(
        frq_cen,
        dfrq,
        nfrq,
        mp.FluxRegion(center=mp.Vector3(y= 0.5*l), size=mp.Vector3(l, 0, l)),
    )
    
    box_z1 = sim.add_flux(
        frq_cen,
        dfrq,
        nfrq,
        mp.FluxRegion(center=mp.Vector3(x=-0.5*l), size=mp.Vector3(l, l, 0)),
    )
    
    box_z2 = sim.add_flux(
        frq_cen,
        dfrq,
        nfrq,
        mp.FluxRegion(center=mp.Vector3(x=+0.5*l), size=mp.Vector3(l, l, 0)),
    )
    
    sim.run(until_after_sources=10)
    
    freqs = mp.get_flux_freqs(box_x1)
    box_x1_data = sim.get_flux_data(box_x1)
    box_x2_data = sim.get_flux_data(box_x2)
    box_y1_data = sim.get_flux_data(box_y1)
    box_y2_data = sim.get_flux_data(box_y2)
    box_z1_data = sim.get_flux_data(box_z1)
    box_z2_data = sim.get_flux_data(box_z2)
    
    box_x1_flux0 = mp.get_fluxes(box_x1)
    
    sim.reset_meep()



    

    ellip_1 = mp.Ellipsoid(material=Au,
                           size = mp.Vector3(2*r, 2*l_e, 2*r),
                           center=mp.Vector3(0, 0.5*l_c, 0))
    
    ellip_2 = mp.Ellipsoid(material=Au,
                           size = mp.Vector3(2*r, 2*l_e, 2*r),
                           center=mp.Vector3(0, -0.5*l_c, 0))
    
    #axis says the orentation of the cylinder
    cylinder = mp.Cylinder(material=Au,
                           radius=r,
                           height=l_c,
                           center=mp.Vector3(),
                           axis=mp.Vector3(0, 1, 0))
    
    geometry = [ellip_1, ellip_2, cylinder]
    
    sim = mp.Simulation(
        resolution=resolution,
        cell_size=cell_size,
        boundary_layers=pml_layers,
        default_material = default_material,
        sources=sources,
        k_point=mp.Vector3(),
        symmetries=symmetries,
        geometry=geometry,
    )
    
    
    
    box_x1 = sim.add_flux(
        frq_cen,
        dfrq,
        nfrq,
        mp.FluxRegion(center=mp.Vector3(x=-0.5*l), size=mp.Vector3(0, l, l)),
    )
    
    box_x2 = sim.add_flux(
        frq_cen,
        dfrq,
        nfrq,
        mp.FluxRegion(center=mp.Vector3(x=+0.5*l), size=mp.Vector3(0, l, l)),
    )
    
    box_y1 = sim.add_flux(
        frq_cen,
        dfrq,
        nfrq,
        mp.FluxRegion(center=mp.Vector3(y= -0.5*l), size=mp.Vector3(l, 0, l)),
    )
    
    box_y2 = sim.add_flux(
        frq_cen,
        dfrq,
        nfrq,
        mp.FluxRegion(center=mp.Vector3(y= 0.5*l), size=mp.Vector3(l, 0, l)),
    )
    
    box_z1 = sim.add_flux(
        frq_cen,
        dfrq,
        nfrq,
        mp.FluxRegion(center=mp.Vector3(x=-0.5*l), size=mp.Vector3(l, l, 0)),
    )
    
    box_z2 = sim.add_flux(
        frq_cen,
        dfrq,
        nfrq,
        mp.FluxRegion(center=mp.Vector3(x=+0.5*l), size=mp.Vector3(l, l, 0)),
    )
    
    
    
    sim.load_minus_flux_data(box_x1, box_x1_data)
    sim.load_minus_flux_data(box_x2, box_x2_data)
    sim.load_minus_flux_data(box_y1, box_y1_data)
    sim.load_minus_flux_data(box_y2, box_y2_data)
    sim.load_minus_flux_data(box_z1, box_z1_data)
    sim.load_minus_flux_data(box_z2, box_z2_data)
    
    sim.run(until_after_sources=100)
    
    #flux power through each flux region.
    box_x1_flux = mp.get_fluxes(box_x1)
    box_x2_flux = mp.get_fluxes(box_x2)
    box_y1_flux = mp.get_fluxes(box_y1)
    box_y2_flux = mp.get_fluxes(box_y2)
    box_z1_flux = mp.get_fluxes(box_z1)
    box_z2_flux = mp.get_fluxes(box_z2)
    
    
    #Just want to plot the power of the scattered flux against wavelength
    scatt_flux = (
        np.asarray(box_x1_flux)
        - np.asarray(box_x2_flux)
        + np.asarray(box_y1_flux)
        - np.asarray(box_y2_flux)
        + np.asarray(box_z1_flux)
        - np.asarray(box_z2_flux)
    )

    perc = str(frac*100)
    
    return scatt_flux, freqs, perc
    #return the scattered flux power data and the range of frequencies

# %%
wvl_min = 400E-3
wvl_max = 1000E-3

freq_data = []  #Going to append all raw sim data arrays, to process and plot after the runs
scatt_data = []
percentages = []

fractions = np.linspace(1,0,20)

index = 1

for fraction in fractions:
    print(f"##################### Run {index} Starting #######################")
    scatt_flux, freqs, perc = get_spectrum_nanorod(fraction, wvl_min, wvl_max)
    scatt_data.append(scatt_flux)     #this appends the array as a row.
    freq_data.append(freqs)
    percentages = np.append(percentages, perc)

    index+=1
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# ##################### Run 1 Starting #######################
# -----------
# Initializing structure...
# Padding y to even number of grid points.
# Padding z to even number of grid points.
# Halving computational cell along direction y
# Halving computational cell along direction z
# time for choose_chunkdivision = 0.00427318 s
# Working in 3D dimensions.
# Computational cell is 0.090625 x 0.090625 x 0.090625 with resolution 1379.31
# time for set_epsilon = 1.05983 s
# -----------
# Meep progress: 0.05292500000000001/16.666666507720947 = 0.3% done in 4.0s, 1256.7s to go
# on time step 146 (time=0.052925), 0.027421 s/step
# Meep progress: 0.13666250000000002/16.666666507720947 = 0.8% done in 8.0s, 969.9s to go
# on time step 377 (time=0.136663), 0.0173807 s/step
# Meep progress: 0.2204/16.666666507720947 = 1.3% done in 12.0s, 897.1s to go
# on time step 608 (time=0.2204), 0.0173305 s/step
# Meep progress: 0.3026875/16.666666507720947 = 1.8% done in 16.0s, 866.9s to go
# on time step 835 (time=0.302687), 0.01767 s/step
# Meep progress: 0.38715000000000005/16.666666507720947 = 2.3% done in 20.0s, 842.7s to go
# on time step 1068 (time=0.38715), 0.0171896 s/step
# Meep progress: 0.47197500000000003/16.666666507720947 = 2.8% done in 24.1s, 825.4s to go
# on time step 1302 (time=0.471975), 0.0171589 s/step
# Meep progress: 0.5571625/16.666666507720947 = 3.3% done in 28.1s, 811.6s to go
# on time step 1537 (time=0.557163), 0.0170793 s/step
# Meep progress: 0.6423500000000001/16.666666507720947 = 3.9% done in 32.1s, 800.1s to go
# on time step 1772 (time=0.64235), 0.0170219 s/step
# Meep progress: 0.7268125000000001/16.666666507720947 = 4.4% done in 36.1s, 791.1s to go
# on time step 2005 (time=0.726813), 0.0171698 s/step
# Meep progress: 0.8112750000000001/16.666666507720947 = 4.9% done in 40.1s, 783.2s to go
# on time step 2238 (time=0.811275), 0.017173 s/step
# Meep progress: 0.8957375000000001/16.666666507720947 = 5.4% done in 44.1s, 776.2s to go
# on time step 2471 (time=0.895738), 0.0172107 s/step
# Meep progress: 0.9802000000000001/16.666666507720947 = 5.9% done in 48.1s, 769.6s to go
# on time step 2704 (time=0.9802), 0.0171823 s/step
# Meep progress: 1.0643/16.666666507720947 = 6.4% done in 52.1s, 763.6s to go
# on time step 2937 (time=1.06466), 0.0172417 s/step
# Meep progress: 1.1473125000000002/16.666666507720947 = 6.9% done in 56.1s, 758.8s to go
# on time step 3166 (time=1.14768), 0.0174713 s/step
# Meep progress: 1.231775/16.666666507720947 = 7.4% done in 60.1s, 753.1s to go
# on time step 3399 (time=1.23214), 0.0171935 s/step
# Meep progress: 1.3166000000000002/16.666666507720947 = 7.9% done in 64.1s, 747.4s to go
# on time step 3633 (time=1.31696), 0.0171193 s/step
# Meep progress: 1.4014250000000001/16.666666507720947 = 8.4% done in 68.1s, 741.9s to go
# on time step 3867 (time=1.40179), 0.0171214 s/step
# Meep progress: 1.4858875/16.666666507720947 = 8.9% done in 72.1s, 736.8s to go
# on time step 4100 (time=1.48625), 0.0171808 s/step
# Meep progress: 1.5707125000000002/16.666666507720947 = 9.4% done in 76.1s, 731.7s to go
# on time step 4334 (time=1.57108), 0.0171364 s/step
# Meep progress: 1.6548125000000002/16.666666507720947 = 9.9% done in 80.1s, 726.9s to go
# on time step 4566 (time=1.65518), 0.0172541 s/step
# Meep progress: 1.7374625000000001/16.666666507720947 = 10.4% done in 84.1s, 723.0s to go
# on time step 4794 (time=1.73783), 0.0175934 s/step
# Meep progress: 1.8201125000000002/16.666666507720947 = 10.9% done in 88.2s, 719.1s to go
# on time step 5022 (time=1.82048), 0.0175848 s/step
# Meep progress: 1.9013125000000002/16.666666507720947 = 11.4% done in 92.2s, 715.8s to go
# on time step 5246 (time=1.90168), 0.0179191 s/step
# Meep progress: 1.9828750000000002/16.666666507720947 = 11.9% done in 96.2s, 712.2s to go
# on time step 5471 (time=1.98324), 0.017829 s/step
# Meep progress: 2.0644375000000004/16.666666507720947 = 12.4% done in 100.2s, 708.6s to go
# on time step 5696 (time=2.0648), 0.0178156 s/step
# Meep progress: 2.1460000000000004/16.666666507720947 = 12.9% done in 104.2s, 705.0s to go
# on time step 5922 (time=2.14672), 0.017775 s/step
# Meep progress: 2.22865/16.666666507720947 = 13.4% done in 108.2s, 701.0s to go
# on time step 6150 (time=2.22938), 0.017599 s/step
# Meep progress: 2.3102125/16.666666507720947 = 13.9% done in 112.2s, 697.4s to go
# on time step 6375 (time=2.31094), 0.0178488 s/step
# Meep progress: 2.391775/16.666666507720947 = 14.4% done in 116.2s, 693.7s to go
# on time step 6600 (time=2.3925), 0.0178329 s/step
# Meep progress: 2.471525/16.666666507720947 = 14.8% done in 120.2s, 690.6s to go
# on time step 6820 (time=2.47225), 0.0182401 s/step
# Meep progress: 2.55345/16.666666507720947 = 15.3% done in 124.3s, 686.8s to go
# on time step 7046 (time=2.55418), 0.0177656 s/step
# Meep progress: 2.6364625000000004/16.666666507720947 = 15.8% done in 128.3s, 682.6s to go
# on time step 7275 (time=2.63719), 0.0174751 s/step
# Meep progress: 2.6980875/16.666666507720947 = 16.2% done in 132.3s, 684.8s to go
# on time step 7445 (time=2.69881), 0.0236175 s/step
# Meep progress: 2.7705875000000004/16.666666507720947 = 16.6% done in 136.3s, 683.6s to go
# on time step 7645 (time=2.77131), 0.020097 s/step
# Meep progress: 2.8449000000000004/16.666666507720947 = 17.1% done in 140.3s, 681.7s to go
# on time step 7850 (time=2.84563), 0.0195331 s/step
# Meep progress: 2.9257375000000003/16.666666507720947 = 17.6% done in 144.3s, 677.8s to go
# on time step 8073 (time=2.92646), 0.0179871 s/step
# Meep progress: 3.0047625000000004/16.666666507720947 = 18.0% done in 148.3s, 674.4s to go
# on time step 8291 (time=3.00549), 0.0183495 s/step
# Meep progress: 3.08705/16.666666507720947 = 18.5% done in 152.3s, 670.1s to go
# on time step 8518 (time=3.08778), 0.0176657 s/step
# Meep progress: 3.1664375000000002/16.666666507720947 = 19.0% done in 156.3s, 666.6s to go
# on time step 8737 (time=3.16716), 0.0183072 s/step
# Meep progress: 3.2494500000000004/16.666666507720947 = 19.5% done in 160.4s, 662.1s to go
# on time step 8966 (time=3.25018), 0.0175184 s/step
# Meep progress: 3.3317375000000005/16.666666507720947 = 20.0% done in 164.4s, 657.8s to go
# on time step 9193 (time=3.33246), 0.017657 s/step
# Meep progress: 3.41475/16.666666507720947 = 20.5% done in 168.4s, 653.4s to go
# on time step 9422 (time=3.41548), 0.0174807 s/step
# Meep progress: 3.4974000000000003/16.666666507720947 = 21.0% done in 172.4s, 649.1s to go
# on time step 9650 (time=3.49813), 0.0176148 s/step
# Meep progress: 3.5796875000000004/16.666666507720947 = 21.5% done in 176.4s, 644.9s to go
# on time step 9877 (time=3.58041), 0.0176405 s/step
# Meep progress: 3.6627000000000005/16.666666507720947 = 22.0% done in 180.4s, 640.5s to go
# on time step 10106 (time=3.66343), 0.0174693 s/step
# Meep progress: 3.741725/16.666666507720947 = 22.5% done in 184.4s, 636.9s to go
# on time step 10324 (time=3.74245), 0.0184032 s/step
# Meep progress: 3.8240125000000003/16.666666507720947 = 22.9% done in 188.4s, 632.7s to go
# on time step 10552 (time=3.8251), 0.0175936 s/step
# Meep progress: 3.9073875000000005/16.666666507720947 = 23.4% done in 192.4s, 628.3s to go
# on time step 10782 (time=3.90848), 0.0174416 s/step
# Meep progress: 3.9900375/16.666666507720947 = 23.9% done in 196.4s, 624.0s to go
# on time step 11010 (time=3.99113), 0.0175865 s/step
# Meep progress: 4.072325/16.666666507720947 = 24.4% done in 200.4s, 619.9s to go
# on time step 11237 (time=4.07341), 0.017646 s/step
# Meep progress: 4.154975/16.666666507720947 = 24.9% done in 204.4s, 615.6s to go
# on time step 11465 (time=4.15606), 0.0175681 s/step
# Meep progress: 4.2372625/16.666666507720947 = 25.4% done in 208.4s, 611.4s to go
# on time step 11692 (time=4.23835), 0.0176349 s/step
# Meep progress: 4.3195500000000004/16.666666507720947 = 25.9% done in 212.4s, 607.3s to go
# on time step 11919 (time=4.32064), 0.0176647 s/step
# Meep progress: 4.4018375/16.666666507720947 = 26.4% done in 216.5s, 603.1s to go
# on time step 12146 (time=4.40293), 0.0176546 s/step
# Meep progress: 4.484125000000001/16.666666507720947 = 26.9% done in 220.5s, 598.9s to go
# on time step 12374 (time=4.48558), 0.0176098 s/step
# Meep progress: 4.5671375/16.666666507720947 = 27.4% done in 224.5s, 594.7s to go
# on time step 12603 (time=4.56859), 0.017524 s/step
# Meep progress: 4.65015/16.666666507720947 = 27.9% done in 228.5s, 590.4s to go
# on time step 12832 (time=4.6516), 0.017515 s/step
# Meep progress: 4.7317125/16.666666507720947 = 28.4% done in 232.5s, 586.4s to go
# on time step 13057 (time=4.73316), 0.0177988 s/step
# Meep progress: 4.813275/16.666666507720947 = 28.9% done in 236.5s, 582.4s to go
# on time step 13282 (time=4.81473), 0.0177802 s/step
# Meep progress: 4.895925/16.666666507720947 = 29.4% done in 240.5s, 578.2s to go
# on time step 13510 (time=4.89738), 0.0176128 s/step
# Meep progress: 4.9774875000000005/16.666666507720947 = 29.9% done in 244.5s, 574.2s to go
# on time step 13735 (time=4.97894), 0.0178147 s/step
# Meep progress: 5.059775/16.666666507720947 = 30.4% done in 248.5s, 570.1s to go
# on time step 13962 (time=5.06123), 0.0176842 s/step
# Meep progress: 5.142062500000001/16.666666507720947 = 30.9% done in 252.5s, 566.0s to go
# on time step 14189 (time=5.14351), 0.0176886 s/step
# Meep progress: 5.225075/16.666666507720947 = 31.4% done in 256.5s, 561.8s to go
# on time step 14418 (time=5.22653), 0.0174806 s/step
# Meep progress: 5.3077250000000005/16.666666507720947 = 31.8% done in 260.6s, 557.6s to go
# on time step 14646 (time=5.30918), 0.0175945 s/step
# Meep progress: 5.390375000000001/16.666666507720947 = 32.3% done in 264.6s, 553.5s to go
# on time step 14874 (time=5.39183), 0.0176064 s/step
# Meep progress: 5.473750000000001/16.666666507720947 = 32.8% done in 268.6s, 549.2s to go
# on time step 15104 (time=5.4752), 0.0174507 s/step
# Meep progress: 5.5564/16.666666507720947 = 33.3% done in 272.6s, 545.1s to go
# on time step 15332 (time=5.55785), 0.0176133 s/step
# Meep progress: 5.6350625/16.666666507720947 = 33.8% done in 276.6s, 541.5s to go
# on time step 15549 (time=5.63651), 0.0184378 s/step
# Meep progress: 5.718075000000001/16.666666507720947 = 34.3% done in 280.6s, 537.3s to go
# on time step 15778 (time=5.71953), 0.017505 s/step
# Meep progress: 5.8003625/16.666666507720947 = 34.8% done in 284.6s, 533.2s to go
# on time step 16005 (time=5.80181), 0.0176633 s/step
# Meep progress: 5.877937500000001/16.666666507720947 = 35.3% done in 288.6s, 529.8s to go
# on time step 16219 (time=5.87939), 0.0187579 s/step
# Meep progress: 5.960225/16.666666507720947 = 35.8% done in 292.7s, 525.7s to go
# on time step 16446 (time=5.96168), 0.0176672 s/step
# Meep progress: 6.042512500000001/16.666666507720947 = 36.3% done in 296.7s, 521.6s to go
# on time step 16673 (time=6.04396), 0.0176959 s/step
# Meep progress: 6.1251625/16.666666507720947 = 36.8% done in 300.7s, 517.5s to go
# on time step 16901 (time=6.12661), 0.0175681 s/step
# Meep progress: 6.200925000000001/16.666666507720947 = 37.2% done in 304.7s, 514.3s to go
# on time step 17110 (time=6.20238), 0.0192036 s/step
# Meep progress: 6.281037500000001/16.666666507720947 = 37.7% done in 308.7s, 510.5s to go
# on time step 17331 (time=6.28249), 0.018173 s/step
# Meep progress: 6.3658625/16.666666507720947 = 38.2% done in 312.7s, 506.0s to go
# on time step 17564 (time=6.36695), 0.0171706 s/step
# Meep progress: 6.453225000000001/16.666666507720947 = 38.7% done in 316.7s, 501.3s to go
# on time step 17805 (time=6.45431), 0.0166028 s/step
# Meep progress: 6.537325000000001/16.666666507720947 = 39.2% done in 320.7s, 497.0s to go
# on time step 18037 (time=6.53841), 0.0172938 s/step
# Meep progress: 6.621787500000001/16.666666507720947 = 39.7% done in 324.8s, 492.6s to go
# on time step 18270 (time=6.62288), 0.01721 s/step
# Meep progress: 6.7124125/16.666666507720947 = 40.3% done in 328.8s, 487.5s to go
# on time step 18521 (time=6.71386), 0.015993 s/step
# Meep progress: 6.807387500000001/16.666666507720947 = 40.8% done in 332.8s, 482.0s to go
# on time step 18783 (time=6.80884), 0.0152925 s/step
# Meep progress: 6.901275000000001/16.666666507720947 = 41.4% done in 336.8s, 476.6s to go
# on time step 19042 (time=6.90273), 0.0154861 s/step
# Meep progress: 6.994437500000001/16.666666507720947 = 42.0% done in 340.8s, 471.3s to go
# on time step 19299 (time=6.99589), 0.0155898 s/step
# Meep progress: 7.087600000000001/16.666666507720947 = 42.5% done in 344.8s, 466.0s to go
# on time step 19556 (time=7.08905), 0.0155828 s/step
# Meep progress: 7.1796750000000005/16.666666507720947 = 43.1% done in 348.8s, 460.9s to go
# on time step 19810 (time=7.18113), 0.0157923 s/step
# Meep progress: 7.2728375000000005/16.666666507720947 = 43.6% done in 352.8s, 455.7s to go
# on time step 20068 (time=7.27465), 0.0155567 s/step
# Meep progress: 7.362375000000001/16.666666507720947 = 44.2% done in 356.8s, 450.9s to go
# on time step 20314 (time=7.36383), 0.0162761 s/step
# Meep progress: 7.442125000000001/16.666666507720947 = 44.7% done in 360.8s, 447.2s to go
# on time step 20535 (time=7.44394), 0.0181759 s/step
# Meep progress: 7.522600000000001/16.666666507720947 = 45.1% done in 364.8s, 443.5s to go
# on time step 20756 (time=7.52405), 0.0181161 s/step
# Meep progress: 7.605250000000001/16.666666507720947 = 45.6% done in 368.8s, 439.5s to go
# on time step 20985 (time=7.60706), 0.0174888 s/step
# Meep progress: 7.6908/16.666666507720947 = 46.1% done in 372.8s, 435.1s to go
# on time step 21220 (time=7.69225), 0.0170322 s/step
# Meep progress: 7.767287500000001/16.666666507720947 = 46.6% done in 376.9s, 431.8s to go
# on time step 21430 (time=7.76838), 0.0191011 s/step
# Meep progress: 7.846675/16.666666507720947 = 47.1% done in 380.9s, 428.1s to go
# on time step 21649 (time=7.84776), 0.018288 s/step
# Meep progress: 7.929325/16.666666507720947 = 47.6% done in 384.9s, 424.1s to go
# on time step 21877 (time=7.93041), 0.0175895 s/step
# Meep progress: 8.012337500000001/16.666666507720947 = 48.1% done in 388.9s, 420.1s to go
# on time step 22106 (time=8.01342), 0.0175189 s/step
# Meep progress: 8.09535/16.666666507720947 = 48.6% done in 392.9s, 416.0s to go
# on time step 22335 (time=8.09644), 0.0175166 s/step
# Meep progress: 8.178725/16.666666507720947 = 49.1% done in 396.9s, 411.9s to go
# on time step 22565 (time=8.17981), 0.0174457 s/step
# Meep progress: 8.2617375/16.666666507720947 = 49.6% done in 400.9s, 407.9s to go
# on time step 22795 (time=8.26319), 0.0174637 s/step
# Meep progress: 8.344750000000001/16.666666507720947 = 50.1% done in 404.9s, 403.8s to go
# on time step 23024 (time=8.3462), 0.0174771 s/step
# Meep progress: 8.4274/16.666666507720947 = 50.6% done in 408.9s, 399.8s to go
# on time step 23252 (time=8.42885), 0.0175619 s/step
# Meep progress: 8.510412500000001/16.666666507720947 = 51.1% done in 413.0s, 395.8s to go
# on time step 23481 (time=8.51186), 0.0175092 s/step
# Meep progress: 8.593787500000001/16.666666507720947 = 51.6% done in 417.0s, 391.7s to go
# on time step 23711 (time=8.59524), 0.0174379 s/step
# Meep progress: 8.6768/16.666666507720947 = 52.1% done in 421.0s, 387.6s to go
# on time step 23940 (time=8.67825), 0.0175059 s/step
# Meep progress: 8.7598125/16.666666507720947 = 52.6% done in 425.0s, 383.6s to go
# on time step 24169 (time=8.76126), 0.017535 s/step
# Meep progress: 8.842825000000001/16.666666507720947 = 53.1% done in 429.0s, 379.6s to go
# on time step 24398 (time=8.84428), 0.0174831 s/step
# Meep progress: 8.926562500000001/16.666666507720947 = 53.6% done in 433.0s, 375.5s to go
# on time step 24629 (time=8.92801), 0.0173472 s/step
# Meep progress: 9.009937500000001/16.666666507720947 = 54.1% done in 437.0s, 371.4s to go
# on time step 24859 (time=9.01139), 0.0174085 s/step
# Meep progress: 9.091862500000001/16.666666507720947 = 54.6% done in 441.0s, 367.4s to go
# on time step 25085 (time=9.09331), 0.0177149 s/step
# Meep progress: 9.173425/16.666666507720947 = 55.0% done in 445.0s, 363.5s to go
# on time step 25310 (time=9.17488), 0.0177983 s/step
# Meep progress: 9.256075000000001/16.666666507720947 = 55.5% done in 449.0s, 359.5s to go
# on time step 25538 (time=9.25753), 0.0176134 s/step
# Meep progress: 9.339450000000001/16.666666507720947 = 56.0% done in 453.1s, 355.4s to go
# on time step 25768 (time=9.3409), 0.0174539 s/step
# Meep progress: 9.4224625/16.666666507720947 = 56.5% done in 457.1s, 351.4s to go
# on time step 25997 (time=9.42391), 0.0175192 s/step
# Meep progress: 9.505112500000001/16.666666507720947 = 57.0% done in 461.1s, 347.4s to go
# on time step 26225 (time=9.50656), 0.0176181 s/step
# Meep progress: 9.5877625/16.666666507720947 = 57.5% done in 465.1s, 343.4s to go
# on time step 26453 (time=9.58921), 0.0175735 s/step
# Meep progress: 9.670412500000001/16.666666507720947 = 58.0% done in 469.1s, 339.4s to go
# on time step 26682 (time=9.67223), 0.0175409 s/step
# Meep progress: 9.750887500000001/16.666666507720947 = 58.5% done in 473.1s, 335.5s to go
# on time step 26904 (time=9.7527), 0.0180372 s/step
# Meep progress: 9.832450000000001/16.666666507720947 = 59.0% done in 477.1s, 331.6s to go
# on time step 27129 (time=9.83426), 0.0178415 s/step
# Meep progress: 9.91365/16.666666507720947 = 59.5% done in 481.1s, 327.7s to go
# on time step 27353 (time=9.91546), 0.0178976 s/step
# Meep progress: 9.994125/16.666666507720947 = 60.0% done in 485.1s, 323.9s to go
# on time step 27575 (time=9.99594), 0.0180362 s/step
# Meep progress: 10.0742375/16.666666507720947 = 60.4% done in 489.1s, 320.1s to go
# on time step 27796 (time=10.0761), 0.0181362 s/step
# Meep progress: 10.1547125/16.666666507720947 = 60.9% done in 493.1s, 316.2s to go
# on time step 28019 (time=10.1569), 0.0180096 s/step
# Meep progress: 10.236275000000001/16.666666507720947 = 61.4% done in 497.1s, 312.3s to go
# on time step 28243 (time=10.2381), 0.0178589 s/step
# Meep progress: 10.3171125/16.666666507720947 = 61.9% done in 501.2s, 308.4s to go
# on time step 28466 (time=10.3189), 0.0179904 s/step
# Meep progress: 10.397950000000002/16.666666507720947 = 62.4% done in 505.2s, 304.6s to go
# on time step 28689 (time=10.3998), 0.0179529 s/step
# Meep progress: 10.47915/16.666666507720947 = 62.9% done in 509.2s, 300.7s to go
# on time step 28913 (time=10.481), 0.0178955 s/step
# Meep progress: 10.560350000000001/16.666666507720947 = 63.4% done in 513.2s, 296.7s to go
# on time step 29137 (time=10.5622), 0.0178738 s/step
# Meep progress: 10.6419125/16.666666507720947 = 63.9% done in 517.2s, 292.8s to go
# on time step 29363 (time=10.6441), 0.0177745 s/step
# Meep progress: 10.722025/16.666666507720947 = 64.3% done in 521.2s, 289.0s to go
# on time step 29584 (time=10.7242), 0.0181228 s/step
# Meep progress: 10.804675000000001/16.666666507720947 = 64.8% done in 525.2s, 284.9s to go
# on time step 29812 (time=10.8069), 0.0175622 s/step
# Meep progress: 10.885150000000001/16.666666507720947 = 65.3% done in 529.2s, 281.1s to go
# on time step 30033 (time=10.887), 0.0181203 s/step
# Meep progress: 10.966712500000002/16.666666507720947 = 65.8% done in 533.2s, 277.1s to go
# on time step 30258 (time=10.9685), 0.017822 s/step
# Meep progress: 11.047550000000001/16.666666507720947 = 66.3% done in 537.2s, 273.3s to go
# on time step 30481 (time=11.0494), 0.0179882 s/step
# Meep progress: 11.129112500000002/16.666666507720947 = 66.8% done in 541.2s, 269.3s to go
# on time step 30706 (time=11.1309), 0.0177944 s/step
# Meep progress: 11.210675/16.666666507720947 = 67.3% done in 545.2s, 265.4s to go
# on time step 30931 (time=11.2125), 0.0177808 s/step
# Meep progress: 11.284625/16.666666507720947 = 67.7% done in 549.3s, 262.0s to go
# on time step 31134 (time=11.2861), 0.0197711 s/step
# Meep progress: 11.361475/16.666666507720947 = 68.2% done in 553.3s, 258.4s to go
# on time step 31346 (time=11.3629), 0.0188719 s/step
# Meep progress: 11.4430375/16.666666507720947 = 68.7% done in 557.3s, 254.4s to go
# on time step 31571 (time=11.4445), 0.0178146 s/step
# Meep progress: 11.5249625/16.666666507720947 = 69.1% done in 561.3s, 250.4s to go
# on time step 31797 (time=11.5264), 0.0177156 s/step
# Meep progress: 11.6058/16.666666507720947 = 69.6% done in 565.3s, 246.5s to go
# on time step 32020 (time=11.6073), 0.0179513 s/step
# Meep progress: 11.687725/16.666666507720947 = 70.1% done in 569.3s, 242.5s to go
# on time step 32246 (time=11.6892), 0.0177435 s/step
# Meep progress: 11.7692875/16.666666507720947 = 70.6% done in 573.3s, 238.6s to go
# on time step 32471 (time=11.7707), 0.0178247 s/step
# Meep progress: 11.850125/16.666666507720947 = 71.1% done in 577.3s, 234.7s to go
# on time step 32694 (time=11.8516), 0.0179933 s/step
# Meep progress: 11.927700000000002/16.666666507720947 = 71.6% done in 581.3s, 231.0s to go
# on time step 32908 (time=11.9292), 0.0187233 s/step
# Meep progress: 12.012887500000001/16.666666507720947 = 72.1% done in 585.4s, 226.8s to go
# on time step 33143 (time=12.0143), 0.0170648 s/step
# Meep progress: 12.1006125/16.666666507720947 = 72.6% done in 589.4s, 222.4s to go
# on time step 33385 (time=12.1021), 0.0165571 s/step
# Meep progress: 12.175650000000001/16.666666507720947 = 73.1% done in 593.4s, 218.9s to go
# on time step 33589 (time=12.176), 0.0196185 s/step
# Meep progress: 12.249237500000001/16.666666507720947 = 73.5% done in 597.4s, 215.4s to go
# on time step 33793 (time=12.25), 0.0197352 s/step
# Meep progress: 12.317025000000001/16.666666507720947 = 73.9% done in 601.4s, 212.4s to go
# on time step 33980 (time=12.3178), 0.0213928 s/step
# Meep progress: 12.395687500000001/16.666666507720947 = 74.4% done in 605.4s, 208.6s to go
# on time step 34197 (time=12.3964), 0.0184709 s/step
# Meep progress: 12.477250000000002/16.666666507720947 = 74.9% done in 609.4s, 204.6s to go
# on time step 34422 (time=12.478), 0.0178191 s/step
# Meep progress: 12.5599/16.666666507720947 = 75.4% done in 613.5s, 200.6s to go
# on time step 34650 (time=12.5606), 0.0175835 s/step
# Meep progress: 12.642550000000002/16.666666507720947 = 75.9% done in 617.5s, 196.5s to go
# on time step 34878 (time=12.6433), 0.0176248 s/step
# Meep progress: 12.7223/16.666666507720947 = 76.3% done in 621.5s, 192.7s to go
# on time step 35098 (time=12.723), 0.0182143 s/step
# Meep progress: 12.805675/16.666666507720947 = 76.8% done in 625.5s, 188.6s to go
# on time step 35328 (time=12.8064), 0.0174415 s/step
# Meep progress: 12.889050000000001/16.666666507720947 = 77.3% done in 629.5s, 184.5s to go
# on time step 35558 (time=12.8898), 0.0174474 s/step
# Meep progress: 12.9713375/16.666666507720947 = 77.8% done in 633.5s, 180.5s to go
# on time step 35785 (time=12.9721), 0.0176659 s/step
# Meep progress: 13.052900000000001/16.666666507720947 = 78.3% done in 637.5s, 176.5s to go
# on time step 36010 (time=13.0536), 0.0178188 s/step
# Meep progress: 13.13555/16.666666507720947 = 78.8% done in 641.5s, 172.5s to go
# on time step 36239 (time=13.1366), 0.017532 s/step
# Meep progress: 13.218200000000001/16.666666507720947 = 79.3% done in 645.5s, 168.4s to go
# on time step 36468 (time=13.2197), 0.0175382 s/step
# Meep progress: 13.301212500000002/16.666666507720947 = 79.8% done in 649.5s, 164.3s to go
# on time step 36698 (time=13.303), 0.0174729 s/step
# Meep progress: 13.384225/16.666666507720947 = 80.3% done in 653.5s, 160.3s to go
# on time step 36927 (time=13.386), 0.0175108 s/step
# Meep progress: 13.467237500000001/16.666666507720947 = 80.8% done in 657.5s, 156.2s to go
# on time step 37157 (time=13.4694), 0.0174539 s/step
# Meep progress: 13.549525000000001/16.666666507720947 = 81.3% done in 661.6s, 152.2s to go
# on time step 37384 (time=13.5517), 0.017675 s/step
# Meep progress: 13.631087500000001/16.666666507720947 = 81.8% done in 665.6s, 148.2s to go
# on time step 37609 (time=13.6333), 0.0178319 s/step
# Meep progress: 13.713012500000001/16.666666507720947 = 82.3% done in 669.6s, 144.2s to go
# on time step 37834 (time=13.7148), 0.0177833 s/step
# Meep progress: 13.796025000000002/16.666666507720947 = 82.8% done in 673.6s, 140.2s to go
# on time step 38063 (time=13.7978), 0.0174993 s/step
# Meep progress: 13.8794/16.666666507720947 = 83.3% done in 677.6s, 136.1s to go
# on time step 38293 (time=13.8812), 0.0174294 s/step
# Meep progress: 13.962775/16.666666507720947 = 83.8% done in 681.6s, 132.0s to go
# on time step 38523 (time=13.9646), 0.0174481 s/step
# Meep progress: 14.045787500000001/16.666666507720947 = 84.3% done in 685.6s, 127.9s to go
# on time step 38751 (time=14.0472), 0.0175499 s/step
# Meep progress: 14.1284375/16.666666507720947 = 84.8% done in 689.6s, 123.9s to go
# on time step 38980 (time=14.1303), 0.0175212 s/step
# Meep progress: 14.210725000000002/16.666666507720947 = 85.3% done in 693.6s, 119.9s to go
# on time step 39207 (time=14.2125), 0.017646 s/step
# Meep progress: 14.291925/16.666666507720947 = 85.8% done in 697.7s, 115.9s to go
# on time step 39431 (time=14.2937), 0.0179281 s/step
# Meep progress: 14.3724/16.666666507720947 = 86.2% done in 701.7s, 112.0s to go
# on time step 39653 (time=14.3742), 0.018069 s/step
# Meep progress: 14.4510625/16.666666507720947 = 86.7% done in 705.7s, 108.2s to go
# on time step 39870 (time=14.4529), 0.0184378 s/step
# Meep progress: 14.531175000000001/16.666666507720947 = 87.2% done in 709.7s, 104.3s to go
# on time step 40091 (time=14.533), 0.018105 s/step
# Meep progress: 14.608025000000001/16.666666507720947 = 87.6% done in 713.7s, 100.6s to go
# on time step 40303 (time=14.6098), 0.0189234 s/step
# Meep progress: 14.6827/16.666666507720947 = 88.1% done in 717.7s, 97.0s to go
# on time step 40509 (time=14.6845), 0.0194451 s/step
# Meep progress: 14.763537500000002/16.666666507720947 = 88.6% done in 721.7s, 93.0s to go
# on time step 40732 (time=14.7654), 0.0179423 s/step
# Meep progress: 14.844012500000002/16.666666507720947 = 89.1% done in 725.7s, 89.1s to go
# on time step 40954 (time=14.8458), 0.0180255 s/step
# Meep progress: 14.9237625/16.666666507720947 = 89.5% done in 729.7s, 85.2s to go
# on time step 41174 (time=14.9256), 0.0182212 s/step
# Meep progress: 15.003512500000001/16.666666507720947 = 90.0% done in 733.7s, 81.3s to go
# on time step 41394 (time=15.0053), 0.018257 s/step
# Meep progress: 15.083987500000001/16.666666507720947 = 90.5% done in 737.7s, 77.4s to go
# on time step 41616 (time=15.0858), 0.0180815 s/step
# Meep progress: 15.164825/16.666666507720947 = 91.0% done in 741.7s, 73.5s to go
# on time step 41839 (time=15.1666), 0.0179791 s/step
# Meep progress: 15.245300000000002/16.666666507720947 = 91.5% done in 745.8s, 69.5s to go
# on time step 42061 (time=15.2471), 0.0180644 s/step
# Meep progress: 15.327225000000002/16.666666507720947 = 92.0% done in 749.8s, 65.5s to go
# on time step 42287 (time=15.329), 0.0177649 s/step
# Meep progress: 15.4087875/16.666666507720947 = 92.5% done in 753.8s, 61.5s to go
# on time step 42512 (time=15.4106), 0.0178101 s/step
# Meep progress: 15.4907125/16.666666507720947 = 92.9% done in 757.8s, 57.5s to go
# on time step 42738 (time=15.4925), 0.017742 s/step
# Meep progress: 15.572275000000001/16.666666507720947 = 93.4% done in 761.8s, 53.5s to go
# on time step 42963 (time=15.5741), 0.0177999 s/step
# Meep progress: 15.653837500000002/16.666666507720947 = 93.9% done in 765.8s, 49.5s to go
# on time step 43188 (time=15.6557), 0.0178052 s/step
# Meep progress: 15.735400000000002/16.666666507720947 = 94.4% done in 769.8s, 45.6s to go
# on time step 43413 (time=15.7372), 0.017809 s/step
# Meep progress: 15.818050000000001/16.666666507720947 = 94.9% done in 773.8s, 41.5s to go
# on time step 43641 (time=15.8199), 0.0175652 s/step
# Meep progress: 15.899975000000001/16.666666507720947 = 95.4% done in 777.8s, 37.5s to go
# on time step 43867 (time=15.9018), 0.017725 s/step
# Meep progress: 15.981537500000002/16.666666507720947 = 95.9% done in 781.8s, 33.5s to go
# on time step 44092 (time=15.9834), 0.0178406 s/step
# Meep progress: 16.063100000000002/16.666666507720947 = 96.4% done in 785.8s, 29.5s to go
# on time step 44317 (time=16.0649), 0.0178147 s/step
# Meep progress: 16.1443/16.666666507720947 = 96.9% done in 789.9s, 25.6s to go
# on time step 44541 (time=16.1461), 0.0179073 s/step
# Meep progress: 16.226225000000003/16.666666507720947 = 97.4% done in 793.9s, 21.5s to go
# on time step 44767 (time=16.228), 0.0177462 s/step
# Meep progress: 16.3077875/16.666666507720947 = 97.8% done in 797.9s, 17.6s to go
# on time step 44992 (time=16.3096), 0.0178172 s/step
# Meep progress: 16.3904375/16.666666507720947 = 98.3% done in 801.9s, 13.5s to go
# on time step 45220 (time=16.3923), 0.0175793 s/step
# Meep progress: 16.472/16.666666507720947 = 98.8% done in 805.9s, 9.5s to go
# on time step 45445 (time=16.4738), 0.0178276 s/step
# Meep progress: 16.5474/16.666666507720947 = 99.3% done in 809.9s, 5.8s to go
# on time step 45654 (time=16.5496), 0.0192028 s/step
# Meep progress: 16.6289625/16.666666507720947 = 99.8% done in 813.9s, 1.8s to go
# on time step 45879 (time=16.6311), 0.0178061 s/step
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# run 0 finished at t = 16.667025000000002 (45978 timesteps)
# -----------
# Initializing structure...
# Padding y to even number of grid points.
# Padding z to even number of grid points.
# Halving computational cell along direction y
# Halving computational cell along direction z
# time for choose_chunkdivision = 0.00317717 s
# Working in 3D dimensions.
# Computational cell is 0.090625 x 0.090625 x 0.090625 with resolution 1379.31
#      ellipsoid, center = (0,0.0127,0)
#           size (0.0145,0,0.0145)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2,2,2)
#      ellipsoid, center = (0,-0.0127,0)
#           size (0.0145,0,0.0145)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2,2,2)
#      cylinder, center = (0,0,0)
#           radius 0.00725, height 0.0254, axis (0, 1, 0)
#           dielectric constant epsilon diagonal = (2,2,2)
# time for set_epsilon = 1.16866 s
# time for set_conductivity = 0.018672 s
# time for set_conductivity = 0.0180919 s
# time for set_conductivity = 0.0182459 s
# -----------
# Meep progress: 0.0489375/106.66666650772095 = 0.0% done in 4.0s, 8753.9s to go
# on time step 135 (time=0.0489375), 0.0297643 s/step
# Meep progress: 0.1265125/106.66666650772095 = 0.1% done in 8.0s, 6753.6s to go
# on time step 349 (time=0.126512), 0.0186948 s/step
# Meep progress: 0.2040875/106.66666650772095 = 0.2% done in 12.0s, 6273.0s to go
# on time step 563 (time=0.204088), 0.0187125 s/step
# Meep progress: 0.28166250000000004/106.66666650772095 = 0.3% done in 16.0s, 6053.5s to go
# on time step 777 (time=0.281663), 0.0186974 s/step
# Meep progress: 0.35923750000000004/106.66666650772095 = 0.3% done in 20.0s, 5931.5s to go
# on time step 991 (time=0.359238), 0.0187671 s/step
# Meep progress: 0.43717500000000004/106.66666650772095 = 0.4% done in 24.1s, 5846.0s to go
# on time step 1206 (time=0.437175), 0.0186681 s/step
# Meep progress: 0.51475/106.66666650772095 = 0.5% done in 28.1s, 5788.5s to go
# on time step 1420 (time=0.51475), 0.0187404 s/step
# Meep progress: 0.5923250000000001/106.66666650772095 = 0.6% done in 32.1s, 5744.5s to go
# on time step 1634 (time=0.592325), 0.0187264 s/step
# Meep progress: 0.6699/106.66666650772095 = 0.6% done in 36.1s, 5710.4s to go
# on time step 1848 (time=0.6699), 0.0187451 s/step
# Meep progress: 0.7474750000000001/106.66666650772095 = 0.7% done in 40.1s, 5682.4s to go
# on time step 2062 (time=0.747475), 0.0187408 s/step
# Meep progress: 0.8250500000000001/106.66666650772095 = 0.8% done in 44.1s, 5659.2s to go
# on time step 2276 (time=0.82505), 0.0187505 s/step
# Meep progress: 0.8997250000000001/106.66666650772095 = 0.8% done in 48.1s, 5657.2s to go
# on time step 2482 (time=0.899725), 0.019462 s/step
# Meep progress: 0.9776625000000001/106.66666650772095 = 0.9% done in 52.1s, 5636.6s to go
# on time step 2697 (time=0.977663), 0.0186762 s/step
# Meep progress: 1.0552375/106.66666650772095 = 1.0% done in 56.2s, 5620.5s to go
# on time step 2911 (time=1.05524), 0.0187727 s/step
# Meep progress: 1.1328125/106.66666650772095 = 1.1% done in 60.2s, 5604.8s to go
# on time step 3125 (time=1.13281), 0.0187047 s/step
# Meep progress: 1.21075/106.66666650772095 = 1.1% done in 64.2s, 5589.5s to go
# on time step 3340 (time=1.21075), 0.0186546 s/step
# Meep progress: 1.2883250000000002/106.66666650772095 = 1.2% done in 68.2s, 5577.3s to go
# on time step 3554 (time=1.28833), 0.0187454 s/step
# Meep progress: 1.3662625000000002/106.66666650772095 = 1.3% done in 72.2s, 5563.7s to go
# on time step 3769 (time=1.36626), 0.0186111 s/step
# Meep progress: 1.4438375/106.66666650772095 = 1.4% done in 76.2s, 5553.4s to go
# on time step 3983 (time=1.44384), 0.0187516 s/step
# Meep progress: 1.52105/106.66666650772095 = 1.4% done in 80.2s, 5544.9s to go
# on time step 4196 (time=1.52105), 0.0188284 s/step
# Meep progress: 1.5989875000000002/106.66666650772095 = 1.5% done in 84.2s, 5533.9s to go
# on time step 4411 (time=1.59899), 0.0186227 s/step
# Meep progress: 1.6772875/106.66666650772095 = 1.6% done in 88.2s, 5522.9s to go
# on time step 4627 (time=1.67729), 0.0185829 s/step
# Meep progress: 1.755225/106.66666650772095 = 1.6% done in 92.2s, 5513.4s to go
# on time step 4842 (time=1.75523), 0.0186418 s/step
# Meep progress: 1.8331625000000003/106.66666650772095 = 1.7% done in 96.3s, 5504.5s to go
# on time step 5057 (time=1.83316), 0.0186573 s/step
# Meep progress: 1.9107375000000002/106.66666650772095 = 1.8% done in 100.3s, 5497.0s to go
# on time step 5271 (time=1.91074), 0.0187373 s/step
# Meep progress: 1.9839625/106.66666650772095 = 1.9% done in 104.3s, 5501.5s to go
# on time step 5474 (time=1.98433), 0.0198126 s/step
# Meep progress: 2.05755/106.66666650772095 = 1.9% done in 108.3s, 5505.0s to go
# on time step 5677 (time=2.05791), 0.0197483 s/step
# Meep progress: 2.1351250000000004/106.66666650772095 = 2.0% done in 112.3s, 5497.4s to go
# on time step 5891 (time=2.13549), 0.0187415 s/step
# Meep progress: 2.2127000000000003/106.66666650772095 = 2.1% done in 116.3s, 5490.2s to go
# on time step 6105 (time=2.21306), 0.018746 s/step
# Meep progress: 2.2902750000000003/106.66666650772095 = 2.1% done in 120.3s, 5482.9s to go
# on time step 6319 (time=2.29064), 0.0187225 s/step
# Meep progress: 2.3678500000000002/106.66666650772095 = 2.2% done in 124.3s, 5475.7s to go
# on time step 6533 (time=2.36821), 0.0187035 s/step
# Meep progress: 2.4457875000000002/106.66666650772095 = 2.3% done in 128.3s, 5468.1s to go
# on time step 6748 (time=2.44615), 0.0186426 s/step
# Meep progress: 2.523/106.66666650772095 = 2.4% done in 132.3s, 5462.0s to go
# on time step 6961 (time=2.52336), 0.0187877 s/step
# Meep progress: 2.6013/106.66666650772095 = 2.4% done in 136.3s, 5453.9s to go
# on time step 7177 (time=2.60166), 0.0185499 s/step
# Meep progress: 2.6796/106.66666650772095 = 2.5% done in 140.3s, 5446.1s to go
# on time step 7393 (time=2.67996), 0.0185531 s/step
# Meep progress: 2.7582625000000003/106.66666650772095 = 2.6% done in 144.4s, 5438.1s to go
# on time step 7610 (time=2.75863), 0.0185096 s/step
# Meep progress: 2.8369250000000004/106.66666650772095 = 2.7% done in 148.4s, 5429.8s to go
# on time step 7827 (time=2.83729), 0.0184371 s/step
# Meep progress: 2.9155875000000004/106.66666650772095 = 2.7% done in 152.4s, 5422.0s to go
# on time step 8044 (time=2.91595), 0.0184728 s/step
# Meep progress: 2.9938875/106.66666650772095 = 2.8% done in 156.4s, 5414.8s to go
# on time step 8260 (time=2.99425), 0.0185294 s/step
# Meep progress: 3.07255/106.66666650772095 = 2.9% done in 160.4s, 5407.5s to go
# on time step 8477 (time=3.07291), 0.0185 s/step
# Meep progress: 3.15085/106.66666650772095 = 3.0% done in 164.4s, 5400.9s to go
# on time step 8693 (time=3.15121), 0.0185549 s/step
# Meep progress: 3.2295125000000002/106.66666650772095 = 3.0% done in 168.4s, 5393.8s to go
# on time step 8910 (time=3.22988), 0.0184872 s/step
# Meep progress: 3.3074500000000002/106.66666650772095 = 3.1% done in 172.4s, 5388.1s to go
# on time step 9125 (time=3.30781), 0.0186525 s/step
# Meep progress: 3.3853875/106.66666650772095 = 3.2% done in 176.4s, 5382.5s to go
# on time step 9340 (time=3.38575), 0.0186536 s/step
# Meep progress: 3.463325/106.66666650772095 = 3.2% done in 180.4s, 5376.7s to go
# on time step 9555 (time=3.46369), 0.0186208 s/step
# Meep progress: 3.5419875000000003/106.66666650772095 = 3.3% done in 184.4s, 5370.2s to go
# on time step 9772 (time=3.54235), 0.0185019 s/step
# Meep progress: 3.6206500000000004/106.66666650772095 = 3.4% done in 188.5s, 5363.9s to go
# on time step 9989 (time=3.62101), 0.0185112 s/step
# Meep progress: 3.6906125000000003/106.66666650772095 = 3.5% done in 192.5s, 5370.4s to go
# on time step 10182 (time=3.69098), 0.0207875 s/step
# Meep progress: 3.7689125000000003/106.66666650772095 = 3.5% done in 196.5s, 5364.4s to go
# on time step 10398 (time=3.76928), 0.0185444 s/step
# Meep progress: 3.8461250000000002/106.66666650772095 = 3.6% done in 200.5s, 5359.8s to go
# on time step 10611 (time=3.84649), 0.0187929 s/step
# Meep progress: 3.9258750000000004/106.66666650772095 = 3.7% done in 204.5s, 5351.5s to go
# on time step 10831 (time=3.92624), 0.0181862 s/step
# Meep progress: 4.00345/106.66666650772095 = 3.8% done in 208.5s, 5346.8s to go
# on time step 11045 (time=4.00381), 0.018755 s/step
# Meep progress: 4.088275/106.66666650772095 = 3.8% done in 212.5s, 5332.1s to go
# on time step 11279 (time=4.08864), 0.0171219 s/step
# Meep progress: 4.176362500000001/106.66666650772095 = 3.9% done in 216.5s, 5313.4s to go
# on time step 11523 (time=4.17709), 0.0164569 s/step
# Meep progress: 4.265175/106.66666650772095 = 4.0% done in 220.5s, 5294.3s to go
# on time step 11769 (time=4.26626), 0.0163258 s/step
# Meep progress: 4.353625/106.66666650772095 = 4.1% done in 224.5s, 5276.3s to go
# on time step 12013 (time=4.35471), 0.0164 s/step
# Meep progress: 4.4428/106.66666650772095 = 4.2% done in 228.5s, 5258.0s to go
# on time step 12259 (time=4.44389), 0.0162745 s/step
# Meep progress: 4.5316125000000005/106.66666650772095 = 4.2% done in 232.5s, 5240.7s to go
# on time step 12504 (time=4.5327), 0.0163499 s/step
# Meep progress: 4.6186125/106.66666650772095 = 4.3% done in 236.5s, 5226.3s to go
# on time step 12744 (time=4.6197), 0.0167109 s/step
# Meep progress: 4.7027125000000005/106.66666650772095 = 4.4% done in 240.5s, 5215.5s to go
# on time step 12976 (time=4.7038), 0.0172791 s/step
# Meep progress: 4.7846375000000005/106.66666650772095 = 4.5% done in 244.5s, 5207.3s to go
# on time step 13203 (time=4.78609), 0.017685 s/step
# Meep progress: 4.8651125/106.66666650772095 = 4.6% done in 248.6s, 5201.1s to go
# on time step 13424 (time=4.8662), 0.0181131 s/step
# Meep progress: 4.9434125/106.66666650772095 = 4.6% done in 252.6s, 5197.2s to go
# on time step 13640 (time=4.9445), 0.0185347 s/step
# Meep progress: 5.0217125000000005/106.66666650772095 = 4.7% done in 256.6s, 5193.4s to go
# on time step 13856 (time=5.0228), 0.0185567 s/step
# Meep progress: 5.104725/106.66666650772095 = 4.8% done in 260.6s, 5184.6s to go
# on time step 14085 (time=5.10581), 0.0175033 s/step
# Meep progress: 5.1855625000000005/106.66666650772095 = 4.9% done in 264.6s, 5178.3s to go
# on time step 14307 (time=5.18629), 0.01802 s/step
# Meep progress: 5.267125/106.66666650772095 = 4.9% done in 268.6s, 5171.0s to go
# on time step 14532 (time=5.26785), 0.0177824 s/step
# Meep progress: 5.351587500000001/106.66666650772095 = 5.0% done in 272.6s, 5161.0s to go
# on time step 14765 (time=5.35231), 0.0171692 s/step
# Meep progress: 5.432787500000001/106.66666650772095 = 5.1% done in 276.6s, 5154.4s to go
# on time step 14989 (time=5.43351), 0.0178889 s/step
# Meep progress: 5.513987500000001/106.66666650772095 = 5.2% done in 280.6s, 5148.0s to go
# on time step 15213 (time=5.51471), 0.017925 s/step
# Meep progress: 5.5922875/106.66666650772095 = 5.2% done in 284.6s, 5144.4s to go
# on time step 15430 (time=5.59338), 0.0184886 s/step
# Meep progress: 5.6782/106.66666650772095 = 5.3% done in 288.6s, 5133.5s to go
# on time step 15667 (time=5.67929), 0.0169306 s/step
# Meep progress: 5.7626625/106.66666650772095 = 5.4% done in 292.6s, 5124.2s to go
# on time step 15900 (time=5.76375), 0.0171714 s/step
# Meep progress: 5.848575/106.66666650772095 = 5.5% done in 296.7s, 5113.8s to go
# on time step 16137 (time=5.84966), 0.0169299 s/step
# Meep progress: 5.929775/106.66666650772095 = 5.6% done in 300.7s, 5107.8s to go
# on time step 16361 (time=5.93086), 0.0178832 s/step
# Meep progress: 6.01025/106.66666650772095 = 5.6% done in 304.7s, 5102.6s to go
# on time step 16583 (time=6.01134), 0.0181041 s/step
# Meep progress: 6.0765875000000005/106.66666650772095 = 5.7% done in 308.7s, 5109.8s to go
# on time step 16766 (time=6.07768), 0.0218669 s/step
# Meep progress: 6.14655/106.66666650772095 = 5.8% done in 312.7s, 5113.8s to go
# on time step 16959 (time=6.14764), 0.020759 s/step
# Meep progress: 6.2302875/106.66666650772095 = 5.8% done in 316.7s, 5105.5s to go
# on time step 17190 (time=6.23138), 0.0173526 s/step
# Meep progress: 6.316925/106.66666650772095 = 5.9% done in 320.7s, 5094.7s to go
# on time step 17429 (time=6.31801), 0.0167442 s/step
# Meep progress: 6.406825/106.66666650772095 = 6.0% done in 324.7s, 5081.4s to go
# on time step 17677 (time=6.40791), 0.0161419 s/step
# Meep progress: 6.4967250000000005/106.66666650772095 = 6.1% done in 328.7s, 5068.5s to go
# on time step 17925 (time=6.49781), 0.0161735 s/step
# Meep progress: 6.5869875/106.66666650772095 = 6.2% done in 332.7s, 5055.4s to go
# on time step 18174 (time=6.58808), 0.0161026 s/step
# Meep progress: 6.6703625/106.66666650772095 = 6.3% done in 336.7s, 5048.2s to go
# on time step 18404 (time=6.67145), 0.017455 s/step
# Meep progress: 6.755187500000001/106.66666650772095 = 6.3% done in 340.8s, 5040.0s to go
# on time step 18638 (time=6.75628), 0.0171317 s/step
# Meep progress: 6.8465375/106.66666650772095 = 6.4% done in 344.8s, 5026.6s to go
# on time step 18890 (time=6.84763), 0.0158885 s/step
# Meep progress: 6.937525000000001/106.66666650772095 = 6.5% done in 348.8s, 5013.8s to go
# on time step 19141 (time=6.93861), 0.0159951 s/step
# Meep progress: 7.028150000000001/106.66666650772095 = 6.6% done in 352.8s, 5001.5s to go
# on time step 19391 (time=7.02924), 0.0160263 s/step
# Meep progress: 7.1129750000000005/106.66666650772095 = 6.7% done in 356.8s, 4993.7s to go
# on time step 19625 (time=7.11406), 0.0171089 s/step
# Meep progress: 7.199975/106.66666650772095 = 6.7% done in 360.8s, 4984.4s to go
# on time step 19865 (time=7.20106), 0.0166807 s/step
# Meep progress: 7.287700000000001/106.66666650772095 = 6.8% done in 364.8s, 4974.7s to go
# on time step 20107 (time=7.28879), 0.016573 s/step
# Meep progress: 7.376150000000001/106.66666650772095 = 6.9% done in 368.8s, 4964.7s to go
# on time step 20351 (time=7.37724), 0.0164435 s/step
# Meep progress: 7.466775/106.66666650772095 = 7.0% done in 372.8s, 4953.3s to go
# on time step 20601 (time=7.46786), 0.0160484 s/step
# Meep progress: 7.558487500000001/106.66666650772095 = 7.1% done in 376.9s, 4941.3s to go
# on time step 20854 (time=7.55958), 0.0158639 s/step
# Meep progress: 7.650200000000001/106.66666650772095 = 7.2% done in 380.9s, 4929.4s to go
# on time step 21107 (time=7.65129), 0.0158148 s/step
# Meep progress: 7.741550000000001/106.66666650772095 = 7.3% done in 384.9s, 4917.9s to go
# on time step 21359 (time=7.74264), 0.0158865 s/step
# Meep progress: 7.832537500000001/106.66666650772095 = 7.3% done in 388.9s, 4906.8s to go
# on time step 21610 (time=7.83363), 0.0159404 s/step
# Meep progress: 7.923525000000001/106.66666650772095 = 7.4% done in 392.9s, 4895.9s to go
# on time step 21861 (time=7.92461), 0.0159724 s/step
# Meep progress: 8.00835/106.66666650772095 = 7.5% done in 396.9s, 4889.2s to go
# on time step 22095 (time=8.00944), 0.0170996 s/step
# Meep progress: 8.093175/106.66666650772095 = 7.6% done in 400.9s, 4882.7s to go
# on time step 22328 (time=8.0939), 0.0171795 s/step
# Meep progress: 8.179450000000001/106.66666650772095 = 7.7% done in 404.9s, 4875.4s to go
# on time step 22566 (time=8.18018), 0.0168597 s/step
# Meep progress: 8.2704375/106.66666650772095 = 7.8% done in 408.9s, 4864.9s to go
# on time step 22817 (time=8.27116), 0.0159474 s/step
# Meep progress: 8.359250000000001/106.66666650772095 = 7.8% done in 412.9s, 4855.9s to go
# on time step 23062 (time=8.35998), 0.0163549 s/step
# Meep progress: 8.4448/106.66666650772095 = 7.9% done in 416.9s, 4849.2s to go
# on time step 23298 (time=8.44552), 0.01696 s/step
# Meep progress: 8.5365125/106.66666650772095 = 8.0% done in 420.9s, 4838.8s to go
# on time step 23551 (time=8.53724), 0.0158703 s/step
# Meep progress: 8.617712500000001/106.66666650772095 = 8.1% done in 424.9s, 4834.8s to go
# on time step 23775 (time=8.61844), 0.0178695 s/step
# Meep progress: 8.707612500000002/106.66666650772095 = 8.2% done in 429.0s, 4825.6s to go
# on time step 24023 (time=8.70834), 0.0161791 s/step
# Meep progress: 8.7986/106.66666650772095 = 8.2% done in 433.0s, 4815.9s to go
# on time step 24274 (time=8.79933), 0.0159972 s/step
# Meep progress: 8.881250000000001/106.66666650772095 = 8.3% done in 437.0s, 4811.2s to go
# on time step 24502 (time=8.88198), 0.0175676 s/step
# Meep progress: 8.966800000000001/106.66666650772095 = 8.4% done in 441.0s, 4804.8s to go
# on time step 24738 (time=8.96753), 0.0169832 s/step
# Meep progress: 9.050175000000001/106.66666650772095 = 8.5% done in 445.0s, 4799.8s to go
# on time step 24967 (time=9.05054), 0.0174885 s/step
# Meep progress: 9.130287500000001/106.66666650772095 = 8.6% done in 449.0s, 4796.7s to go
# on time step 25188 (time=9.13065), 0.0181802 s/step
# Meep progress: 9.211125000000001/106.66666650772095 = 8.6% done in 453.0s, 4793.0s to go
# on time step 25412 (time=9.21185), 0.0179108 s/step
# Meep progress: 9.2970375/106.66666650772095 = 8.7% done in 457.0s, 4786.5s to go
# on time step 25649 (time=9.29776), 0.0169207 s/step
# Meep progress: 9.38005/106.66666650772095 = 8.8% done in 461.0s, 4781.7s to go
# on time step 25878 (time=9.38078), 0.017522 s/step
# Meep progress: 9.460162500000001/106.66666650772095 = 8.9% done in 465.0s, 4778.5s to go
# on time step 26100 (time=9.46125), 0.0181002 s/step
# Meep progress: 9.531575/106.66666650772095 = 8.9% done in 469.0s, 4780.0s to go
# on time step 26297 (time=9.53266), 0.020404 s/step
# Meep progress: 9.591750000000001/106.66666650772095 = 9.0% done in 473.1s, 4787.7s to go
# on time step 26463 (time=9.59284), 0.024233 s/step
# Meep progress: 9.663525/106.66666650772095 = 9.1% done in 477.1s, 4788.9s to go
# on time step 26662 (time=9.66498), 0.0201304 s/step
# Meep progress: 9.7436375/106.66666650772095 = 9.1% done in 481.1s, 4785.5s to go
# on time step 26883 (time=9.74509), 0.0181234 s/step
# Meep progress: 9.8284625/106.66666650772095 = 9.2% done in 485.1s, 4779.6s to go
# on time step 27117 (time=9.82991), 0.0171225 s/step
# Meep progress: 9.917637500000001/106.66666650772095 = 9.3% done in 489.1s, 4771.3s to go
# on time step 27363 (time=9.91909), 0.0162686 s/step
# Meep progress: 10.007537500000002/106.66666650772095 = 9.4% done in 493.1s, 4762.7s to go
# on time step 27611 (time=10.009), 0.0161635 s/step
# Meep progress: 10.084025/106.66666650772095 = 9.5% done in 497.1s, 4761.2s to go
# on time step 27822 (time=10.0855), 0.0189637 s/step
# Meep progress: 10.169575/106.66666650772095 = 9.5% done in 501.1s, 4755.0s to go
# on time step 28058 (time=10.171), 0.0169955 s/step
# Meep progress: 10.258387500000001/106.66666650772095 = 9.6% done in 505.1s, 4747.2s to go
# on time step 28303 (time=10.2598), 0.0163781 s/step
# Meep progress: 10.348287500000001/106.66666650772095 = 9.7% done in 509.1s, 4738.9s to go
# on time step 28551 (time=10.3497), 0.0161576 s/step
# Meep progress: 10.4374625/106.66666650772095 = 9.8% done in 513.1s, 4731.0s to go
# on time step 28798 (time=10.4393), 0.016258 s/step
# Meep progress: 10.513950000000001/106.66666650772095 = 9.9% done in 517.2s, 4729.5s to go
# on time step 29008 (time=10.5154), 0.0190781 s/step
# Meep progress: 10.592250000000002/106.66666650772095 = 9.9% done in 521.2s, 4727.1s to go
# on time step 29224 (time=10.5937), 0.0185327 s/step
# Meep progress: 10.664025/106.66666650772095 = 10.0% done in 525.2s, 4727.8s to go
# on time step 29422 (time=10.6655), 0.0202658 s/step
# Meep progress: 10.7474/106.66666650772095 = 10.1% done in 529.2s, 4722.8s to go
# on time step 29653 (time=10.7492), 0.017317 s/step
# Meep progress: 10.836575000000002/106.66666650772095 = 10.2% done in 533.2s, 4715.0s to go
# on time step 29899 (time=10.8384), 0.0162768 s/step
# Meep progress: 10.926837500000001/106.66666650772095 = 10.2% done in 537.2s, 4706.8s to go
# on time step 30148 (time=10.9287), 0.016103 s/step
# Meep progress: 11.01565/106.66666650772095 = 10.3% done in 541.2s, 4699.3s to go
# on time step 30393 (time=11.0175), 0.016354 s/step
# ...
# on time step 48290 (time=17.5051), 0.0163669 s/step
# Meep progress: 17.5932125/106.66666650772095 = 16.5% done in 769.4s, 3895.4s to go
# on time step 48546 (time=17.5979), 0.0156396 s/step
# Meep progress: 17.690725/106.66666650772095 = 16.6% done in 773.4s, 3889.8s to go
# on time step 48815 (time=17.6954), 0.0148802 s/step
# Meep progress: 17.7911375/106.66666650772095 = 16.7% done in 777.4s, 3883.5s to go
# on time step 49091 (time=17.7955), 0.014494 s/step
# Meep progress: 17.8911875/106.66666650772095 = 16.8% done in 781.4s, 3877.4s to go
# on time step 49367 (time=17.8955), 0.0145109 s/step
# Meep progress: 17.989787500000002/106.66666650772095 = 16.9% done in 785.4s, 3871.6s to go
# on time step 49638 (time=17.9938), 0.0147621 s/step
# Meep progress: 18.08005/106.66666650772095 = 17.0% done in 789.4s, 3868.0s to go
# on time step 49886 (time=18.0837), 0.0161357 s/step
# Meep progress: 18.16995/106.66666650772095 = 17.0% done in 793.4s, 3864.5s to go
# on time step 50135 (time=18.1739), 0.0161122 s/step
# Meep progress: 18.264200000000002/106.66666650772095 = 17.1% done in 797.5s, 3859.8s to go
# on time step 50394 (time=18.2678), 0.0154497 s/step
# Meep progress: 18.353012500000002/106.66666650772095 = 17.2% done in 801.5s, 3856.6s to go
# on time step 50639 (time=18.3566), 0.0163537 s/step
# Meep progress: 18.441825/106.66666650772095 = 17.3% done in 805.5s, 3853.3s to go
# on time step 50884 (time=18.4455), 0.0163522 s/step
# Meep progress: 18.530275000000003/106.66666650772095 = 17.4% done in 809.5s, 3850.2s to go
# on time step 51128 (time=18.5339), 0.0164388 s/step
# Meep progress: 18.61945/106.66666650772095 = 17.5% done in 813.5s, 3846.8s to go
# on time step 51374 (time=18.6231), 0.0162777 s/step
# Meep progress: 18.7111625/106.66666650772095 = 17.5% done in 817.5s, 3842.8s to go
# on time step 51628 (time=18.7152), 0.0157776 s/step
# Meep progress: 18.8046875/106.66666650772095 = 17.6% done in 821.5s, 3838.3s to go
# on time step 51885 (time=18.8083), 0.0155978 s/step
# Meep progress: 18.8945875/106.66666650772095 = 17.7% done in 825.5s, 3834.8s to go
# on time step 52133 (time=18.8982), 0.0161673 s/step
# Meep progress: 18.982675/106.66666650772095 = 17.8% done in 829.5s, 3831.7s to go
# on time step 52376 (time=18.9863), 0.0165017 s/step
# Meep progress: 19.07185/106.66666650772095 = 17.9% done in 833.5s, 3828.3s to go
# on time step 52622 (time=19.0755), 0.0162751 s/step
# Meep progress: 19.1635625/106.66666650772095 = 18.0% done in 837.5s, 3824.3s to go
# on time step 52875 (time=19.1672), 0.0158214 s/step
# Meep progress: 19.252012500000003/106.66666650772095 = 18.0% done in 841.5s, 3821.1s to go
# on time step 53119 (time=19.2556), 0.0164125 s/step
# Meep progress: 19.3459/106.66666650772095 = 18.1% done in 845.6s, 3816.5s to go
# on time step 53379 (time=19.3499), 0.0154393 s/step
# Meep progress: 19.4445/106.66666650772095 = 18.2% done in 849.6s, 3810.9s to go
# on time step 53650 (time=19.4481), 0.0147646 s/step
# Meep progress: 19.5362125/106.66666650772095 = 18.3% done in 853.6s, 3806.9s to go
# on time step 53903 (time=19.5398), 0.0158587 s/step
# Meep progress: 19.632275/106.66666650772095 = 18.4% done in 857.6s, 3801.8s to go
# on time step 54169 (time=19.6363), 0.0150764 s/step
# Meep progress: 19.731237500000002/106.66666650772095 = 18.5% done in 861.6s, 3796.1s to go
# on time step 54442 (time=19.7352), 0.0146759 s/step
# Meep progress: 19.830562500000003/106.66666650772095 = 18.6% done in 865.6s, 3790.4s to go
# on time step 54716 (time=19.8346), 0.0146496 s/step
# Meep progress: 19.923725/106.66666650772095 = 18.7% done in 869.6s, 3786.0s to go
# on time step 54972 (time=19.9274), 0.0156337 s/step
# Meep progress: 20.012175000000003/106.66666650772095 = 18.8% done in 873.6s, 3782.8s to go
# on time step 55217 (time=20.0162), 0.0163903 s/step
# Meep progress: 20.10135/106.66666650772095 = 18.8% done in 877.6s, 3779.4s to go
# on time step 55463 (time=20.1053), 0.0162692 s/step
# Meep progress: 20.190162500000003/106.66666650772095 = 18.9% done in 881.6s, 3776.1s to go
# on time step 55708 (time=20.1942), 0.0163715 s/step
# Meep progress: 20.278975000000003/106.66666650772095 = 19.0% done in 885.6s, 3772.7s to go
# on time step 55953 (time=20.283), 0.0163665 s/step
# Meep progress: 20.3685125/106.66666650772095 = 19.1% done in 889.6s, 3769.3s to go
# on time step 56200 (time=20.3725), 0.0162297 s/step
# Meep progress: 20.456962500000003/106.66666650772095 = 19.2% done in 893.7s, 3766.0s to go
# on time step 56444 (time=20.461), 0.016442 s/step
# Meep progress: 20.545775000000003/106.66666650772095 = 19.3% done in 897.7s, 3762.7s to go
# on time step 56689 (time=20.5498), 0.016368 s/step
# Meep progress: 20.635675000000003/106.66666650772095 = 19.3% done in 901.7s, 3759.1s to go
# on time step 56937 (time=20.6397), 0.0161661 s/step
# Meep progress: 20.726300000000002/106.66666650772095 = 19.4% done in 905.7s, 3755.4s to go
# on time step 57187 (time=20.7303), 0.0160522 s/step
# Meep progress: 20.816200000000002/106.66666650772095 = 19.5% done in 909.7s, 3751.8s to go
# on time step 57436 (time=20.8206), 0.016123 s/step
# Meep progress: 20.910812500000002/106.66666650772095 = 19.6% done in 913.7s, 3747.1s to go
# on time step 57697 (time=20.9152), 0.0153777 s/step
# Meep progress: 20.999625/106.66666650772095 = 19.7% done in 917.7s, 3743.8s to go
# on time step 57942 (time=21.004), 0.0163674 s/step
# Meep progress: 21.0891625/106.66666650772095 = 19.8% done in 921.7s, 3740.2s to go
# on time step 58190 (time=21.0939), 0.0161687 s/step
# Meep progress: 21.183775/106.66666650772095 = 19.9% done in 925.7s, 3735.5s to go
# on time step 58451 (time=21.1885), 0.0153524 s/step
# Meep progress: 21.2754875/106.66666650772095 = 19.9% done in 929.7s, 3731.5s to go
# on time step 58705 (time=21.2806), 0.0157905 s/step
# Meep progress: 21.373725/106.66666650772095 = 20.0% done in 933.7s, 3726.1s to go
# on time step 58976 (time=21.3788), 0.0147843 s/step
# Meep progress: 21.472687500000003/106.66666650772095 = 20.1% done in 937.7s, 3720.6s to go
# on time step 59249 (time=21.4778), 0.0146985 s/step
# Meep progress: 21.57165/106.66666650772095 = 20.2% done in 941.8s, 3715.0s to go
# on time step 59522 (time=21.5767), 0.0146883 s/step
# Meep progress: 21.671337500000003/106.66666650772095 = 20.3% done in 945.8s, 3709.3s to go
# on time step 59797 (time=21.6764), 0.0145934 s/step
# Meep progress: 21.770300000000002/106.66666650772095 = 20.4% done in 949.8s, 3703.8s to go
# on time step 60070 (time=21.7754), 0.0146651 s/step
# Meep progress: 21.8689/106.66666650772095 = 20.5% done in 953.8s, 3698.4s to go
# on time step 60341 (time=21.8736), 0.0147735 s/step
# Meep progress: 21.959525000000003/106.66666650772095 = 20.6% done in 957.8s, 3694.7s to go
# on time step 60590 (time=21.9639), 0.0161207 s/step
# Meep progress: 22.047975/106.66666650772095 = 20.7% done in 961.8s, 3691.4s to go
# on time step 60834 (time=22.0523), 0.0164088 s/step
# Meep progress: 22.137150000000002/106.66666650772095 = 20.8% done in 965.8s, 3687.9s to go
# on time step 61080 (time=22.1415), 0.0163001 s/step
# Meep progress: 22.224512500000003/106.66666650772095 = 20.8% done in 969.8s, 3684.8s to go
# on time step 61322 (time=22.2292), 0.0165827 s/step
# Meep progress: 22.313325000000003/106.66666650772095 = 20.9% done in 973.8s, 3681.5s to go
# on time step 61567 (time=22.318), 0.0163493 s/step
# Meep progress: 22.402137500000002/106.66666650772095 = 21.0% done in 977.8s, 3678.1s to go
# on time step 61812 (time=22.4069), 0.0163733 s/step
# Meep progress: 22.4898625/106.66666650772095 = 21.1% done in 981.8s, 3674.9s to go
# on time step 62054 (time=22.4946), 0.0165637 s/step
# Meep progress: 22.580125000000002/106.66666650772095 = 21.2% done in 985.8s, 3671.2s to go
# on time step 62304 (time=22.5852), 0.0160579 s/step
# Meep progress: 22.668575/106.66666650772095 = 21.3% done in 989.8s, 3667.9s to go
# on time step 62548 (time=22.6737), 0.0164058 s/step
# Meep progress: 22.757025000000002/106.66666650772095 = 21.3% done in 993.9s, 3664.6s to go
# on time step 62792 (time=22.7621), 0.0164311 s/step
# Meep progress: 22.845837500000002/106.66666650772095 = 21.4% done in 997.9s, 3661.1s to go
# on time step 63037 (time=22.8509), 0.0163302 s/step
# Meep progress: 22.93465/106.66666650772095 = 21.5% done in 1001.9s, 3657.7s to go
# on time step 63282 (time=22.9397), 0.016373 s/step
# Meep progress: 23.023100000000003/106.66666650772095 = 21.6% done in 1005.9s, 3654.4s to go
# on time step 63527 (time=23.0285), 0.0163876 s/step
# Meep progress: 23.114812500000003/106.66666650772095 = 21.7% done in 1009.9s, 3650.4s to go
# on time step 63780 (time=23.1203), 0.015827 s/step
# Meep progress: 23.20435/106.66666650772095 = 21.8% done in 1013.9s, 3646.8s to go
# on time step 64028 (time=23.2102), 0.0161543 s/step
# Meep progress: 23.295337500000002/106.66666650772095 = 21.8% done in 1017.9s, 3642.9s to go
# on time step 64278 (time=23.3008), 0.0160066 s/step
# Meep progress: 23.3856/106.66666650772095 = 21.9% done in 1021.9s, 3639.2s to go
# on time step 64528 (time=23.3914), 0.0160243 s/step
# Meep progress: 23.482025/106.66666650772095 = 22.0% done in 1025.9s, 3634.3s to go
# on time step 64795 (time=23.4882), 0.0150357 s/step
# Meep progress: 23.58135/106.66666650772095 = 22.1% done in 1029.9s, 3628.7s to go
# on time step 65069 (time=23.5875), 0.01462 s/step
# Meep progress: 23.680675/106.66666650772095 = 22.2% done in 1033.9s, 3623.3s to go
# on time step 65343 (time=23.6868), 0.0146515 s/step
# Meep progress: 23.7789125/106.66666650772095 = 22.3% done in 1037.9s, 3618.0s to go
# on time step 65614 (time=23.7851), 0.0148002 s/step
# Meep progress: 23.877875000000003/106.66666650772095 = 22.4% done in 1041.9s, 3612.6s to go
# on time step 65887 (time=23.884), 0.0146674 s/step
# Meep progress: 23.976475/106.66666650772095 = 22.5% done in 1045.9s, 3607.3s to go
# on time step 66159 (time=23.9826), 0.0147127 s/step
# Meep progress: 24.0747125/106.66666650772095 = 22.6% done in 1049.9s, 3602.0s to go
# on time step 66430 (time=24.0809), 0.0147871 s/step
# Meep progress: 24.168962500000003/106.66666650772095 = 22.7% done in 1054.0s, 3597.6s to go
# on time step 66689 (time=24.1748), 0.0155068 s/step
# Meep progress: 24.2566875/106.66666650772095 = 22.7% done in 1058.0s, 3594.4s to go
# on time step 66931 (time=24.2625), 0.0165713 s/step
# Meep progress: 24.344775000000002/106.66666650772095 = 22.8% done in 1062.0s, 3591.1s to go
# on time step 67174 (time=24.3506), 0.0165151 s/step
# Meep progress: 24.433225000000004/106.66666650772095 = 22.9% done in 1066.0s, 3587.8s to go
# on time step 67417 (time=24.4387), 0.016465 s/step
# Meep progress: 24.518050000000002/106.66666650772095 = 23.0% done in 1070.0s, 3585.1s to go
# on time step 67645 (time=24.5213), 0.0175711 s/step
# Meep progress: 24.584025/106.66666650772095 = 23.0% done in 1074.0s, 3586.0s to go
# on time step 67831 (time=24.5887), 0.0215849 s/step
# Meep progress: 24.6692125/106.66666650772095 = 23.1% done in 1078.0s, 3583.3s to go
# on time step 68068 (time=24.6747), 0.0169308 s/step
# Meep progress: 24.757662500000002/106.66666650772095 = 23.2% done in 1082.0s, 3579.8s to go
# on time step 68313 (time=24.7635), 0.016393 s/step
# Meep progress: 24.845750000000002/106.66666650772095 = 23.3% done in 1086.0s, 3576.5s to go
# on time step 68555 (time=24.8512), 0.0165322 s/step
# Meep progress: 24.933112500000004/106.66666650772095 = 23.4% done in 1090.1s, 3573.4s to go
# on time step 68796 (time=24.9386), 0.0166083 s/step
# Meep progress: 25.021925000000003/106.66666650772095 = 23.5% done in 1094.1s, 3569.9s to go
# on time step 69041 (time=25.0274), 0.016329 s/step
# Meep progress: 25.1111/106.66666650772095 = 23.5% done in 1098.1s, 3566.3s to go
# on time step 69286 (time=25.1162), 0.0163381 s/step
# Meep progress: 25.1991875/106.66666650772095 = 23.6% done in 1102.1s, 3563.0s to go
# on time step 69529 (time=25.2043), 0.016464 s/step
# Meep progress: 25.2818375/106.66666650772095 = 23.7% done in 1106.1s, 3560.6s to go
# on time step 69757 (time=25.2869), 0.0175787 s/step
# Meep progress: 25.37355/106.66666650772095 = 23.8% done in 1110.1s, 3556.6s to go
# on time step 70011 (time=25.379), 0.0157741 s/step
# Meep progress: 25.469612500000004/106.66666650772095 = 23.9% done in 1114.1s, 3551.8s to go
# on time step 70276 (time=25.4751), 0.0151062 s/step
# Meep progress: 25.5616875/106.66666650772095 = 24.0% done in 1118.1s, 3547.7s to go
# on time step 70530 (time=25.5671), 0.0157985 s/step
# Meep progress: 25.6552125/106.66666650772095 = 24.1% done in 1122.1s, 3543.3s to go
# on time step 70789 (time=25.661), 0.0154686 s/step
# Meep progress: 25.7545375/106.66666650772095 = 24.1% done in 1126.1s, 3537.9s to go
# on time step 71063 (time=25.7603), 0.0146274 s/step
# Meep progress: 25.8538625/106.66666650772095 = 24.2% done in 1130.1s, 3532.5s to go
# on time step 71337 (time=25.8597), 0.0146104 s/step
# Meep progress: 25.952825/106.66666650772095 = 24.3% done in 1134.1s, 3527.2s to go
# on time step 71611 (time=25.959), 0.0146525 s/step
# Meep progress: 26.049975000000003/106.66666650772095 = 24.4% done in 1138.1s, 3522.2s to go
# on time step 71877 (time=26.0554), 0.0150488 s/step
# Meep progress: 26.138425/106.66666650772095 = 24.5% done in 1142.1s, 3518.8s to go
# on time step 72121 (time=26.1439), 0.0164414 s/step
# Meep progress: 26.226875000000003/106.66666650772095 = 24.6% done in 1146.2s, 3515.4s to go
# on time step 72364 (time=26.232), 0.0164778 s/step
# Meep progress: 26.315325/106.66666650772095 = 24.7% done in 1150.2s, 3511.9s to go
# on time step 72608 (time=26.3204), 0.0164098 s/step
# Meep progress: 26.402687500000003/106.66666650772095 = 24.8% done in 1154.2s, 3508.7s to go
# on time step 72849 (time=26.4078), 0.0166133 s/step
# Meep progress: 26.4911375/106.66666650772095 = 24.8% done in 1158.2s, 3505.3s to go
# on time step 73093 (time=26.4962), 0.0164445 s/step
# Meep progress: 26.579950000000004/106.66666650772095 = 24.9% done in 1162.2s, 3501.8s to go
# on time step 73338 (time=26.585), 0.0163545 s/step
# Meep progress: 26.668400000000002/106.66666650772095 = 25.0% done in 1166.2s, 3498.3s to go
# on time step 73582 (time=26.6735), 0.0164302 s/step
# Meep progress: 26.7572125/106.66666650772095 = 25.1% done in 1170.2s, 3494.8s to go
# on time step 73827 (time=26.7623), 0.0163541 s/step
# Meep progress: 26.846025/106.66666650772095 = 25.2% done in 1174.2s, 3491.3s to go
# on time step 74072 (time=26.8511), 0.0163373 s/step
# Meep progress: 26.933750000000003/106.66666650772095 = 25.3% done in 1178.2s, 3488.0s to go
# on time step 74314 (time=26.9388), 0.0165718 s/step
# Meep progress: 27.020750000000003/106.66666650772095 = 25.3% done in 1182.2s, 3484.7s to go
# on time step 74555 (time=27.0262), 0.0166554 s/step
# Meep progress: 27.108837500000003/106.66666650772095 = 25.4% done in 1186.2s, 3481.3s to go
# on time step 74798 (time=27.1143), 0.0164776 s/step
# Meep progress: 27.1972875/106.66666650772095 = 25.5% done in 1190.2s, 3477.9s to go
# on time step 75042 (time=27.2027), 0.0164098 s/step
# Meep progress: 27.290087500000002/106.66666650772095 = 25.6% done in 1194.3s, 3473.6s to go
# on time step 75299 (time=27.2959), 0.0155879 s/step
# Meep progress: 27.387600000000003/106.66666650772095 = 25.7% done in 1198.3s, 3468.6s to go
# on time step 75568 (time=27.3934), 0.0149058 s/step
# Meep progress: 27.478587500000003/106.66666650772095 = 25.8% done in 1202.3s, 3464.7s to go
# on time step 75818 (time=27.484), 0.0160456 s/step
# Meep progress: 27.5670375/106.66666650772095 = 25.8% done in 1206.3s, 3461.2s to go
# on time step 76063 (time=27.5728), 0.0163715 s/step
# Meep progress: 27.660925000000002/106.66666650772095 = 25.9% done in 1210.3s, 3456.8s to go
# on time step 76323 (time=27.6671), 0.0154047 s/step
# Meep progress: 27.7598875/106.66666650772095 = 26.0% done in 1214.3s, 3451.6s to go
# on time step 76596 (time=27.7661), 0.0146829 s/step
# Meep progress: 27.858850000000004/106.66666650772095 = 26.1% done in 1218.3s, 3446.3s to go
# on time step 76869 (time=27.865), 0.014692 s/step
# Meep progress: 27.957812500000003/106.66666650772095 = 26.2% done in 1222.3s, 3441.1s to go
# on time step 77142 (time=27.964), 0.0146644 s/step
# Meep progress: 28.053875/106.66666650772095 = 26.3% done in 1226.3s, 3436.4s to go
# on time step 77407 (time=28.06), 0.0151461 s/step

# %%
max_wvls = [] #to store the wavelength value where the peak occurs
index = 0

scatt_data = np.asarray(scatt_data)
freq_data = np.asarray(freq_data)    #turn both lists into numpy arrays for easy processing.

#for each row, plot the data, find the max wavelength, and use the percentage value for label.

for run in scatt_data:
    
    scatt_flux = run
    freqs = freq_data[index]
    perc = percentages[index]
    
    plt.plot(1E3/freqs, -1*scatt_flux*1E9, "-", label=f"{100-round(float(perc),2)}%")
    plt.grid(True, which="both", ls="-")
    plt.xlabel("Wavelength, nm")
    plt.ylabel("Absorption Power, nW")
    #plt.yscale("symlog", linthresh=5E-9) #linear threshold says the region about 0 to scale linearly

    plt.legend(loc="upper right", title = "Curvature")
    plt.title("Absorption Spectrum of Au Nanorod: Varying Curvature")
    plt.tight_layout()


    #Frequency position of the peak is the index of the max value in scattered flux data, in frequencies.
    # Doing argmin since the scattering peak is the largest negative value.
    max_wvl = 1E3/freqs[np.argmin(scatt_flux)]
    max_wvls.append([float(perc), max_wvl])

    index += 1 #So the percentage value in the percentages array changes for each row.

plt.savefig(fname="Absorption Spectrum of an Au Nanorod: Varying Curvature",
            dpi=150, 
            bbox_inches="tight")
plt.show()

max_wvls = np.asarray(max_wvls)
for row in max_wvls:
    print(row)


#plot curvature vs. peak position

plt.plot(max_wvls[:,1], 100-max_wvls[:,0], "gx-")
plt.grid(True, which="both", ls="-")
plt.xlabel("Peak Wavelength, nm")
plt.ylabel("Curvature (ellipsoid % of total rod length), %")
plt.title("Nanorod Curvature vs. Peak Wavelength")
plt.tight_layout()
plt.savefig(fname="Nanorod Curvature vs Peak Wavelength",
            dpi=150, 
            bbox_inches="tight")
plt.show()


#Plot of redshift vs. curvature

redshift = max_wvls[:,1]-max_wvls[0,1] #peak position minus 100% cylinder position
curvature = 100-max_wvls[:,0]

plt.plot(curvature, -1*redshift, "bx-")
plt.grid(True, which="both", ls="-")
plt.xlabel("Curvature (ellipsoid % of total rod length), %")
plt.ylabel("Blueshift from 0% curvature, nm")
plt.title("Blueshift vs. Nanorod Curvature")
plt.tight_layout()
plt.savefig(fname="Blueshift vs Nanorod Curvature",
            dpi=150, 
            bbox_inches="tight")
plt.show()

plt.plot(curvature, redshift, "rx-")
plt.grid(True, which="both", ls="-")
plt.xlabel("Curvature (ellipsoid % of total rod length), %")
plt.ylabel("Redshift from 0% curvature, nm")
plt.title("Redshift vs. Nanorod Curvature")
plt.tight_layout()
plt.savefig(fname="Redshift vs Nanorod Curvature",
            dpi=150, 
            bbox_inches="tight")
plt.show()
