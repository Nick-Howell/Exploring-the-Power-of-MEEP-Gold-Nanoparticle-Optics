# %%
#Mie Scattering of a Gold Sphere

import meep as mp
import numpy as np
import matplotlib.pyplot as plt
from meep.materials import Au

r = 1.0  # radius of sphere

wvl_min = 2 * np.pi * r / 10
wvl_max = 2 * np.pi * r / 2

frq_min = 1 / wvl_max
frq_max = 1 / wvl_min
frq_cen = 0.5 * (frq_min + frq_max)
dfrq = frq_max - frq_min
nfrq = 100

## at least 8 pixels per smallest wavelength, i.e. np.floor(8/wvl_min)
resolution = 50

dpml = 0.5 * wvl_max
dair = 0.5 * wvl_max

pml_layers = [mp.PML(thickness=dpml)]

symmetries = [mp.Mirror(mp.Y), mp.Mirror(mp.Z, phase=-1)]

s = 2 * (dpml + dair + r)
cell_size = mp.Vector3(s, s, s)

# is_integrated=True necessary for any planewave source extending into PML
sources = [
    mp.Source(
        mp.GaussianSource(frq_cen, fwidth=dfrq, is_integrated=True),
        center=mp.Vector3(-0.5 * s + dpml),
        size=mp.Vector3(0, s, s),
        component=mp.Ez,
    )
]

sim = mp.Simulation(
    resolution=resolution,
    cell_size=cell_size,
    boundary_layers=pml_layers,
    sources=sources,
    k_point=mp.Vector3(),
    symmetries=symmetries,
)

box_x1 = sim.add_flux(
    frq_cen,
    dfrq,
    nfrq,
    mp.FluxRegion(center=mp.Vector3(x=-r), size=mp.Vector3(0, 2 * r, 2 * r)),
)
box_x2 = sim.add_flux(
    frq_cen,
    dfrq,
    nfrq,
    mp.FluxRegion(center=mp.Vector3(x=+r), size=mp.Vector3(0, 2 * r, 2 * r)),
)
box_y1 = sim.add_flux(
    frq_cen,
    dfrq,
    nfrq,
    mp.FluxRegion(center=mp.Vector3(y=-r), size=mp.Vector3(2 * r, 0, 2 * r)),
)
box_y2 = sim.add_flux(
    frq_cen,
    dfrq,
    nfrq,
    mp.FluxRegion(center=mp.Vector3(y=+r), size=mp.Vector3(2 * r, 0, 2 * r)),
)
box_z1 = sim.add_flux(
    frq_cen,
    dfrq,
    nfrq,
    mp.FluxRegion(center=mp.Vector3(z=-r), size=mp.Vector3(2 * r, 2 * r, 0)),
)
box_z2 = sim.add_flux(
    frq_cen,
    dfrq,
    nfrq,
    mp.FluxRegion(center=mp.Vector3(z=+r), size=mp.Vector3(2 * r, 2 * r, 0)),
)

sim.run(until_after_sources=10)

freqs = mp.get_flux_freqs(box_x1)
box_x1_data = sim.get_flux_data(box_x1)
box_x2_data = sim.get_flux_data(box_x2)
box_y1_data = sim.get_flux_data(box_y1)
box_y2_data = sim.get_flux_data(box_y2)
box_z1_data = sim.get_flux_data(box_z1)
box_z2_data = sim.get_flux_data(box_z2)

box_x1_flux0 = mp.get_fluxes(box_x1)

sim.reset_meep()







n_sphere = 2.0
geometry = [mp.Sphere(material=mp.Medium(index=n_sphere), center=mp.Vector3(), radius=r)
           ]

sim = mp.Simulation(
    resolution=resolution,
    cell_size=cell_size,
    boundary_layers=pml_layers,
    sources=sources,
    k_point=mp.Vector3(),
    symmetries=symmetries,
    geometry=geometry,
)

box_x1 = sim.add_flux(
    frq_cen,
    dfrq,
    nfrq,
    mp.FluxRegion(center=mp.Vector3(x=-r), size=mp.Vector3(0, 2 * r, 2 * r)),
)
box_x2 = sim.add_flux(
    frq_cen,
    dfrq,
    nfrq,
    mp.FluxRegion(center=mp.Vector3(x=+r), size=mp.Vector3(0, 2 * r, 2 * r)),
)
box_y1 = sim.add_flux(
    frq_cen,
    dfrq,
    nfrq,
    mp.FluxRegion(center=mp.Vector3(y=-r), size=mp.Vector3(2 * r, 0, 2 * r)),
)
box_y2 = sim.add_flux(
    frq_cen,
    dfrq,
    nfrq,
    mp.FluxRegion(center=mp.Vector3(y=+r), size=mp.Vector3(2 * r, 0, 2 * r)),
)
box_z1 = sim.add_flux(
    frq_cen,
    dfrq,
    nfrq,
    mp.FluxRegion(center=mp.Vector3(z=-r), size=mp.Vector3(2 * r, 2 * r, 0)),
)
box_z2 = sim.add_flux(
    frq_cen,
    dfrq,
    nfrq,
    mp.FluxRegion(center=mp.Vector3(z=+r), size=mp.Vector3(2 * r, 2 * r, 0)),
)

sim.load_minus_flux_data(box_x1, box_x1_data)
sim.load_minus_flux_data(box_x2, box_x2_data)
sim.load_minus_flux_data(box_y1, box_y1_data)
sim.load_minus_flux_data(box_y2, box_y2_data)
sim.load_minus_flux_data(box_z1, box_z1_data)
sim.load_minus_flux_data(box_z2, box_z2_data)

sim.run(until_after_sources=100)

box_x1_flux = mp.get_fluxes(box_x1)
box_x2_flux = mp.get_fluxes(box_x2)
box_y1_flux = mp.get_fluxes(box_y1)
box_y2_flux = mp.get_fluxes(box_y2)
box_z1_flux = mp.get_fluxes(box_z1)
box_z2_flux = mp.get_fluxes(box_z2)

scatt_flux = (
    np.asarray(box_x1_flux)
    - np.asarray(box_x2_flux)
    + np.asarray(box_y1_flux)
    - np.asarray(box_y2_flux)
    + np.asarray(box_z1_flux)
    - np.asarray(box_z2_flux)
)

#intensity = np.asarray(box_x1_flux0) / (2 * r) ** 2
#scatt_cross_section = np.divide(scatt_flux, intensity)
#scatt_eff = scatt_cross_section * -1 / (np.pi * r**2)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 3
#       1 #Mie Scattering of a Gold Sphere
# ----> 3 import meep as mp
#       4 import numpy as np
#       5 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'meep'

# %%
#Plot the scattering efficiency against the spectrum of frequencies we sent toward the sphere:

plt.figure(dpi=150) #dpi is dots per inch. Just changes the resolution of the image of the plot.

#We'll plot wavelength.
#We'll also use a logged scale for both x and y axes (loglog).
plt.plot(1E3/np.asarray(freqs), scatt_flux, "bx-")
plt.grid(True, which="both", ls="-")
plt.xlabel("Wavelength, nm")
plt.ylabel("Scattering Power, W")
plt.title("Mie Scattering of a Lossless Dielectric Sphere")
plt.tight_layout()
plt.savefig(fname="Mie Scattering of a Lossless Dielectric Sphere",
            dpi=150, 
            bbox_inches="tight")
plt.show()

# %%
#Now for gold

import meep as mp
import numpy as np
import matplotlib.pyplot as plt
from typing import Tuple
from scipy.optimize import minimize

#Au material script from complex refractive index data

wvl_data = np.array([250.000000, 260.000000, 270.000000, 280.000000, 290.000000, 300.000000,
                              310.000000, 320.000000, 330.000000, 340.000000, 350.000000, 360.000000,
                              370.000000, 380.000000, 390.000000, 400.000000, 410.000000, 420.000000,
                              430.000000, 440.000000, 450.000000, 460.000000, 470.000000, 480.000000,
                              490.000000, 500.000000, 510.000000, 520.000000, 530.000000, 540.000000,
                              550.000000, 560.000000, 570.000000, 580.000000, 590.000000, 600.000000,
                              610.000000, 620.000000, 630.000000, 640.000000, 650.000000, 660.000000,
                              670.000000, 680.000000, 690.000000, 700.000000, 710.000000, 720.000000,
                              730.000000, 740.000000, 750.000000, 760.000000, 770.000000, 780.000000,
                              790.000000, 800.000000, 810.000000, 820.000000, 830.000000, 840.000000,
                              850.000000, 860.000000, 870.000000, 880.000000, 890.000000, 900.000000,
                              910.000000, 920.000000, 930.000000, 940.000000, 950.000000, 960.000000,
                              970.000000, 980.000000, 990.000000, 1000.000000])

#Refractive index data
n_data = np.array([1.486293, 1.517101, 1.602219, 1.678100, 1.750429, 1.800042, 1.830000, 1.836011,
                   1.813111, 1.781199, 1.751161, 1.726732, 1.706249, 1.687926, 1.670782, 1.658000,
                   1.641467, 1.626593, 1.607286, 1.572004, 1.503407, 1.417996, 1.315496, 1.189871,
                   1.018554, 0.849238, 0.698231, 0.571152, 0.475555, 0.397920, 0.355713, 0.318417,
                   0.295010, 0.278152, 0.261664, 0.245531, 0.229740, 0.214278, 0.199131, 0.184288,
                   0.169737, 0.164060, 0.162125, 0.160792, 0.160087, 0.160906, 0.161863, 0.162930,
                   0.164154, 0.166357, 0.168557, 0.170750, 0.172934, 0.175425, 0.178189, 0.180917,
                   0.183609, 0.186265, 0.189334, 0.193206, 0.197006, 0.200737, 0.204403, 0.208008,
                   0.211773, 0.215750, 0.219658, 0.223500, 0.227279, 0.230997, 0.234659, 0.239028,
                   0.243770, 0.248435, 0.253026, 0.257546])

#Absorption coefficient data (imaginary coefficient of complex refractive index)
k_data = np.array([1.660980, 1.759202, 1.824512, 1.873471, 1.904443, 1.919298, 1.916000, 1.897531,
                   1.870450, 1.852625, 1.847116, 1.855697, 1.883198, 1.916907, 1.939990, 1.956000,
                   1.957488, 1.949527, 1.934151, 1.910625, 1.878436, 1.843614, 1.814717, 1.799925,
                   1.820950, 1.892178, 2.027084, 2.185897, 2.374957, 2.553141, 2.695668, 2.832206,
                   2.899935, 2.930925, 2.961718, 2.992315, 3.022714, 3.052916, 3.082919, 3.112725,
                   3.142334, 3.293285, 3.477580, 3.652616, 3.817434, 3.959739, 4.097111, 4.230027,
                   4.358280, 4.474892, 4.588542, 4.699445, 4.807792, 4.914824, 5.020584, 5.124162,
                   5.225688, 5.325278, 5.419440, 5.505117, 5.589481, 5.672590, 5.754499, 5.835259,
                   5.919898, 6.009588, 6.097960, 6.185070, 6.270970, 6.355709, 6.439333, 6.519685,
                   6.597783, 6.674968, 6.751271, 6.826722])


#Fit the data to Lorentz Function and generate Au material

def lorentzfunc(p: np.ndarray, x: np.ndarray) -> np.ndarray:
    """
    Returns the complex ε profile given a set of Lorentzian parameters p
    (σ_0, ω_0, γ_0, σ_1, ω_1, γ_1, ...) for a set of frequencies x.
    """
    N = len(p) // 3
    y = np.zeros(len(x))
    for n in range(N):
        A_n, x_n, g_n = p[3 * n : 3 * n + 3]
        y = y + A_n / (np.square(x_n) - np.square(x) - 1j * x * g_n)
    return y


def lorentzerr(p: np.ndarray, x: np.ndarray, y: np.ndarray) -> float:
    """
    Returns the error (or residual or loss) as the L2 norm
    of the difference of ε(p,x) and y over a set of frequencies x.
    """
    yp = lorentzfunc(p, x)
    val = np.sum(np.square(abs(y - yp)))
    return val


def lorentzfit(
    p0: np.ndarray,
    x: np.ndarray,
    y: np.ndarray,
    tol: float = 1e-25,
    maxeval: float = 10000,
) -> Tuple[np.ndarray, float]:
    """
    Returns the optimal Lorentzian polarizability parameters and error
    which minimize the error in ε(p0,x) relative to y for an initial
    set of Lorentzian polarizability parameters p0 over a set of
    frequencies x using the scipy.optimize algorithm for a relative
    tolerance tol and a maximum number of iterations maxeval.
    """
    result = minimize(
        lambda p: lorentzerr(p, x, y),
        p0,
        method="L-BFGS-B",
        options={"ftol": tol, "maxiter": maxeval},
    )
    popt = result.x
    minf = result.fun
    return popt, minf


if __name__ == "__main__":
    
    n = n_data[:] + 1j * k_data[:]
    eps_inf = 1.1

    eps = np.square(n) - eps_inf

    wl = wvl_data[:]
    wl_min = 250  # minimum wavelength (units of nm)
    wl_max = 1000  # maximum wavelength (units of nm)
    start_idx = np.where(wl > wl_min)
    idx_start = start_idx[0][0]
    end_idx = np.where(wl < wl_max)
    idx_end = end_idx[0][-1] + 1

    # The fitting function is ε(f) where f is the frequency, rather than ε(λ).
    freqs = 1000 / wl  # units of 1/μm
    freqs_reduced = freqs[idx_start:idx_end]
    wl_reduced = wl[idx_start:idx_end]
    eps_reduced = eps[idx_start:idx_end]

    # Fitting parameter: number of Lorentzian terms to use in the fit
    num_lorentzians = 2

    # Number of times to repeat local optimization with random initial values.
    num_repeat = 30

    ps = np.zeros((num_repeat, 3 * num_lorentzians))
    mins = np.zeros(num_repeat)
    for m in range(num_repeat):
        # Initial values for the Lorentzian polarizability terms. Each term
        # consists of three parameters (σ, ω, γ) and is chosen randomly.
        # Note: for the case of no absorption, γ should be set to zero.
        p_rand = [10 ** (np.random.random()) for _ in range(3 * num_lorentzians)]
        ps[m, :], mins[m] = lorentzfit(p_rand, freqs_reduced, eps_reduced, 1e-25, 50000)
        ps_str = "( " + ", ".join(f"{prm:.4f}" for prm in ps[m, :]) + " )"
        print(f"iteration:, {m:3d}, ps_str, {mins[m]:.6f}")

    # Find the best performing set of parameters.
    idx_opt = np.argmin(mins)
    popt_str = "( " + ", ".join(f"{prm:.4f}" for prm in ps[idx_opt]) + " )"
    print(f"optimal:, {popt_str}, {mins[idx_opt]:.6f}")

    # Define a `Medium` class object using the optimal fitting parameters.
    E_susceptibilities = []

    for n in range(num_lorentzians):
        mymaterial_freq, mymaterial_gamma = ps[idx_opt][3 * n + 1:3 * n + 3]

        if mymaterial_freq == 0:
            mymaterial_sigma = ps[idx_opt][3 * n + 0] / 1.0**2
            E_susceptibilities.append(
                mp.DrudeSusceptibility(
                    frequency=1.0, gamma=mymaterial_gamma, sigma=mymaterial_sigma
                )
            )
        else:
            mymaterial_sigma = ps[idx_opt][3 * n + 0] / mymaterial_freq**2
            E_susceptibilities.append(
                mp.LorentzianSusceptibility(
                    frequency=mymaterial_freq,
                    gamma=mymaterial_gamma,
                    sigma=mymaterial_sigma,
                )
            )

    Au = mp.Medium(epsilon=eps_inf, E_susceptibilities=E_susceptibilities)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 #Now for gold
# ----> 3 import meep as mp
#       4 import numpy as np
#       5 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'meep'

# %%
import meep as mp
import numpy as np
import matplotlib.pyplot as plt
from meep.materials import Au

r = 50E-3  # radius of sphere

wvl_min = 300E-3
wvl_max = 800E-3

frq_min = 1 / wvl_max
frq_max = 1 / wvl_min
frq_cen = 0.5 * (frq_min + frq_max)
dfrq = frq_max - frq_min
nfrq = 100

## at least 8 pixels per smallest wavelength, i.e. np.floor(8/wvl_min)
resolution = 25/r

dpml = 2*r
dair = 2*r

pml_layers = [mp.PML(thickness=dpml)]

symmetries = [mp.Mirror(mp.Y), mp.Mirror(mp.Z, phase=-1)]

s = 2 * (dpml + dair + r)
cell_size = mp.Vector3(s, s, s)

# is_integrated=True necessary for any planewave source extending into PML
sources = [
    mp.Source(
        mp.GaussianSource(frq_cen, fwidth=dfrq, is_integrated=True),
        center=mp.Vector3(-0.5 * s + dpml),
        size=mp.Vector3(0, s, s),
        component=mp.Ez,
    )
]

sim = mp.Simulation(
    resolution=resolution,
    cell_size=cell_size,
    boundary_layers=pml_layers,
    sources=sources,
    k_point=mp.Vector3(),
    symmetries=symmetries,
)

box_x1 = sim.add_flux(
    frq_cen,
    dfrq,
    nfrq,
    mp.FluxRegion(center=mp.Vector3(x=-r), size=mp.Vector3(0, 2 * r, 2 * r)),
)
box_x2 = sim.add_flux(
    frq_cen,
    dfrq,
    nfrq,
    mp.FluxRegion(center=mp.Vector3(x=+r), size=mp.Vector3(0, 2 * r, 2 * r)),
)
box_y1 = sim.add_flux(
    frq_cen,
    dfrq,
    nfrq,
    mp.FluxRegion(center=mp.Vector3(y=-r), size=mp.Vector3(2 * r, 0, 2 * r)),
)
box_y2 = sim.add_flux(
    frq_cen,
    dfrq,
    nfrq,
    mp.FluxRegion(center=mp.Vector3(y=+r), size=mp.Vector3(2 * r, 0, 2 * r)),
)
box_z1 = sim.add_flux(
    frq_cen,
    dfrq,
    nfrq,
    mp.FluxRegion(center=mp.Vector3(z=-r), size=mp.Vector3(2 * r, 2 * r, 0)),
)
box_z2 = sim.add_flux(
    frq_cen,
    dfrq,
    nfrq,
    mp.FluxRegion(center=mp.Vector3(z=+r), size=mp.Vector3(2 * r, 2 * r, 0)),
)

sim.run(until_after_sources=10)

freqs = mp.get_flux_freqs(box_x1)
box_x1_data = sim.get_flux_data(box_x1)
box_x2_data = sim.get_flux_data(box_x2)
box_y1_data = sim.get_flux_data(box_y1)
box_y2_data = sim.get_flux_data(box_y2)
box_z1_data = sim.get_flux_data(box_z1)
box_z2_data = sim.get_flux_data(box_z2)

box_x1_flux0 = mp.get_fluxes(box_x1)

sim.reset_meep()







geometry = [mp.Sphere(material=Au, center=mp.Vector3(), radius=r)
           ]

sim = mp.Simulation(
    resolution=resolution,
    cell_size=cell_size,
    boundary_layers=pml_layers,
    sources=sources,
    k_point=mp.Vector3(),
    symmetries=symmetries,
    geometry=geometry,
)

box_x1 = sim.add_flux(
    frq_cen,
    dfrq,
    nfrq,
    mp.FluxRegion(center=mp.Vector3(x=-r), size=mp.Vector3(0, 2 * r, 2 * r)),
)
box_x2 = sim.add_flux(
    frq_cen,
    dfrq,
    nfrq,
    mp.FluxRegion(center=mp.Vector3(x=+r), size=mp.Vector3(0, 2 * r, 2 * r)),
)
box_y1 = sim.add_flux(
    frq_cen,
    dfrq,
    nfrq,
    mp.FluxRegion(center=mp.Vector3(y=-r), size=mp.Vector3(2 * r, 0, 2 * r)),
)
box_y2 = sim.add_flux(
    frq_cen,
    dfrq,
    nfrq,
    mp.FluxRegion(center=mp.Vector3(y=+r), size=mp.Vector3(2 * r, 0, 2 * r)),
)
box_z1 = sim.add_flux(
    frq_cen,
    dfrq,
    nfrq,
    mp.FluxRegion(center=mp.Vector3(z=-r), size=mp.Vector3(2 * r, 2 * r, 0)),
)
box_z2 = sim.add_flux(
    frq_cen,
    dfrq,
    nfrq,
    mp.FluxRegion(center=mp.Vector3(z=+r), size=mp.Vector3(2 * r, 2 * r, 0)),
)

sim.load_minus_flux_data(box_x1, box_x1_data)
sim.load_minus_flux_data(box_x2, box_x2_data)
sim.load_minus_flux_data(box_y1, box_y1_data)
sim.load_minus_flux_data(box_y2, box_y2_data)
sim.load_minus_flux_data(box_z1, box_z1_data)
sim.load_minus_flux_data(box_z2, box_z2_data)

sim.run(until_after_sources=100)

box_x1_flux = mp.get_fluxes(box_x1)
box_x2_flux = mp.get_fluxes(box_x2)
box_y1_flux = mp.get_fluxes(box_y1)
box_y2_flux = mp.get_fluxes(box_y2)
box_z1_flux = mp.get_fluxes(box_z1)
box_z2_flux = mp.get_fluxes(box_z2)

scatt_flux = (
    np.asarray(box_x1_flux)
    - np.asarray(box_x2_flux)
    + np.asarray(box_y1_flux)
    - np.asarray(box_y2_flux)
    + np.asarray(box_z1_flux)
    - np.asarray(box_z2_flux)
)

#intensity = np.asarray(box_x1_flux0) / (2 * r) ** 2
#scatt_cross_section = np.divide(scatt_flux, intensity)
#scatt_eff = scatt_cross_section * -1 / (np.pi * r**2)
# Out:
# -----------
# Initializing structure...
# Halving computational cell along direction y
# Halving computational cell along direction z
# time for choose_chunkdivision = 0.00216007 s
# Working in 3D dimensions.
# Computational cell is 0.5 x 0.5 x 0.5 with resolution 500
# time for set_epsilon = 10.1533 s
# -----------
# Meep progress: 0.001/14.800000190734863 = 0.0% done in 8.8s, 129912.8s to go
# on time step 1 (time=0.001), 8.77867 s/step
# Meep progress: 0.03/14.800000190734863 = 0.2% done in 12.8s, 6291.7s to go
# on time step 31 (time=0.031), 0.137792 s/step
# Meep progress: 0.059000000000000004/14.800000190734863 = 0.4% done in 16.8s, 4207.8s to go
# on time step 60 (time=0.06), 0.140076 s/step
# Meep progress: 0.088/14.800000190734863 = 0.6% done in 21.0s, 3509.2s to go
# on time step 88 (time=0.088), 0.143348 s/step
# Meep progress: 0.117/14.800000190734863 = 0.8% done in 25.1s, 3143.7s to go
# on time step 117 (time=0.117), 0.139958 s/step
# Meep progress: 0.146/14.800000190734863 = 1.0% done in 29.1s, 2916.3s to go
# on time step 146 (time=0.146), 0.138092 s/step
# Meep progress: 0.17300000000000001/14.800000190734863 = 1.2% done in 33.1s, 2798.0s to go
# on time step 173 (time=0.173), 0.149519 s/step
# Meep progress: 0.202/14.800000190734863 = 1.4% done in 37.2s, 2686.7s to go
# on time step 202 (time=0.202), 0.140816 s/step
# Meep progress: 0.231/14.800000190734863 = 1.6% done in 41.2s, 2597.8s to go
# on time step 231 (time=0.231), 0.138294 s/step
# Meep progress: 0.259/14.800000190734863 = 1.7% done in 45.4s, 2546.4s to go
# on time step 259 (time=0.259), 0.148788 s/step
# Meep progress: 0.28600000000000003/14.800000190734863 = 1.9% done in 49.4s, 2507.8s to go
# on time step 286 (time=0.286), 0.150359 s/step
# Meep progress: 0.316/14.800000190734863 = 2.1% done in 53.5s, 2453.7s to go
# on time step 316 (time=0.316), 0.137201 s/step
# Meep progress: 0.34500000000000003/14.800000190734863 = 2.3% done in 57.5s, 2411.2s to go
# on time step 345 (time=0.345), 0.138425 s/step
# Meep progress: 0.374/14.800000190734863 = 2.5% done in 61.6s, 2376.4s to go
# on time step 374 (time=0.374), 0.140013 s/step
# Meep progress: 0.401/14.800000190734863 = 2.7% done in 65.6s, 2356.7s to go
# on time step 401 (time=0.401), 0.148936 s/step
# Meep progress: 0.43/14.800000190734863 = 2.9% done in 69.8s, 2331.5s to go
# on time step 430 (time=0.43), 0.142517 s/step
# Meep progress: 0.46/14.800000190734863 = 3.1% done in 73.9s, 2303.5s to go
# on time step 460 (time=0.46), 0.137567 s/step
# Meep progress: 0.489/14.800000190734863 = 3.3% done in 78.1s, 2285.1s to go
# on time step 489 (time=0.489), 0.144377 s/step
# Meep progress: 0.516/14.800000190734863 = 3.5% done in 82.1s, 2273.6s to go
# on time step 516 (time=0.516), 0.149946 s/step
# Meep progress: 0.541/14.800000190734863 = 3.7% done in 86.2s, 2271.2s to go
# on time step 541 (time=0.541), 0.161654 s/step
# Meep progress: 0.5680000000000001/14.800000190734863 = 3.8% done in 90.4s, 2264.2s to go
# on time step 568 (time=0.568), 0.155125 s/step
# Meep progress: 0.593/14.800000190734863 = 4.0% done in 94.5s, 2263.6s to go
# on time step 593 (time=0.593), 0.164835 s/step
# Meep progress: 0.621/14.800000190734863 = 4.2% done in 98.6s, 2250.3s to go
# on time step 621 (time=0.621), 0.145449 s/step
# Meep progress: 0.651/14.800000190734863 = 4.4% done in 102.7s, 2231.6s to go
# on time step 651 (time=0.651), 0.137208 s/step
# Meep progress: 0.68/14.800000190734863 = 4.6% done in 106.8s, 2216.7s to go
# on time step 680 (time=0.68), 0.140548 s/step
# Meep progress: 0.708/14.800000190734863 = 4.8% done in 110.8s, 2204.6s to go
# on time step 708 (time=0.708), 0.143232 s/step
# Meep progress: 0.737/14.800000190734863 = 5.0% done in 114.9s, 2191.5s to go
# on time step 737 (time=0.737), 0.140939 s/step
# Meep progress: 0.766/14.800000190734863 = 5.2% done in 118.9s, 2178.0s to go
# on time step 766 (time=0.766), 0.138885 s/step
# Meep progress: 0.795/14.800000190734863 = 5.4% done in 123.0s, 2166.0s to go
# on time step 795 (time=0.795), 0.140348 s/step
# Meep progress: 0.8240000000000001/14.800000190734863 = 5.6% done in 127.0s, 2154.2s to go
# on time step 824 (time=0.824), 0.139786 s/step
# Meep progress: 0.853/14.800000190734863 = 5.8% done in 131.1s, 2143.1s to go
# on time step 853 (time=0.853), 0.140135 s/step
# Meep progress: 0.882/14.800000190734863 = 6.0% done in 135.2s, 2133.5s to go
# on time step 882 (time=0.882), 0.142375 s/step
# Meep progress: 0.911/14.800000190734863 = 6.2% done in 139.4s, 2124.9s to go
# on time step 911 (time=0.911), 0.143937 s/step
# Meep progress: 0.9390000000000001/14.800000190734863 = 6.3% done in 143.5s, 2118.5s to go
# on time step 939 (time=0.939), 0.147752 s/step
# Meep progress: 0.965/14.800000190734863 = 6.5% done in 147.6s, 2115.9s to go
# on time step 965 (time=0.965), 0.15654 s/step
# Meep progress: 0.991/14.800000190734863 = 6.7% done in 151.7s, 2113.3s to go
# on time step 991 (time=0.991), 0.156682 s/step
# Meep progress: 1.018/14.800000190734863 = 6.9% done in 155.7s, 2108.0s to go
# on time step 1018 (time=1.018), 0.149972 s/step
# Meep progress: 1.047/14.800000190734863 = 7.1% done in 159.8s, 2099.1s to go
# on time step 1047 (time=1.047), 0.141149 s/step
# Meep progress: 1.077/14.800000190734863 = 7.3% done in 163.9s, 2088.8s to go
# on time step 1077 (time=1.077), 0.137549 s/step
# Meep progress: 1.106/14.800000190734863 = 7.5% done in 168.0s, 2079.8s to go
# on time step 1106 (time=1.106), 0.13933 s/step
# Meep progress: 1.1360000000000001/14.800000190734863 = 7.7% done in 172.1s, 2070.1s to go
# on time step 1136 (time=1.136), 0.137686 s/step
# Meep progress: 1.166/14.800000190734863 = 7.9% done in 176.2s, 2060.4s to go
# on time step 1166 (time=1.166), 0.136673 s/step
# Meep progress: 1.194/14.800000190734863 = 8.1% done in 180.3s, 2054.2s to go
# on time step 1194 (time=1.194), 0.145134 s/step
# Meep progress: 1.223/14.800000190734863 = 8.3% done in 184.3s, 2046.4s to go
# on time step 1223 (time=1.223), 0.140215 s/step
# Meep progress: 1.252/14.800000190734863 = 8.5% done in 188.4s, 2038.5s to go
# on time step 1252 (time=1.252), 0.139604 s/step
# Meep progress: 1.282/14.800000190734863 = 8.7% done in 192.5s, 2029.3s to go
# on time step 1282 (time=1.282), 0.135486 s/step
# Meep progress: 1.312/14.800000190734863 = 8.9% done in 196.6s, 2021.0s to go
# on time step 1312 (time=1.312), 0.137681 s/step
# Meep progress: 1.342/14.800000190734863 = 9.1% done in 200.7s, 2012.3s to go
# on time step 1342 (time=1.342), 0.136028 s/step
# Meep progress: 1.373/14.800000190734863 = 9.3% done in 204.8s, 2002.6s to go
# on time step 1373 (time=1.373), 0.132562 s/step
# Meep progress: 1.4020000000000001/14.800000190734863 = 9.5% done in 208.9s, 1995.8s to go
# on time step 1402 (time=1.402), 0.140516 s/step
# Meep progress: 1.431/14.800000190734863 = 9.7% done in 212.9s, 1989.2s to go
# on time step 1431 (time=1.431), 0.140227 s/step
# Meep progress: 1.46/14.800000190734863 = 9.9% done in 217.0s, 1983.0s to go
# on time step 1460 (time=1.46), 0.141707 s/step
# Meep progress: 1.49/14.800000190734863 = 10.1% done in 221.1s, 1975.4s to go
# on time step 1490 (time=1.49), 0.136841 s/step
# Meep progress: 1.5190000000000001/14.800000190734863 = 10.3% done in 225.1s, 1968.4s to go
# on time step 1519 (time=1.519), 0.13798 s/step
# Meep progress: 1.549/14.800000190734863 = 10.5% done in 229.2s, 1960.6s to go
# on time step 1549 (time=1.549), 0.135129 s/step
# Meep progress: 1.579/14.800000190734863 = 10.7% done in 233.2s, 1952.6s to go
# on time step 1579 (time=1.579), 0.133589 s/step
# Meep progress: 1.609/14.800000190734863 = 10.9% done in 237.3s, 1945.4s to go
# on time step 1609 (time=1.609), 0.13637 s/step
# Meep progress: 1.639/14.800000190734863 = 11.1% done in 241.4s, 1938.3s to go
# on time step 1639 (time=1.639), 0.136236 s/step
# Meep progress: 1.668/14.800000190734863 = 11.3% done in 245.5s, 1932.5s to go
# on time step 1668 (time=1.668), 0.140621 s/step
# Meep progress: 1.698/14.800000190734863 = 11.5% done in 249.5s, 1925.2s to go
# on time step 1698 (time=1.698), 0.135006 s/step
# Meep progress: 1.728/14.800000190734863 = 11.7% done in 253.6s, 1918.1s to go
# on time step 1728 (time=1.728), 0.13469 s/step
# Meep progress: 1.7570000000000001/14.800000190734863 = 11.9% done in 257.6s, 1912.3s to go
# on time step 1757 (time=1.757), 0.139819 s/step
# Meep progress: 1.788/14.800000190734863 = 12.1% done in 261.7s, 1904.5s to go
# on time step 1788 (time=1.788), 0.132188 s/step
# Meep progress: 1.818/14.800000190734863 = 12.3% done in 265.7s, 1897.4s to go
# on time step 1818 (time=1.818), 0.133547 s/step
# Meep progress: 1.847/14.800000190734863 = 12.5% done in 269.8s, 1892.2s to go
# on time step 1847 (time=1.847), 0.141484 s/step
# Meep progress: 1.874/14.800000190734863 = 12.7% done in 273.9s, 1888.9s to go
# on time step 1874 (time=1.874), 0.149573 s/step
# Meep progress: 1.899/14.800000190734863 = 12.8% done in 278.0s, 1888.4s to go
# on time step 1899 (time=1.899), 0.164682 s/step
# Meep progress: 1.923/14.800000190734863 = 13.0% done in 282.1s, 1889.0s to go
# on time step 1923 (time=1.923), 0.17152 s/step
# Meep progress: 1.947/14.800000190734863 = 13.2% done in 286.1s, 1888.8s to go
# on time step 1947 (time=1.947), 0.167793 s/step
# Meep progress: 1.973/14.800000190734863 = 13.3% done in 290.3s, 1887.0s to go
# on time step 1973 (time=1.973), 0.158869 s/step
# Meep progress: 1.999/14.800000190734863 = 13.5% done in 294.4s, 1885.1s to go
# on time step 1999 (time=1.999), 0.158745 s/step
# Meep progress: 2.024/14.800000190734863 = 13.7% done in 298.5s, 1884.5s to go
# on time step 2024 (time=2.024), 0.166497 s/step
# Meep progress: 2.049/14.800000190734863 = 13.8% done in 302.7s, 1883.5s to go
# on time step 2049 (time=2.049), 0.16496 s/step
# Meep progress: 2.074/14.800000190734863 = 14.0% done in 306.8s, 1882.8s to go
# on time step 2074 (time=2.074), 0.166705 s/step
# Meep progress: 2.099/14.800000190734863 = 14.2% done in 310.8s, 1880.9s to go
# on time step 2099 (time=2.099), 0.160278 s/step
# Meep progress: 2.125/14.800000190734863 = 14.4% done in 314.9s, 1878.4s to go
# on time step 2125 (time=2.125), 0.156721 s/step
# Meep progress: 2.148/14.800000190734863 = 14.5% done in 318.9s, 1878.6s to go
# on time step 2148 (time=2.148), 0.17458 s/step
# Meep progress: 2.173/14.800000190734863 = 14.7% done in 323.0s, 1877.1s to go
# on time step 2173 (time=2.173), 0.163765 s/step
# Meep progress: 2.201/14.800000190734863 = 14.9% done in 327.1s, 1872.3s to go
# on time step 2201 (time=2.201), 0.144499 s/step
# Meep progress: 2.229/14.800000190734863 = 15.1% done in 331.2s, 1868.0s to go
# on time step 2229 (time=2.229), 0.14784 s/step
# Meep progress: 2.258/14.800000190734863 = 15.3% done in 335.2s, 1862.1s to go
# on time step 2258 (time=2.258), 0.138678 s/step
# Meep progress: 2.287/14.800000190734863 = 15.5% done in 339.4s, 1856.8s to go
# on time step 2287 (time=2.287), 0.142213 s/step
# Meep progress: 2.316/14.800000190734863 = 15.6% done in 343.5s, 1851.5s to go
# on time step 2316 (time=2.316), 0.142106 s/step
# Meep progress: 2.341/14.800000190734863 = 15.8% done in 347.6s, 1849.8s to go
# on time step 2341 (time=2.341), 0.163461 s/step
# Meep progress: 2.368/14.800000190734863 = 16.0% done in 351.7s, 1846.4s to go
# on time step 2368 (time=2.368), 0.15225 s/step
# Meep progress: 2.392/14.800000190734863 = 16.2% done in 355.7s, 1845.2s to go
# on time step 2392 (time=2.392), 0.167884 s/step
# Meep progress: 2.418/14.800000190734863 = 16.3% done in 359.9s, 1842.7s to go
# on time step 2418 (time=2.418), 0.158901 s/step
# Meep progress: 2.439/14.800000190734863 = 16.5% done in 364.0s, 1844.9s to go
# on time step 2439 (time=2.439), 0.198947 s/step
# Meep progress: 2.46/14.800000190734863 = 16.6% done in 368.0s, 1846.2s to go
# on time step 2461 (time=2.461), 0.189833 s/step
# Meep progress: 2.482/14.800000190734863 = 16.8% done in 372.2s, 1847.1s to go
# on time step 2483 (time=2.483), 0.191454 s/step
# Meep progress: 2.507/14.800000190734863 = 16.9% done in 376.3s, 1844.9s to go
# on time step 2509 (time=2.509), 0.158112 s/step
# Meep progress: 2.533/14.800000190734863 = 17.1% done in 380.3s, 1841.5s to go
# on time step 2536 (time=2.536), 0.154307 s/step
# Meep progress: 2.56/14.800000190734863 = 17.3% done in 384.3s, 1837.4s to go
# on time step 2564 (time=2.564), 0.146924 s/step
# Meep progress: 2.587/14.800000190734863 = 17.5% done in 388.4s, 1833.7s to go
# on time step 2591 (time=2.591), 0.153037 s/step
# Meep progress: 2.616/14.800000190734863 = 17.7% done in 392.5s, 1828.3s to go
# on time step 2619 (time=2.619), 0.144738 s/step
# Meep progress: 2.642/14.800000190734863 = 17.9% done in 396.7s, 1825.3s to go
# on time step 2645 (time=2.645), 0.158846 s/step
# Meep progress: 2.669/14.800000190734863 = 18.0% done in 400.7s, 1821.3s to go
# on time step 2672 (time=2.672), 0.14829 s/step
# Meep progress: 2.699/14.800000190734863 = 18.2% done in 404.8s, 1815.1s to go
# on time step 2701 (time=2.701), 0.138661 s/step
# Meep progress: 2.727/14.800000190734863 = 18.4% done in 409.0s, 1810.8s to go
# on time step 2729 (time=2.729), 0.147307 s/step
# Meep progress: 2.755/14.800000190734863 = 18.6% done in 413.1s, 1806.2s to go
# on time step 2757 (time=2.757), 0.146277 s/step
# Meep progress: 2.785/14.800000190734863 = 18.8% done in 417.1s, 1799.7s to go
# on time step 2787 (time=2.787), 0.136204 s/step
# Meep progress: 2.8120000000000003/14.800000190734863 = 19.0% done in 421.3s, 1796.0s to go
# on time step 2814 (time=2.814), 0.152345 s/step
# Meep progress: 2.839/14.800000190734863 = 19.2% done in 425.4s, 1792.3s to go
# on time step 2841 (time=2.841), 0.151497 s/step
# Meep progress: 2.866/14.800000190734863 = 19.4% done in 429.5s, 1788.4s to go
# on time step 2868 (time=2.868), 0.151503 s/step
# Meep progress: 2.891/14.800000190734863 = 19.5% done in 433.6s, 1786.1s to go
# on time step 2893 (time=2.893), 0.165037 s/step
# Meep progress: 2.918/14.800000190734863 = 19.7% done in 437.7s, 1782.2s to go
# on time step 2920 (time=2.92), 0.151647 s/step
# Meep progress: 2.945/14.800000190734863 = 19.9% done in 441.7s, 1778.1s to go
# on time step 2947 (time=2.947), 0.148154 s/step
# Meep progress: 2.973/14.800000190734863 = 20.1% done in 445.8s, 1773.3s to go
# on time step 2975 (time=2.975), 0.144898 s/step
# Meep progress: 3.0/14.800000190734863 = 20.3% done in 449.8s, 1769.2s to go
# on time step 3002 (time=3.002), 0.148439 s/step
# Meep progress: 3.027/14.800000190734863 = 20.5% done in 453.9s, 1765.4s to go
# on time step 3029 (time=3.029), 0.155178 s/step
# Meep progress: 3.0540000000000003/14.800000190734863 = 20.6% done in 458.0s, 1761.7s to go
# on time step 3056 (time=3.056), 0.152021 s/step
# Meep progress: 3.082/14.800000190734863 = 20.8% done in 462.1s, 1757.1s to go
# on time step 3084 (time=3.084), 0.145542 s/step
# Meep progress: 3.108/14.800000190734863 = 21.0% done in 466.2s, 1754.0s to go
# on time step 3110 (time=3.11), 0.158838 s/step
# Meep progress: 3.134/14.800000190734863 = 21.2% done in 470.3s, 1750.7s to go
# on time step 3136 (time=3.136), 0.154131 s/step
# Meep progress: 3.164/14.800000190734863 = 21.4% done in 474.3s, 1744.5s to go
# on time step 3166 (time=3.166), 0.134903 s/step
# Meep progress: 3.1910000000000003/14.800000190734863 = 21.6% done in 478.4s, 1740.3s to go
# on time step 3193 (time=3.193), 0.149277 s/step
# Meep progress: 3.217/14.800000190734863 = 21.7% done in 482.5s, 1737.2s to go
# on time step 3219 (time=3.219), 0.157414 s/step
# Meep progress: 3.247/14.800000190734863 = 21.9% done in 486.6s, 1731.2s to go
# on time step 3249 (time=3.249), 0.137015 s/step
# Meep progress: 3.275/14.800000190734863 = 22.1% done in 490.6s, 1726.6s to go
# on time step 3277 (time=3.277), 0.144387 s/step
# Meep progress: 3.3040000000000003/14.800000190734863 = 22.3% done in 494.7s, 1721.4s to go
# on time step 3306 (time=3.306), 0.140774 s/step
# Meep progress: 3.334/14.800000190734863 = 22.5% done in 498.9s, 1715.7s to go
# on time step 3335 (time=3.335), 0.139342 s/step
# Meep progress: 3.361/14.800000190734863 = 22.7% done in 502.9s, 1711.7s to go
# on time step 3362 (time=3.362), 0.149723 s/step
# Meep progress: 3.387/14.800000190734863 = 22.9% done in 506.9s, 1708.2s to go
# on time step 3388 (time=3.388), 0.154335 s/step
# Meep progress: 3.412/14.800000190734863 = 23.1% done in 511.0s, 1705.6s to go
# on time step 3413 (time=3.413), 0.164648 s/step
# Meep progress: 3.436/14.800000190734863 = 23.2% done in 515.2s, 1703.8s to go
# on time step 3437 (time=3.437), 0.170842 s/step
# Meep progress: 3.462/14.800000190734863 = 23.4% done in 519.2s, 1700.3s to go
# on time step 3463 (time=3.463), 0.15475 s/step
# Meep progress: 3.488/14.800000190734863 = 23.6% done in 523.2s, 1696.9s to go
# on time step 3489 (time=3.489), 0.155918 s/step
# Meep progress: 3.5140000000000002/14.800000190734863 = 23.7% done in 527.3s, 1693.7s to go
# on time step 3515 (time=3.515), 0.158983 s/step
# Meep progress: 3.539/14.800000190734863 = 23.9% done in 531.4s, 1690.9s to go
# on time step 3540 (time=3.54), 0.161973 s/step
# Meep progress: 3.564/14.800000190734863 = 24.1% done in 535.5s, 1688.4s to go
# on time step 3565 (time=3.565), 0.164516 s/step
# Meep progress: 3.589/14.800000190734863 = 24.2% done in 539.6s, 1685.7s to go
# on time step 3590 (time=3.59), 0.165661 s/step
# Meep progress: 3.616/14.800000190734863 = 24.4% done in 543.7s, 1681.8s to go
# on time step 3617 (time=3.617), 0.150206 s/step
# Meep progress: 3.642/14.800000190734863 = 24.6% done in 547.7s, 1678.1s to go
# on time step 3643 (time=3.643), 0.153974 s/step
# Meep progress: 3.67/14.800000190734863 = 24.8% done in 551.9s, 1673.6s to go
# on time step 3671 (time=3.671), 0.147204 s/step
# Meep progress: 3.6950000000000003/14.800000190734863 = 25.0% done in 555.9s, 1670.8s to go
# on time step 3696 (time=3.696), 0.162801 s/step
# Meep progress: 3.724/14.800000190734863 = 25.2% done in 560.1s, 1665.8s to go
# on time step 3724 (time=3.724), 0.143005 s/step
# Meep progress: 3.751/14.800000190734863 = 25.3% done in 564.1s, 1661.6s to go
# on time step 3751 (time=3.751), 0.148345 s/step
# Meep progress: 3.779/14.800000190734863 = 25.5% done in 568.2s, 1657.1s to go
# on time step 3779 (time=3.779), 0.14696 s/step
# Meep progress: 3.809/14.800000190734863 = 25.7% done in 572.3s, 1651.4s to go
# on time step 3809 (time=3.809), 0.136616 s/step
# Meep progress: 3.838/14.800000190734863 = 25.9% done in 576.4s, 1646.4s to go
# on time step 3838 (time=3.838), 0.141922 s/step
# Meep progress: 3.867/14.800000190734863 = 26.1% done in 580.5s, 1641.1s to go
# on time step 3867 (time=3.867), 0.139101 s/step
# Meep progress: 3.896/14.800000190734863 = 26.3% done in 584.5s, 1636.0s to go
# on time step 3896 (time=3.896), 0.140293 s/step
# Meep progress: 3.923/14.800000190734863 = 26.5% done in 588.6s, 1631.9s to go
# on time step 3923 (time=3.923), 0.149977 s/step
# Meep progress: 3.951/14.800000190734863 = 26.7% done in 592.7s, 1627.6s to go
# on time step 3951 (time=3.951), 0.148113 s/step
# Meep progress: 3.978/14.800000190734863 = 26.9% done in 596.8s, 1623.4s to go
# on time step 3978 (time=3.978), 0.149032 s/step
# Meep progress: 4.005/14.800000190734863 = 27.1% done in 600.9s, 1619.7s to go
# on time step 4005 (time=4.005), 0.153691 s/step
# Meep progress: 4.032/14.800000190734863 = 27.2% done in 605.0s, 1615.7s to go
# on time step 4032 (time=4.032), 0.151561 s/step
# Meep progress: 4.059/14.800000190734863 = 27.4% done in 609.0s, 1611.6s to go
# on time step 4059 (time=4.059), 0.148856 s/step
# Meep progress: 4.087/14.800000190734863 = 27.6% done in 613.1s, 1607.0s to go
# on time step 4087 (time=4.087), 0.144828 s/step
# Meep progress: 4.114/14.800000190734863 = 27.8% done in 617.1s, 1603.0s to go
# on time step 4114 (time=4.114), 0.150188 s/step
# Meep progress: 4.1370000000000005/14.800000190734863 = 28.0% done in 621.3s, 1601.3s to go
# on time step 4137 (time=4.137), 0.179621 s/step
# Meep progress: 4.164/14.800000190734863 = 28.1% done in 625.3s, 1597.2s to go
# on time step 4164 (time=4.164), 0.149088 s/step
# Meep progress: 4.191/14.800000190734863 = 28.3% done in 629.3s, 1593.1s to go
# on time step 4191 (time=4.191), 0.149792 s/step
# Meep progress: 4.218/14.800000190734863 = 28.5% done in 633.5s, 1589.2s to go
# on time step 4218 (time=4.218), 0.153358 s/step
# Meep progress: 4.246/14.800000190734863 = 28.7% done in 637.6s, 1584.7s to go
# on time step 4246 (time=4.246), 0.146009 s/step
# Meep progress: 4.273/14.800000190734863 = 28.9% done in 641.6s, 1580.7s to go
# on time step 4273 (time=4.273), 0.150962 s/step
# Meep progress: 4.301/14.800000190734863 = 29.1% done in 645.6s, 1576.1s to go
# on time step 4301 (time=4.301), 0.143169 s/step
# Meep progress: 4.331/14.800000190734863 = 29.3% done in 649.7s, 1570.5s to go
# on time step 4331 (time=4.331), 0.135626 s/step
# Meep progress: 4.359/14.800000190734863 = 29.5% done in 653.8s, 1566.0s to go
# on time step 4359 (time=4.359), 0.145098 s/step
# Meep progress: 4.383/14.800000190734863 = 29.6% done in 657.8s, 1563.5s to go
# on time step 4383 (time=4.383), 0.1687 s/step
# Meep progress: 4.41/14.800000190734863 = 29.8% done in 661.8s, 1559.3s to go
# on time step 4410 (time=4.41), 0.148622 s/step
# Meep progress: 4.436/14.800000190734863 = 30.0% done in 665.9s, 1555.7s to go
# on time step 4436 (time=4.436), 0.155317 s/step
# Meep progress: 4.463/14.800000190734863 = 30.2% done in 669.9s, 1551.6s to go
# on time step 4463 (time=4.463), 0.149056 s/step
# Meep progress: 4.488/14.800000190734863 = 30.3% done in 673.9s, 1548.5s to go
# on time step 4488 (time=4.488), 0.161135 s/step
# Meep progress: 4.515/14.800000190734863 = 30.5% done in 678.1s, 1544.6s to go
# on time step 4515 (time=4.515), 0.152455 s/step
# Meep progress: 4.538/14.800000190734863 = 30.7% done in 682.1s, 1542.5s to go
# on time step 4538 (time=4.538), 0.177075 s/step
# Meep progress: 4.563/14.800000190734863 = 30.8% done in 686.2s, 1539.4s to go
# on time step 4563 (time=4.563), 0.16192 s/step
# Meep progress: 4.589/14.800000190734863 = 31.0% done in 690.3s, 1536.0s to go
# on time step 4589 (time=4.589), 0.158049 s/step
# Meep progress: 4.611/14.800000190734863 = 31.2% done in 694.3s, 1534.2s to go
# on time step 4611 (time=4.611), 0.182998 s/step
# Meep progress: 4.636/14.800000190734863 = 31.3% done in 698.4s, 1531.2s to go
# on time step 4636 (time=4.636), 0.16308 s/step
# Meep progress: 4.66/14.800000190734863 = 31.5% done in 702.4s, 1528.5s to go
# on time step 4660 (time=4.66), 0.168552 s/step
# Meep progress: 4.6770000000000005/14.800000190734863 = 31.6% done in 706.6s, 1529.4s to go
# on time step 4677 (time=4.677), 0.243812 s/step
# Meep progress: 4.695/14.800000190734863 = 31.7% done in 710.6s, 1529.5s to go
# on time step 4695 (time=4.695), 0.225012 s/step
# Meep progress: 4.712/14.800000190734863 = 31.8% done in 714.7s, 1530.1s to go
# on time step 4712 (time=4.712), 0.237902 s/step
# Meep progress: 4.734/14.800000190734863 = 32.0% done in 718.8s, 1528.4s to go
# on time step 4734 (time=4.734), 0.186652 s/step
# Meep progress: 4.761/14.800000190734863 = 32.2% done in 722.9s, 1524.3s to go
# on time step 4761 (time=4.761), 0.151543 s/step
# Meep progress: 4.785/14.800000190734863 = 32.3% done in 726.9s, 1521.4s to go
# on time step 4785 (time=4.785), 0.167794 s/step
# Meep progress: 4.812/14.800000190734863 = 32.5% done in 731.1s, 1517.4s to go
# on time step 4812 (time=4.812), 0.153471 s/step
# Meep progress: 4.837/14.800000190734863 = 32.7% done in 735.2s, 1514.4s to go
# on time step 4837 (time=4.837), 0.166212 s/step
# Meep progress: 4.864/14.800000190734863 = 32.9% done in 739.4s, 1510.4s to go
# on time step 4864 (time=4.864), 0.154247 s/step
# Meep progress: 4.894/14.800000190734863 = 33.1% done in 743.4s, 1504.8s to go
# on time step 4894 (time=4.894), 0.13474 s/step
# Meep progress: 4.922/14.800000190734863 = 33.3% done in 747.5s, 1500.2s to go
# on time step 4922 (time=4.922), 0.147078 s/step
# Meep progress: 4.948/14.800000190734863 = 33.4% done in 751.7s, 1496.7s to go
# on time step 4948 (time=4.948), 0.158952 s/step
# Meep progress: 4.9670000000000005/14.800000190734863 = 33.6% done in 755.8s, 1496.2s to go
# on time step 4967 (time=4.967), 0.215699 s/step
# Meep progress: 4.9910000000000005/14.800000190734863 = 33.7% done in 759.9s, 1493.5s to go
# on time step 4991 (time=4.991), 0.172322 s/step
# Meep progress: 5.014/14.800000190734863 = 33.9% done in 763.9s, 1491.0s to go
# on time step 5014 (time=5.014), 0.175185 s/step
# Meep progress: 5.037/14.800000190734863 = 34.0% done in 767.9s, 1488.5s to go
# on time step 5038 (time=5.038), 0.174096 s/step
# Meep progress: 5.061/14.800000190734863 = 34.2% done in 772.1s, 1485.8s to go
# on time step 5062 (time=5.062), 0.174484 s/step
# Meep progress: 5.086/14.800000190734863 = 34.4% done in 776.1s, 1482.3s to go
# on time step 5088 (time=5.088), 0.158471 s/step
# Meep progress: 5.111/14.800000190734863 = 34.5% done in 780.3s, 1479.2s to go
# on time step 5112 (time=5.112), 0.168109 s/step
# Meep progress: 5.134/14.800000190734863 = 34.7% done in 784.3s, 1476.7s to go
# on time step 5135 (time=5.135), 0.175462 s/step
# Meep progress: 5.159/14.800000190734863 = 34.9% done in 788.4s, 1473.4s to go
# on time step 5160 (time=5.16), 0.16231 s/step
# Meep progress: 5.1850000000000005/14.800000190734863 = 35.0% done in 792.5s, 1469.6s to go
# on time step 5186 (time=5.186), 0.156786 s/step
# Meep progress: 5.212/14.800000190734863 = 35.2% done in 796.5s, 1465.3s to go
# on time step 5213 (time=5.213), 0.149769 s/step
# Meep progress: 5.239/14.800000190734863 = 35.4% done in 800.6s, 1461.0s to go
# on time step 5240 (time=5.24), 0.149076 s/step
# Meep progress: 5.266/14.800000190734863 = 35.6% done in 804.7s, 1456.8s to go
# on time step 5267 (time=5.267), 0.151288 s/step
# Meep progress: 5.296/14.800000190734863 = 35.8% done in 808.8s, 1451.4s to go
# on time step 5297 (time=5.297), 0.136556 s/step
# Meep progress: 5.325/14.800000190734863 = 36.0% done in 812.9s, 1446.4s to go
# on time step 5326 (time=5.326), 0.141074 s/step
# Meep progress: 5.355/14.800000190734863 = 36.2% done in 816.9s, 1440.8s to go
# on time step 5356 (time=5.356), 0.134687 s/step
# Meep progress: 5.384/14.800000190734863 = 36.4% done in 820.9s, 1435.7s to go
# on time step 5385 (time=5.385), 0.139696 s/step
# Meep progress: 5.4110000000000005/14.800000190734863 = 36.6% done in 825.0s, 1431.5s to go
# on time step 5412 (time=5.412), 0.149757 s/step
# Meep progress: 5.439/14.800000190734863 = 36.7% done in 829.1s, 1427.0s to go
# on time step 5439 (time=5.439), 0.148492 s/step
# Meep progress: 5.465/14.800000190734863 = 36.9% done in 833.2s, 1423.3s to go
# on time step 5465 (time=5.465), 0.157334 s/step
# Meep progress: 5.492/14.800000190734863 = 37.1% done in 837.3s, 1419.1s to go
# on time step 5492 (time=5.492), 0.150619 s/step
# Meep progress: 5.5200000000000005/14.800000190734863 = 37.3% done in 841.4s, 1414.5s to go
# on time step 5520 (time=5.52), 0.146895 s/step
# Meep progress: 5.549/14.800000190734863 = 37.5% done in 845.5s, 1409.6s to go
# on time step 5549 (time=5.549), 0.140693 s/step
# Meep progress: 5.5760000000000005/14.800000190734863 = 37.7% done in 849.6s, 1405.4s to go
# on time step 5576 (time=5.576), 0.150331 s/step
# Meep progress: 5.6000000000000005/14.800000190734863 = 37.8% done in 853.6s, 1402.4s to go
# on time step 5600 (time=5.6), 0.168826 s/step
# Meep progress: 5.628/14.800000190734863 = 38.0% done in 857.7s, 1397.9s to go
# on time step 5628 (time=5.628), 0.147494 s/step
# Meep progress: 5.656/14.800000190734863 = 38.2% done in 861.8s, 1393.3s to go
# on time step 5656 (time=5.656), 0.146059 s/step
# Meep progress: 5.683/14.800000190734863 = 38.4% done in 865.9s, 1389.1s to go
# on time step 5683 (time=5.683), 0.150307 s/step
# Meep progress: 5.708/14.800000190734863 = 38.6% done in 869.9s, 1385.7s to go
# on time step 5708 (time=5.708), 0.161797 s/step
# Meep progress: 5.736/14.800000190734863 = 38.8% done in 874.0s, 1381.1s to go
# on time step 5736 (time=5.736), 0.144424 s/step
# Meep progress: 5.764/14.800000190734863 = 38.9% done in 878.0s, 1376.4s to go
# on time step 5764 (time=5.764), 0.142864 s/step
# Meep progress: 5.7940000000000005/14.800000190734863 = 39.1% done in 882.0s, 1371.0s to go
# on time step 5794 (time=5.794), 0.135362 s/step
# Meep progress: 5.824/14.800000190734863 = 39.4% done in 886.1s, 1365.7s to go
# on time step 5824 (time=5.824), 0.135396 s/step
# Meep progress: 5.853/14.800000190734863 = 39.5% done in 890.2s, 1360.8s to go
# on time step 5853 (time=5.853), 0.142182 s/step
# Meep progress: 5.88/14.800000190734863 = 39.7% done in 894.3s, 1356.6s to go
# on time step 5880 (time=5.88), 0.149672 s/step
# Meep progress: 5.908/14.800000190734863 = 39.9% done in 898.4s, 1352.1s to go
# on time step 5908 (time=5.908), 0.147161 s/step
# Meep progress: 5.938/14.800000190734863 = 40.1% done in 902.5s, 1346.9s to go
# on time step 5938 (time=5.938), 0.137464 s/step
# Meep progress: 5.9670000000000005/14.800000190734863 = 40.3% done in 906.5s, 1342.0s to go
# on time step 5967 (time=5.967), 0.138621 s/step
# Meep progress: 5.998/14.800000190734863 = 40.5% done in 910.7s, 1336.4s to go
# on time step 5998 (time=5.998), 0.132712 s/step
# Meep progress: 6.027/14.800000190734863 = 40.7% done in 914.7s, 1331.5s to go
# on time step 6027 (time=6.027), 0.140595 s/step
# Meep progress: 6.055/14.800000190734863 = 40.9% done in 918.9s, 1327.1s to go
# on time step 6055 (time=6.055), 0.14819 s/step
# Meep progress: 6.079/14.800000190734863 = 41.1% done in 923.0s, 1324.1s to go
# on time step 6079 (time=6.079), 0.170131 s/step
# Meep progress: 6.104/14.800000190734863 = 41.2% done in 927.0s, 1320.6s to go
# on time step 6104 (time=6.104), 0.160722 s/step
# Meep progress: 6.128/14.800000190734863 = 41.4% done in 931.0s, 1317.6s to go
# on time step 6128 (time=6.128), 0.168956 s/step
# Meep progress: 6.154/14.800000190734863 = 41.6% done in 935.1s, 1313.7s to go
# on time step 6154 (time=6.154), 0.155666 s/step
# Meep progress: 6.179/14.800000190734863 = 41.7% done in 939.2s, 1310.4s to go
# on time step 6179 (time=6.179), 0.163985 s/step
# Meep progress: 6.203/14.800000190734863 = 41.9% done in 943.2s, 1307.2s to go
# on time step 6203 (time=6.203), 0.167868 s/step
# Meep progress: 6.229/14.800000190734863 = 42.1% done in 947.3s, 1303.4s to go
# on time step 6229 (time=6.229), 0.155211 s/step
# Meep progress: 6.257000000000001/14.800000190734863 = 42.3% done in 951.4s, 1299.0s to go
# on time step 6257 (time=6.257), 0.14709 s/step
# Meep progress: 6.279/14.800000190734863 = 42.4% done in 955.5s, 1296.7s to go
# on time step 6279 (time=6.279), 0.186801 s/step
# Meep progress: 6.3020000000000005/14.800000190734863 = 42.6% done in 959.6s, 1294.0s to go
# on time step 6302 (time=6.302), 0.180936 s/step
# Meep progress: 6.325/14.800000190734863 = 42.7% done in 963.8s, 1291.4s to go
# on time step 6325 (time=6.325), 0.178883 s/step
# Meep progress: 6.352/14.800000190734863 = 42.9% done in 967.9s, 1287.3s to go
# on time step 6352 (time=6.352), 0.153449 s/step
# Meep progress: 6.3790000000000004/14.800000190734863 = 43.1% done in 972.0s, 1283.1s to go
# on time step 6379 (time=6.379), 0.150441 s/step
# Meep progress: 6.406/14.800000190734863 = 43.3% done in 976.1s, 1279.0s to go
# on time step 6406 (time=6.406), 0.15118 s/step
# Meep progress: 6.433/14.800000190734863 = 43.5% done in 980.1s, 1274.8s to go
# on time step 6433 (time=6.433), 0.150418 s/step
# Meep progress: 6.462/14.800000190734863 = 43.7% done in 984.2s, 1269.9s to go
# on time step 6462 (time=6.462), 0.13985 s/step
# Meep progress: 6.488/14.800000190734863 = 43.8% done in 988.2s, 1266.0s to go
# on time step 6488 (time=6.488), 0.154758 s/step
# Meep progress: 6.514/14.800000190734863 = 44.0% done in 992.2s, 1262.1s to go
# on time step 6514 (time=6.514), 0.154398 s/step
# Meep progress: 6.539/14.800000190734863 = 44.2% done in 996.2s, 1258.6s to go
# on time step 6539 (time=6.539), 0.161436 s/step
# Meep progress: 6.565/14.800000190734863 = 44.4% done in 1000.4s, 1254.9s to go
# on time step 6565 (time=6.565), 0.160775 s/step
# Meep progress: 6.5920000000000005/14.800000190734863 = 44.5% done in 1004.6s, 1250.8s to go
# on time step 6592 (time=6.592), 0.152945 s/step
# Meep progress: 6.6160000000000005/14.800000190734863 = 44.7% done in 1008.6s, 1247.6s to go
# on time step 6616 (time=6.616), 0.166816 s/step
# Meep progress: 6.639/14.800000190734863 = 44.9% done in 1012.7s, 1244.9s to go
# on time step 6639 (time=6.639), 0.180782 s/step
# Meep progress: 6.6610000000000005/14.800000190734863 = 45.0% done in 1016.8s, 1242.4s to go
# on time step 6661 (time=6.661), 0.186302 s/step
# Meep progress: 6.686/14.800000190734863 = 45.2% done in 1020.8s, 1238.9s to go
# on time step 6687 (time=6.687), 0.159793 s/step
# Meep progress: 6.714/14.800000190734863 = 45.4% done in 1024.9s, 1234.4s to go
# on time step 6715 (time=6.715), 0.146155 s/step
# Meep progress: 6.74/14.800000190734863 = 45.5% done in 1029.0s, 1230.6s to go
# on time step 6741 (time=6.741), 0.157886 s/step
# Meep progress: 6.767/14.800000190734863 = 45.7% done in 1033.1s, 1226.3s to go
# on time step 6768 (time=6.768), 0.1491 s/step
# Meep progress: 6.797/14.800000190734863 = 45.9% done in 1037.2s, 1221.2s to go
# on time step 6798 (time=6.798), 0.136123 s/step
# Meep progress: 6.824/14.800000190734863 = 46.1% done in 1041.2s, 1217.0s to go
# on time step 6825 (time=6.825), 0.149178 s/step
# Meep progress: 6.852/14.800000190734863 = 46.3% done in 1045.3s, 1212.5s to go
# on time step 6853 (time=6.853), 0.147091 s/step
# Meep progress: 6.881/14.800000190734863 = 46.5% done in 1049.4s, 1207.7s to go
# on time step 6882 (time=6.882), 0.142224 s/step
# Meep progress: 6.91/14.800000190734863 = 46.7% done in 1053.5s, 1202.9s to go
# on time step 6911 (time=6.911), 0.140579 s/step
# Meep progress: 6.938/14.800000190734863 = 46.9% done in 1057.6s, 1198.5s to go
# on time step 6938 (time=6.938), 0.148263 s/step
# Meep progress: 6.965/14.800000190734863 = 47.1% done in 1061.7s, 1194.3s to go
# on time step 6965 (time=6.965), 0.150405 s/step
# Meep progress: 6.994/14.800000190734863 = 47.3% done in 1065.8s, 1189.5s to go
# on time step 6994 (time=6.994), 0.140971 s/step
# Meep progress: 7.022/14.800000190734863 = 47.4% done in 1070.0s, 1185.1s to go
# on time step 7022 (time=7.022), 0.148542 s/step
# Meep progress: 7.05/14.800000190734863 = 47.6% done in 1074.0s, 1180.6s to go
# on time step 7050 (time=7.05), 0.143333 s/step
# Meep progress: 7.079/14.800000190734863 = 47.8% done in 1078.0s, 1175.8s to go
# on time step 7079 (time=7.079), 0.138818 s/step
# Meep progress: 7.1080000000000005/14.800000190734863 = 48.0% done in 1082.1s, 1171.0s to go
# on time step 7108 (time=7.108), 0.140703 s/step
# Meep progress: 7.1370000000000005/14.800000190734863 = 48.2% done in 1086.2s, 1166.2s to go
# on time step 7137 (time=7.137), 0.141361 s/step
# Meep progress: 7.167/14.800000190734863 = 48.4% done in 1090.2s, 1161.1s to go
# on time step 7167 (time=7.167), 0.135143 s/step
# Meep progress: 7.195/14.800000190734863 = 48.6% done in 1094.4s, 1156.7s to go
# on time step 7195 (time=7.195), 0.147056 s/step
# Meep progress: 7.224/14.800000190734863 = 48.8% done in 1098.5s, 1152.0s to go
# on time step 7224 (time=7.224), 0.141552 s/step
# Meep progress: 7.2540000000000004/14.800000190734863 = 49.0% done in 1102.5s, 1146.9s to go
# on time step 7254 (time=7.254), 0.134905 s/step
# Meep progress: 7.282/14.800000190734863 = 49.2% done in 1106.5s, 1142.4s to go
# on time step 7282 (time=7.282), 0.143489 s/step
# Meep progress: 7.312/14.800000190734863 = 49.4% done in 1110.5s, 1137.3s to go
# on time step 7312 (time=7.312), 0.133336 s/step
# Meep progress: 7.3420000000000005/14.800000190734863 = 49.6% done in 1114.6s, 1132.2s to go
# on time step 7342 (time=7.342), 0.136324 s/step
# Meep progress: 7.369/14.800000190734863 = 49.8% done in 1118.7s, 1128.1s to go
# on time step 7369 (time=7.369), 0.150416 s/step
# Meep progress: 7.398000000000001/14.800000190734863 = 50.0% done in 1122.7s, 1123.3s to go
# on time step 7398 (time=7.398), 0.139805 s/step
# Meep progress: 7.428/14.800000190734863 = 50.2% done in 1126.8s, 1118.3s to go
# on time step 7428 (time=7.428), 0.134828 s/step
# Meep progress: 7.456/14.800000190734863 = 50.4% done in 1130.8s, 1113.8s to go
# on time step 7456 (time=7.456), 0.14335 s/step
# Meep progress: 7.485/14.800000190734863 = 50.6% done in 1134.8s, 1109.0s to go
# on time step 7485 (time=7.485), 0.138783 s/step
# Meep progress: 7.5120000000000005/14.800000190734863 = 50.8% done in 1139.0s, 1105.0s to go
# on time step 7512 (time=7.512), 0.153647 s/step
# Meep progress: 7.541/14.800000190734863 = 51.0% done in 1143.0s, 1100.3s to go
# on time step 7541 (time=7.541), 0.14006 s/step
# Meep progress: 7.57/14.800000190734863 = 51.1% done in 1147.2s, 1095.6s to go
# on time step 7570 (time=7.57), 0.142758 s/step
# Meep progress: 7.598/14.800000190734863 = 51.3% done in 1151.3s, 1091.3s to go
# on time step 7598 (time=7.598), 0.148579 s/step
# Meep progress: 7.626/14.800000190734863 = 51.5% done in 1155.5s, 1087.0s to go
# on time step 7626 (time=7.626), 0.148201 s/step
# Meep progress: 7.655/14.800000190734863 = 51.7% done in 1159.6s, 1082.4s to go
# on time step 7655 (time=7.655), 0.142477 s/step
# Meep progress: 7.684/14.800000190734863 = 51.9% done in 1163.7s, 1077.7s to go
# on time step 7684 (time=7.684), 0.141642 s/step
# Meep progress: 7.714/14.800000190734863 = 52.1% done in 1167.8s, 1072.8s to go
# on time step 7714 (time=7.714), 0.137477 s/step
# Meep progress: 7.742/14.800000190734863 = 52.3% done in 1171.9s, 1068.4s to go
# on time step 7742 (time=7.742), 0.145638 s/step
# Meep progress: 7.772/14.800000190734863 = 52.5% done in 1176.0s, 1063.5s to go
# on time step 7772 (time=7.772), 0.136699 s/step
# Meep progress: 7.801/14.800000190734863 = 52.7% done in 1180.1s, 1058.8s to go
# on time step 7801 (time=7.801), 0.139558 s/step
# Meep progress: 7.831/14.800000190734863 = 52.9% done in 1184.2s, 1053.8s to go
# on time step 7831 (time=7.831), 0.137105 s/step
# Meep progress: 7.859/14.800000190734863 = 53.1% done in 1188.2s, 1049.4s to go
# on time step 7859 (time=7.859), 0.143608 s/step
# Meep progress: 7.889/14.800000190734863 = 53.3% done in 1192.3s, 1044.5s to go
# on time step 7889 (time=7.889), 0.1362 s/step
# Meep progress: 7.9190000000000005/14.800000190734863 = 53.5% done in 1196.4s, 1039.6s to go
# on time step 7919 (time=7.919), 0.137994 s/step
# Meep progress: 7.947/14.800000190734863 = 53.7% done in 1200.5s, 1035.2s to go
# on time step 7947 (time=7.947), 0.143732 s/step
# Meep progress: 7.977/14.800000190734863 = 53.9% done in 1204.6s, 1030.3s to go
# on time step 7977 (time=7.977), 0.137364 s/step
# Meep progress: 8.006/14.800000190734863 = 54.1% done in 1208.6s, 1025.6s to go
# on time step 8006 (time=8.006), 0.138187 s/step
# Meep progress: 8.035/14.800000190734863 = 54.3% done in 1212.6s, 1021.0s to go
# on time step 8035 (time=8.035), 0.139018 s/step
# Meep progress: 8.062/14.800000190734863 = 54.5% done in 1216.7s, 1016.9s to go
# on time step 8062 (time=8.062), 0.151349 s/step
# Meep progress: 8.091/14.800000190734863 = 54.7% done in 1220.8s, 1012.2s to go
# on time step 8091 (time=8.091), 0.13929 s/step
# Meep progress: 8.119/14.800000190734863 = 54.9% done in 1224.9s, 1007.9s to go
# on time step 8119 (time=8.119), 0.146566 s/step
# Meep progress: 8.147/14.800000190734863 = 55.0% done in 1228.9s, 1003.6s to go
# on time step 8147 (time=8.147), 0.145037 s/step
# Meep progress: 8.177/14.800000190734863 = 55.2% done in 1233.1s, 998.7s to go
# on time step 8177 (time=8.177), 0.137506 s/step
# Meep progress: 8.206/14.800000190734863 = 55.4% done in 1237.1s, 994.1s to go
# on time step 8206 (time=8.206), 0.139112 s/step
# Meep progress: 8.234/14.800000190734863 = 55.6% done in 1241.1s, 989.7s to go
# on time step 8234 (time=8.234), 0.144486 s/step
# Meep progress: 8.262/14.800000190734863 = 55.8% done in 1245.2s, 985.4s to go
# on time step 8262 (time=8.262), 0.146231 s/step
# Meep progress: 8.291/14.800000190734863 = 56.0% done in 1249.2s, 980.7s to go
# on time step 8291 (time=8.291), 0.138343 s/step
# Meep progress: 8.32/14.800000190734863 = 56.2% done in 1253.3s, 976.1s to go
# on time step 8320 (time=8.32), 0.139828 s/step
# Meep progress: 8.349/14.800000190734863 = 56.4% done in 1257.3s, 971.5s to go
# on time step 8349 (time=8.349), 0.139578 s/step
# Meep progress: 8.378/14.800000190734863 = 56.6% done in 1261.4s, 966.9s to go
# on time step 8378 (time=8.378), 0.141331 s/step
# Meep progress: 8.407/14.800000190734863 = 56.8% done in 1265.6s, 962.4s to go
# on time step 8407 (time=8.407), 0.143595 s/step
# Meep progress: 8.435/14.800000190734863 = 57.0% done in 1269.7s, 958.1s to go
# on time step 8435 (time=8.435), 0.14489 s/step
# Meep progress: 8.463000000000001/14.800000190734863 = 57.2% done in 1273.8s, 953.8s to go
# on time step 8463 (time=8.463), 0.147377 s/step
# Meep progress: 8.488/14.800000190734863 = 57.4% done in 1277.9s, 950.3s to go
# on time step 8488 (time=8.488), 0.165993 s/step
# Meep progress: 8.514/14.800000190734863 = 57.5% done in 1282.0s, 946.5s to go
# on time step 8514 (time=8.514), 0.154464 s/step
# Meep progress: 8.541/14.800000190734863 = 57.7% done in 1286.1s, 942.4s to go
# on time step 8541 (time=8.541), 0.151564 s/step
# Meep progress: 8.568/14.800000190734863 = 57.9% done in 1290.2s, 938.4s to go
# on time step 8568 (time=8.568), 0.152125 s/step
# Meep progress: 8.595/14.800000190734863 = 58.1% done in 1294.2s, 934.3s to go
# on time step 8595 (time=8.595), 0.148484 s/step
# Meep progress: 8.622/14.800000190734863 = 58.3% done in 1298.2s, 930.2s to go
# on time step 8622 (time=8.622), 0.148453 s/step
# Meep progress: 8.647/14.800000190734863 = 58.4% done in 1302.3s, 926.7s to go
# on time step 8647 (time=8.647), 0.163031 s/step
# Meep progress: 8.676/14.800000190734863 = 58.6% done in 1306.4s, 922.1s to go
# on time step 8676 (time=8.676), 0.141188 s/step
# Meep progress: 8.705/14.800000190734863 = 58.8% done in 1310.4s, 917.5s to go
# on time step 8705 (time=8.705), 0.140669 s/step
# Meep progress: 8.735/14.800000190734863 = 59.0% done in 1314.5s, 912.7s to go
# on time step 8735 (time=8.735), 0.136625 s/step
# Meep progress: 8.771/14.800000190734863 = 59.3% done in 1318.9s, 906.6s to go
# on time step 8771 (time=8.771), 0.120638 s/step
# Meep progress: 8.791/14.800000190734863 = 59.4% done in 1323.1s, 904.4s to go
# on time step 8791 (time=8.791), 0.206464 s/step
# Meep progress: 8.821/14.800000190734863 = 59.6% done in 1327.1s, 899.6s to go
# on time step 8821 (time=8.821), 0.13531 s/step
# Meep progress: 8.854000000000001/14.800000190734863 = 59.8% done in 1331.2s, 894.0s to go
# on time step 8854 (time=8.854), 0.122199 s/step
# Meep progress: 8.887/14.800000190734863 = 60.0% done in 1335.3s, 888.4s to go
# on time step 8887 (time=8.887), 0.124104 s/step
# Meep progress: 8.92/14.800000190734863 = 60.3% done in 1339.3s, 882.9s to go
# on time step 8920 (time=8.92), 0.12173 s/step
# Meep progress: 8.954/14.800000190734863 = 60.5% done in 1343.4s, 877.1s to go
# on time step 8954 (time=8.954), 0.12132 s/step
# Meep progress: 8.987/14.800000190734863 = 60.7% done in 1347.5s, 871.6s to go
# on time step 8987 (time=8.987), 0.122461 s/step
# Meep progress: 9.019/14.800000190734863 = 60.9% done in 1351.6s, 866.4s to go
# on time step 9019 (time=9.019), 0.130583 s/step
# Meep progress: 9.045/14.800000190734863 = 61.1% done in 1355.7s, 862.6s to go
# on time step 9045 (time=9.045), 0.155466 s/step
# Meep progress: 9.078/14.800000190734863 = 61.3% done in 1359.7s, 857.1s to go
# on time step 9078 (time=9.078), 0.123277 s/step
# Meep progress: 9.112/14.800000190734863 = 61.6% done in 1363.8s, 851.3s to go
# on time step 9112 (time=9.112), 0.117889 s/step
# Meep progress: 9.146/14.800000190734863 = 61.8% done in 1367.8s, 845.6s to go
# on time step 9146 (time=9.146), 0.119007 s/step
# Meep progress: 9.179/14.800000190734863 = 62.0% done in 1371.9s, 840.1s to go
# on time step 9179 (time=9.179), 0.123188 s/step
# Meep progress: 9.213000000000001/14.800000190734863 = 62.2% done in 1375.9s, 834.4s to go
# on time step 9213 (time=9.213), 0.119886 s/step
# Meep progress: 9.247/14.800000190734863 = 62.5% done in 1380.0s, 828.7s to go
# on time step 9247 (time=9.247), 0.119183 s/step
# Meep progress: 9.281/14.800000190734863 = 62.7% done in 1384.1s, 823.1s to go
# on time step 9281 (time=9.281), 0.120999 s/step
# Meep progress: 9.315/14.800000190734863 = 62.9% done in 1388.2s, 817.4s to go
# on time step 9315 (time=9.315), 0.120695 s/step
# Meep progress: 9.35/14.800000190734863 = 63.2% done in 1392.3s, 811.6s to go
# on time step 9350 (time=9.35), 0.116894 s/step
# Meep progress: 9.383000000000001/14.800000190734863 = 63.4% done in 1396.3s, 806.1s to go
# on time step 9383 (time=9.383), 0.122288 s/step
# Meep progress: 9.417/14.800000190734863 = 63.6% done in 1400.4s, 800.5s to go
# on time step 9417 (time=9.417), 0.119932 s/step
# Meep progress: 9.449/14.800000190734863 = 63.8% done in 1404.5s, 795.4s to go
# on time step 9449 (time=9.449), 0.126687 s/step
# Meep progress: 9.482/14.800000190734863 = 64.1% done in 1408.6s, 790.0s to go
# on time step 9482 (time=9.482), 0.124769 s/step
# Meep progress: 9.516/14.800000190734863 = 64.3% done in 1412.7s, 784.4s to go
# on time step 9516 (time=9.516), 0.121125 s/step
# Meep progress: 9.55/14.800000190734863 = 64.5% done in 1416.8s, 778.8s to go
# on time step 9550 (time=9.55), 0.118532 s/step
# Meep progress: 9.584/14.800000190734863 = 64.8% done in 1420.8s, 773.2s to go
# on time step 9584 (time=9.584), 0.118437 s/step
# Meep progress: 9.617/14.800000190734863 = 65.0% done in 1424.8s, 767.9s to go
# on time step 9617 (time=9.617), 0.123243 s/step
# Meep progress: 9.65/14.800000190734863 = 65.2% done in 1428.9s, 762.6s to go
# on time step 9650 (time=9.65), 0.123197 s/step
# Meep progress: 9.684000000000001/14.800000190734863 = 65.4% done in 1433.0s, 757.1s to go
# on time step 9684 (time=9.684), 0.120714 s/step
# Meep progress: 9.718/14.800000190734863 = 65.7% done in 1437.1s, 751.5s to go
# on time step 9718 (time=9.718), 0.120109 s/step
# Meep progress: 9.752/14.800000190734863 = 65.9% done in 1441.1s, 746.0s to go
# on time step 9752 (time=9.752), 0.118653 s/step
# Meep progress: 9.786/14.800000190734863 = 66.1% done in 1445.2s, 740.5s to go
# on time step 9786 (time=9.786), 0.120477 s/step
# Meep progress: 9.82/14.800000190734863 = 66.4% done in 1449.3s, 735.0s to go
# on time step 9820 (time=9.82), 0.120849 s/step
# Meep progress: 9.854000000000001/14.800000190734863 = 66.6% done in 1453.4s, 729.5s to go
# on time step 9854 (time=9.854), 0.118317 s/step
# Meep progress: 9.888/14.800000190734863 = 66.8% done in 1457.5s, 724.0s to go
# on time step 9888 (time=9.888), 0.120591 s/step
# Meep progress: 9.922/14.800000190734863 = 67.0% done in 1461.6s, 718.6s to go
# on time step 9922 (time=9.922), 0.12138 s/step
# Meep progress: 9.956/14.800000190734863 = 67.3% done in 1465.7s, 713.1s to go
# on time step 9956 (time=9.956), 0.120938 s/step
# Meep progress: 9.99/14.800000190734863 = 67.5% done in 1469.8s, 707.7s to go
# on time step 9990 (time=9.99), 0.12006 s/step
# Meep progress: 10.024000000000001/14.800000190734863 = 67.7% done in 1473.8s, 702.2s to go
# on time step 10024 (time=10.024), 0.118875 s/step
# Meep progress: 10.056000000000001/14.800000190734863 = 67.9% done in 1478.0s, 697.2s to go
# on time step 10056 (time=10.056), 0.129258 s/step
# Meep progress: 10.086/14.800000190734863 = 68.1% done in 1482.1s, 692.7s to go
# on time step 10086 (time=10.086), 0.137375 s/step
# Meep progress: 10.118/14.800000190734863 = 68.4% done in 1486.2s, 687.7s to go
# on time step 10118 (time=10.118), 0.128056 s/step
# Meep progress: 10.152000000000001/14.800000190734863 = 68.6% done in 1490.3s, 682.3s to go
# on time step 10152 (time=10.152), 0.120604 s/step
# Meep progress: 10.185/14.800000190734863 = 68.8% done in 1494.3s, 677.1s to go
# on time step 10185 (time=10.185), 0.121934 s/step
# Meep progress: 10.216000000000001/14.800000190734863 = 69.0% done in 1498.5s, 672.4s to go
# on time step 10216 (time=10.216), 0.133408 s/step
# Meep progress: 10.245000000000001/14.800000190734863 = 69.2% done in 1502.5s, 668.0s to go
# on time step 10245 (time=10.245), 0.140109 s/step
# Meep progress: 10.277000000000001/14.800000190734863 = 69.4% done in 1506.6s, 663.1s to go
# on time step 10277 (time=10.277), 0.127047 s/step
# Meep progress: 10.31/14.800000190734863 = 69.7% done in 1510.7s, 657.9s to go
# on time step 10310 (time=10.31), 0.123733 s/step
# Meep progress: 10.344/14.800000190734863 = 69.9% done in 1514.7s, 652.5s to go
# on time step 10344 (time=10.344), 0.119331 s/step
# Meep progress: 10.376/14.800000190734863 = 70.1% done in 1518.8s, 647.6s to go
# on time step 10376 (time=10.376), 0.128036 s/step
# Meep progress: 10.405/14.800000190734863 = 70.3% done in 1523.0s, 643.3s to go
# on time step 10405 (time=10.405), 0.142208 s/step
# Meep progress: 10.436/14.800000190734863 = 70.5% done in 1527.0s, 638.6s to go
# on time step 10436 (time=10.436), 0.131134 s/step
# Meep progress: 10.465/14.800000190734863 = 70.7% done in 1531.1s, 634.2s to go
# ...
# on time step 103281 (time=103.281), 0.321196 s/step
# Meep progress: 103.291/104.80000019073486 = 98.6% done in 32740.1s, 478.3s to go
# on time step 103294 (time=103.294), 0.316156 s/step
# Meep progress: 103.304/104.80000019073486 = 98.6% done in 32744.2s, 474.2s to go
# on time step 103307 (time=103.307), 0.318235 s/step
# Meep progress: 103.31700000000001/104.80000019073486 = 98.6% done in 32748.4s, 470.1s to go
# on time step 103320 (time=103.32), 0.317159 s/step
# Meep progress: 103.33/104.80000019073486 = 98.6% done in 32752.5s, 465.9s to go
# on time step 103333 (time=103.333), 0.317213 s/step
# Meep progress: 103.343/104.80000019073486 = 98.6% done in 32756.7s, 461.8s to go
# on time step 103346 (time=103.346), 0.319055 s/step
# Meep progress: 103.35600000000001/104.80000019073486 = 98.6% done in 32760.8s, 457.7s to go
# on time step 103359 (time=103.359), 0.31295 s/step
# Meep progress: 103.369/104.80000019073486 = 98.6% done in 32764.8s, 453.6s to go
# on time step 103372 (time=103.372), 0.310039 s/step
# Meep progress: 103.382/104.80000019073486 = 98.6% done in 32769.0s, 449.5s to go
# on time step 103385 (time=103.385), 0.325036 s/step
# Meep progress: 103.395/104.80000019073486 = 98.7% done in 32773.1s, 445.3s to go
# on time step 103398 (time=103.398), 0.31776 s/step
# Meep progress: 103.408/104.80000019073486 = 98.7% done in 32777.2s, 441.2s to go
# on time step 103411 (time=103.411), 0.319116 s/step
# Meep progress: 103.42/104.80000019073486 = 98.7% done in 32781.3s, 437.4s to go
# on time step 103423 (time=103.423), 0.334425 s/step
# Meep progress: 103.433/104.80000019073486 = 98.7% done in 32785.5s, 433.3s to go
# on time step 103436 (time=103.436), 0.325808 s/step
# Meep progress: 103.446/104.80000019073486 = 98.7% done in 32789.5s, 429.2s to go
# on time step 103449 (time=103.449), 0.310221 s/step
# Meep progress: 103.459/104.80000019073486 = 98.7% done in 32793.6s, 425.1s to go
# on time step 103462 (time=103.462), 0.313628 s/step
# Meep progress: 103.47200000000001/104.80000019073486 = 98.7% done in 32797.8s, 420.9s to go
# on time step 103475 (time=103.475), 0.317833 s/step
# Meep progress: 103.485/104.80000019073486 = 98.7% done in 32802.0s, 416.8s to go
# on time step 103488 (time=103.488), 0.323103 s/step
# Meep progress: 103.498/104.80000019073486 = 98.8% done in 32806.1s, 412.7s to go
# on time step 103501 (time=103.501), 0.314311 s/step
# Meep progress: 103.511/104.80000019073486 = 98.8% done in 32810.2s, 408.6s to go
# on time step 103514 (time=103.514), 0.316404 s/step
# Meep progress: 103.524/104.80000019073486 = 98.8% done in 32814.3s, 404.5s to go
# on time step 103527 (time=103.527), 0.313959 s/step
# Meep progress: 103.537/104.80000019073486 = 98.8% done in 32818.4s, 400.3s to go
# on time step 103540 (time=103.54), 0.318878 s/step
# Meep progress: 103.55/104.80000019073486 = 98.8% done in 32822.6s, 396.2s to go
# on time step 103552 (time=103.552), 0.338036 s/step
# Meep progress: 103.561/104.80000019073486 = 98.8% done in 32826.8s, 392.7s to go
# on time step 103563 (time=103.563), 0.369809 s/step
# Meep progress: 103.57300000000001/104.80000019073486 = 98.8% done in 32830.9s, 388.9s to go
# on time step 103575 (time=103.575), 0.346575 s/step
# Meep progress: 103.58500000000001/104.80000019073486 = 98.8% done in 32835.2s, 385.1s to go
# on time step 103587 (time=103.587), 0.364973 s/step
# Meep progress: 103.596/104.80000019073486 = 98.9% done in 32839.5s, 381.7s to go
# on time step 103598 (time=103.598), 0.383442 s/step
# Meep progress: 103.607/104.80000019073486 = 98.9% done in 32843.6s, 378.2s to go
# on time step 103609 (time=103.609), 0.370247 s/step
# Meep progress: 103.619/104.80000019073486 = 98.9% done in 32847.7s, 374.4s to go
# on time step 103621 (time=103.621), 0.34304 s/step
# Meep progress: 103.631/104.80000019073486 = 98.9% done in 32851.8s, 370.6s to go
# on time step 103633 (time=103.633), 0.335849 s/step
# Meep progress: 103.643/104.80000019073486 = 98.9% done in 32855.8s, 366.8s to go
# on time step 103645 (time=103.645), 0.337828 s/step
# Meep progress: 103.655/104.80000019073486 = 98.9% done in 32860.0s, 363.0s to go
# on time step 103657 (time=103.657), 0.351742 s/step
# Meep progress: 103.667/104.80000019073486 = 98.9% done in 32864.3s, 359.2s to go
# on time step 103668 (time=103.668), 0.375937 s/step
# Meep progress: 103.677/104.80000019073486 = 98.9% done in 32868.5s, 356.0s to go
# on time step 103678 (time=103.678), 0.403216 s/step
# Meep progress: 103.68900000000001/104.80000019073486 = 98.9% done in 32872.8s, 352.2s to go
# on time step 103690 (time=103.69), 0.348544 s/step
# Meep progress: 103.70100000000001/104.80000019073486 = 99.0% done in 32876.9s, 348.4s to go
# on time step 103702 (time=103.702), 0.351766 s/step
# Meep progress: 103.71300000000001/104.80000019073486 = 99.0% done in 32881.0s, 344.6s to go
# on time step 103714 (time=103.714), 0.33683 s/step
# Meep progress: 103.72500000000001/104.80000019073486 = 99.0% done in 32885.0s, 340.8s to go
# on time step 103727 (time=103.727), 0.329965 s/step
# Meep progress: 103.73700000000001/104.80000019073486 = 99.0% done in 32889.1s, 337.0s to go
# on time step 103739 (time=103.739), 0.349422 s/step
# Meep progress: 103.749/104.80000019073486 = 99.0% done in 32893.4s, 333.2s to go
# on time step 103751 (time=103.751), 0.353031 s/step
# Meep progress: 103.761/104.80000019073486 = 99.0% done in 32897.8s, 329.4s to go
# on time step 103763 (time=103.763), 0.360822 s/step
# Meep progress: 103.774/104.80000019073486 = 99.0% done in 32902.0s, 325.3s to go
# on time step 103776 (time=103.776), 0.326268 s/step
# Meep progress: 103.787/104.80000019073486 = 99.0% done in 32906.1s, 321.2s to go
# on time step 103789 (time=103.789), 0.318227 s/step
# Meep progress: 103.8/104.80000019073486 = 99.0% done in 32910.4s, 317.1s to go
# on time step 103802 (time=103.802), 0.335671 s/step
# Meep progress: 103.812/104.80000019073486 = 99.1% done in 32914.5s, 313.3s to go
# on time step 103815 (time=103.815), 0.330444 s/step
# Meep progress: 103.825/104.80000019073486 = 99.1% done in 32918.6s, 309.1s to go
# on time step 103828 (time=103.828), 0.319581 s/step
# Meep progress: 103.83800000000001/104.80000019073486 = 99.1% done in 32922.7s, 305.0s to go
# on time step 103841 (time=103.841), 0.3165 s/step
# Meep progress: 103.85000000000001/104.80000019073486 = 99.1% done in 32926.8s, 301.2s to go
# on time step 103853 (time=103.853), 0.339885 s/step
# Meep progress: 103.863/104.80000019073486 = 99.1% done in 32931.0s, 297.1s to go
# on time step 103866 (time=103.866), 0.31838 s/step
# Meep progress: 103.876/104.80000019073486 = 99.1% done in 32935.2s, 293.0s to go
# on time step 103879 (time=103.879), 0.325034 s/step
# Meep progress: 103.889/104.80000019073486 = 99.1% done in 32939.3s, 288.8s to go
# on time step 103892 (time=103.892), 0.31455 s/step
# Meep progress: 103.902/104.80000019073486 = 99.1% done in 32943.4s, 284.7s to go
# on time step 103905 (time=103.905), 0.320231 s/step
# Meep progress: 103.915/104.80000019073486 = 99.2% done in 32947.5s, 280.6s to go
# on time step 103918 (time=103.918), 0.313454 s/step
# Meep progress: 103.928/104.80000019073486 = 99.2% done in 32951.7s, 276.5s to go
# on time step 103931 (time=103.931), 0.314821 s/step
# Meep progress: 103.941/104.80000019073486 = 99.2% done in 32955.7s, 272.4s to go
# on time step 103945 (time=103.945), 0.31307 s/step
# Meep progress: 103.95400000000001/104.80000019073486 = 99.2% done in 32959.8s, 268.2s to go
# on time step 103958 (time=103.958), 0.311017 s/step
# Meep progress: 103.967/104.80000019073486 = 99.2% done in 32964.0s, 264.1s to go
# on time step 103971 (time=103.971), 0.328332 s/step
# Meep progress: 103.98/104.80000019073486 = 99.2% done in 32968.2s, 260.0s to go
# on time step 103984 (time=103.984), 0.31909 s/step
# Meep progress: 103.99300000000001/104.80000019073486 = 99.2% done in 32972.3s, 255.9s to go
# on time step 103997 (time=103.997), 0.317555 s/step
# Meep progress: 104.006/104.80000019073486 = 99.2% done in 32976.4s, 251.7s to go
# on time step 104010 (time=104.01), 0.320195 s/step
# Meep progress: 104.019/104.80000019073486 = 99.3% done in 32980.5s, 247.6s to go
# on time step 104023 (time=104.023), 0.314387 s/step
# Meep progress: 104.032/104.80000019073486 = 99.3% done in 32984.7s, 243.5s to go
# on time step 104036 (time=104.036), 0.318896 s/step
# Meep progress: 104.045/104.80000019073486 = 99.3% done in 32988.9s, 239.4s to go
# on time step 104049 (time=104.049), 0.323216 s/step
# Meep progress: 104.058/104.80000019073486 = 99.3% done in 32993.0s, 235.3s to go
# on time step 104062 (time=104.062), 0.310945 s/step
# Meep progress: 104.071/104.80000019073486 = 99.3% done in 32997.1s, 231.1s to go
# on time step 104075 (time=104.075), 0.322922 s/step
# Meep progress: 104.084/104.80000019073486 = 99.3% done in 33001.3s, 227.0s to go
# on time step 104088 (time=104.088), 0.316357 s/step
# Meep progress: 104.09700000000001/104.80000019073486 = 99.3% done in 33005.4s, 222.9s to go
# on time step 104101 (time=104.101), 0.318049 s/step
# Meep progress: 104.111/104.80000019073486 = 99.3% done in 33009.7s, 218.5s to go
# on time step 104114 (time=104.114), 0.30983 s/step
# Meep progress: 104.124/104.80000019073486 = 99.4% done in 33013.9s, 214.3s to go
# on time step 104127 (time=104.127), 0.317086 s/step
# Meep progress: 104.136/104.80000019073486 = 99.4% done in 33017.9s, 210.5s to go
# on time step 104139 (time=104.139), 0.336785 s/step
# Meep progress: 104.149/104.80000019073486 = 99.4% done in 33022.1s, 206.4s to go
# on time step 104152 (time=104.152), 0.323986 s/step
# Meep progress: 104.162/104.80000019073486 = 99.4% done in 33026.3s, 202.3s to go
# on time step 104165 (time=104.165), 0.323417 s/step
# Meep progress: 104.175/104.80000019073486 = 99.4% done in 33030.5s, 198.2s to go
# on time step 104178 (time=104.178), 0.323994 s/step
# Meep progress: 104.188/104.80000019073486 = 99.4% done in 33034.8s, 194.0s to go
# on time step 104191 (time=104.191), 0.325895 s/step
# Meep progress: 104.20100000000001/104.80000019073486 = 99.4% done in 33038.9s, 189.9s to go
# on time step 104204 (time=104.204), 0.322861 s/step
# Meep progress: 104.214/104.80000019073486 = 99.4% done in 33043.1s, 185.8s to go
# on time step 104217 (time=104.217), 0.317402 s/step
# Meep progress: 104.227/104.80000019073486 = 99.5% done in 33047.2s, 181.7s to go
# on time step 104230 (time=104.23), 0.316331 s/step
# Meep progress: 104.239/104.80000019073486 = 99.5% done in 33051.2s, 177.9s to go
# on time step 104243 (time=104.243), 0.326693 s/step
# Meep progress: 104.252/104.80000019073486 = 99.5% done in 33055.2s, 173.8s to go
# on time step 104256 (time=104.256), 0.317476 s/step
# Meep progress: 104.265/104.80000019073486 = 99.5% done in 33059.4s, 169.6s to go
# on time step 104269 (time=104.269), 0.321307 s/step
# Meep progress: 104.279/104.80000019073486 = 99.5% done in 33063.8s, 165.2s to go
# on time step 104283 (time=104.283), 0.30803 s/step
# Meep progress: 104.292/104.80000019073486 = 99.5% done in 33067.8s, 161.1s to go
# on time step 104296 (time=104.296), 0.314779 s/step
# Meep progress: 104.305/104.80000019073486 = 99.5% done in 33071.9s, 156.9s to go
# on time step 104309 (time=104.309), 0.308455 s/step
# Meep progress: 104.318/104.80000019073486 = 99.5% done in 33076.0s, 152.8s to go
# on time step 104322 (time=104.322), 0.322023 s/step
# Meep progress: 104.33200000000001/104.80000019073486 = 99.6% done in 33080.3s, 148.4s to go
# on time step 104336 (time=104.336), 0.310513 s/step
# Meep progress: 104.345/104.80000019073486 = 99.6% done in 33084.4s, 144.3s to go
# on time step 104349 (time=104.349), 0.311062 s/step
# Meep progress: 104.358/104.80000019073486 = 99.6% done in 33088.6s, 140.1s to go
# on time step 104362 (time=104.362), 0.31603 s/step
# Meep progress: 104.371/104.80000019073486 = 99.6% done in 33092.6s, 136.0s to go
# on time step 104375 (time=104.375), 0.314091 s/step
# Meep progress: 104.384/104.80000019073486 = 99.6% done in 33096.9s, 131.9s to go
# on time step 104388 (time=104.388), 0.325821 s/step
# Meep progress: 104.397/104.80000019073486 = 99.6% done in 33101.1s, 127.8s to go
# on time step 104401 (time=104.401), 0.322297 s/step
# Meep progress: 104.41/104.80000019073486 = 99.6% done in 33105.2s, 123.7s to go
# on time step 104414 (time=104.414), 0.320612 s/step
# Meep progress: 104.423/104.80000019073486 = 99.6% done in 33109.3s, 119.5s to go
# on time step 104427 (time=104.427), 0.312774 s/step
# Meep progress: 104.436/104.80000019073486 = 99.7% done in 33113.3s, 115.4s to go
# on time step 104441 (time=104.441), 0.306302 s/step
# Meep progress: 104.449/104.80000019073486 = 99.7% done in 33117.5s, 111.3s to go
# on time step 104454 (time=104.454), 0.322058 s/step
# Meep progress: 104.462/104.80000019073486 = 99.7% done in 33121.6s, 107.2s to go
# on time step 104467 (time=104.467), 0.313251 s/step
# Meep progress: 104.47500000000001/104.80000019073486 = 99.7% done in 33125.7s, 103.0s to go
# on time step 104480 (time=104.48), 0.32052 s/step
# Meep progress: 104.488/104.80000019073486 = 99.7% done in 33129.8s, 98.9s to go
# on time step 104493 (time=104.493), 0.310692 s/step
# Meep progress: 104.501/104.80000019073486 = 99.7% done in 33133.9s, 94.8s to go
# on time step 104506 (time=104.506), 0.320756 s/step
# Meep progress: 104.514/104.80000019073486 = 99.7% done in 33138.1s, 90.7s to go
# on time step 104519 (time=104.519), 0.317302 s/step
# Meep progress: 104.527/104.80000019073486 = 99.7% done in 33142.1s, 86.6s to go
# on time step 104532 (time=104.532), 0.313887 s/step
# Meep progress: 104.54/104.80000019073486 = 99.8% done in 33146.2s, 82.4s to go
# on time step 104545 (time=104.545), 0.312354 s/step
# Meep progress: 104.553/104.80000019073486 = 99.8% done in 33150.2s, 78.3s to go
# on time step 104558 (time=104.558), 0.310906 s/step
# Meep progress: 104.566/104.80000019073486 = 99.8% done in 33154.3s, 74.2s to go
# on time step 104571 (time=104.571), 0.313975 s/step
# Meep progress: 104.57900000000001/104.80000019073486 = 99.8% done in 33158.5s, 70.1s to go
# on time step 104584 (time=104.584), 0.320563 s/step
# Meep progress: 104.592/104.80000019073486 = 99.8% done in 33162.6s, 65.9s to go
# on time step 104597 (time=104.597), 0.31627 s/step
# Meep progress: 104.605/104.80000019073486 = 99.8% done in 33166.6s, 61.8s to go
# on time step 104611 (time=104.611), 0.307017 s/step
# Meep progress: 104.61800000000001/104.80000019073486 = 99.8% done in 33170.7s, 57.7s to go
# on time step 104624 (time=104.624), 0.318356 s/step
# Meep progress: 104.631/104.80000019073486 = 99.8% done in 33174.8s, 53.6s to go
# on time step 104637 (time=104.637), 0.308191 s/step
# Meep progress: 104.645/104.80000019073486 = 99.9% done in 33179.1s, 49.1s to go
# on time step 104650 (time=104.65), 0.308128 s/step
# Meep progress: 104.659/104.80000019073486 = 99.9% done in 33183.4s, 44.7s to go
# on time step 104663 (time=104.663), 0.309367 s/step
# Meep progress: 104.672/104.80000019073486 = 99.9% done in 33187.5s, 40.6s to go
# on time step 104676 (time=104.676), 0.325871 s/step
# Meep progress: 104.685/104.80000019073486 = 99.9% done in 33191.6s, 36.5s to go
# on time step 104690 (time=104.69), 0.304656 s/step
# Meep progress: 104.69800000000001/104.80000019073486 = 99.9% done in 33195.8s, 32.3s to go
# on time step 104703 (time=104.703), 0.325944 s/step
# Meep progress: 104.711/104.80000019073486 = 99.9% done in 33199.8s, 28.2s to go
# on time step 104716 (time=104.716), 0.308268 s/step
# Meep progress: 104.724/104.80000019073486 = 99.9% done in 33204.0s, 24.1s to go
# on time step 104729 (time=104.729), 0.328985 s/step
# Meep progress: 104.73700000000001/104.80000019073486 = 99.9% done in 33208.2s, 20.0s to go
# on time step 104742 (time=104.742), 0.316361 s/step
# Meep progress: 104.75/104.80000019073486 = 100.0% done in 33212.2s, 15.9s to go
# on time step 104755 (time=104.755), 0.31169 s/step
# Meep progress: 104.763/104.80000019073486 = 100.0% done in 33216.3s, 11.7s to go
# on time step 104768 (time=104.768), 0.32142 s/step
# Meep progress: 104.776/104.80000019073486 = 100.0% done in 33220.4s, 7.6s to go
# on time step 104782 (time=104.782), 0.299702 s/step
# Meep progress: 104.789/104.80000019073486 = 100.0% done in 33224.5s, 3.5s to go
# on time step 104795 (time=104.795), 0.317672 s/step
# run 0 finished at t = 104.8 (104800 timesteps)

# %%
#Plot the scattering efficiency against the spectrum of frequencies we sent toward the sphere:

plt.figure(dpi=150) #dpi is dots per inch. Just changes the resolution of the image of the plot.

#We'll plot wavelength.
#We'll also use a logged scale for both x and y axes (loglog).
plt.plot(1E3/np.asarray(freqs), scatt_flux, "bx-")
plt.grid(True, which="both", ls="-")
plt.xlabel("Wavelength, nm")
plt.ylabel("Scattering Power, W")
plt.title("Mie Scattering of Au Sphere")
plt.tight_layout()
plt.savefig(fname="Mie Scattering of a Au Sphere, single",
            dpi=150, 
            bbox_inches="tight")
plt.show()
